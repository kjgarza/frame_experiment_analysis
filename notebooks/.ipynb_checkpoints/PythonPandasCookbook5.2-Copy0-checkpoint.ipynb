# %% [markdown]
# # Frame Experiment Analysis
#
# <i>Created by Kristian G</i>

# %% [markdown]
# ### Preliminaries

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from extra_data import datatoFrame
from wordcloud import WordCloud
from ggplot import *

# %%
#seaborn settings
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8,4)})

# %% [markdown]
# ### Load Data Sets

# %%
input_data = datatoFrame('../logs/FrameExperiment', 'dummy')

# %%
df_filtered = input_data[input_data['honest'] == 'on']

# %%
df_filtered["with_who_3"] = df_filtered["with_who_2"].astype('category')
df_filtered.head(10)
# Out:
#                                   academic     awareness  data_file_title_2  \
# sessionid
# 23460298f5d8e931f6b8778e3a38e2c0         1  [u'2', u'3']             RNAseq
# c8f46d4d7396f2bd6056a74d449e2c41         1        [u'3']            DataSet
# a54bc527043e7ebd1b626ae87b073327         1        [u'1']            dataset
# 24b48f963cb4871264ec33551c6f4fb8         1           NaN                NaN
# c613e1d8edb212114499aff4bf996a8c         1             3        Images list
# 67d5452b269bdbfe2d76bb3b03c41f54         2        [u'3']  2014-12-12-2 set
# 891d3b6a0d199e6c89907339f70aa98d         1        [u'3']                NaN
#
#                                                       discipline  ease_1  \
# sessionid
# 23460298f5d8e931f6b8778e3a38e2c0  functional genomics researcher       4
# c8f46d4d7396f2bd6056a74d449e2c41                 Systems Biology       4
# a54bc527043e7ebd1b626ae87b073327       Environmental Engineering       5
# ...

# %% [markdown]
# ### Demographics

# %%
text =', '.join(str(x) for x in df_filtered.discipline)
wordcloud = WordCloud(font_path='/Library/Fonts/Courier New.ttf').generate(text)
plt.imshow(wordcloud)
plt.axis("off")
print df_filtered.when_best.astype('category')
df_filtered.when_best
# Out:
# sessionid
# 23460298f5d8e931f6b8778e3a38e2c0            before publication of a peer-review paper
# c8f46d4d7396f2bd6056a74d449e2c41    immediately after publication of a peer-review...
# a54bc527043e7ebd1b626ae87b073327    immediately after publication of a peer-review...
# 24b48f963cb4871264ec33551c6f4fb8    immediately after publication of a peer-review...
# c613e1d8edb212114499aff4bf996a8c            before publication of a peer-review paper
# 67d5452b269bdbfe2d76bb3b03c41f54    immediately after publication of a peer-review...
# 891d3b6a0d199e6c89907339f70aa98d    immediately after publication of a peer-review...
# Name: when_best, dtype: category
# Categories (2, object): [before publication of a peer-review paper < immediately after publication of a peer-review...]

# %%
text =', '.join(str(x) for x in df_filtered.materials_type)
wordcloud = WordCloud(font_path='/Library/Fonts/Courier New.ttf', stopwords="data, and, with, of, from, analysis").generate(text)
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
plt.hist(df_filtered.year_born)
# Out:
# (array([ 2.,  0.,  0.,  0.,  1.,  0.,  0.,  1.,  2.,  1.]),
#  array([ 1973. ,  1974.4,  1975.8,  1977.2,  1978.6,  1980. ,  1981.4,
#          1982.8,  1984.2,  1985.6,  1987. ]),
#  <a list of 10 Patch objects>)

# %%
s = df_filtered.groupby('treatment')['treatment'].count()
s.plot(kind='bar')

# %%
s = df_filtered.groupby('howmany')['howmany'].count()
s.plot(kind='bar')

# %%
s = df_filtered.groupby('updating')['updating'].count()
s.plot(kind='bar')

# %%
s = df_filtered.groupby('when_best')['when_best'].count()
s.plot(kind='bar')

# %%
df_filtered.groupby('treatment').describe()
# Out:
#                  academic    ease_1    ease_2  regret_1  regret_2  support_1  \
# treatment
# CONTROL   count  5.000000  5.000000  5.000000  5.000000   5.00000   5.000000
#           mean   1.200000  4.000000  4.000000  1.400000   1.20000   3.200000
#           std    0.447214  1.224745  0.707107  1.341641   1.30384   1.095445
#           min    1.000000  2.000000  3.000000  0.000000   0.00000   2.000000
#           25%    1.000000  4.000000  4.000000  0.000000   0.00000   3.000000
#           50%    1.000000  4.000000  4.000000  2.000000   1.00000   3.000000
#           75%    1.000000  5.000000  4.000000  2.000000   2.00000   3.000000
#           max    2.000000  5.000000  5.000000  3.000000   3.00000   5.000000
# TREATMENT count  2.000000  2.000000  1.000000  2.000000   2.00000   2.000000
#           mean   1.000000  4.000000  5.000000  2.000000   2.00000   4.000000
#           std    0.000000  0.000000       NaN  0.000000   0.00000   0.000000
# ...

# %% [markdown]
# ### Results

# %%
s = df_filtered.groupby(['treatment','when_to_2'])['when_to_2'].count()
s.plot(kind='bar')

# %%
s = df_filtered.groupby(['treatment','with_who_2'])['with_who_2'].count()
s.plot(kind='bar')

# %%
df_filtered2 = df_filtered[df_filtered['treatment'] == 'CONTROL']
df_filtered3 = df_filtered[df_filtered['treatment'] == 'TREATMENT']

#sns.boxplot([df_filtered2['ease_1'], df_filtered2['ease_2'].fillna(0)],  names=["pre", "post"],whis=np.inf, color="coral",  join_rm=True)

#sns.boxplot([df_filtered3['ease_1'], df_filtered3['ease_2'].fillna(0)],  names=["pre", "post"],whis=np.inf, color="coral",  join_rm=True)

sns.boxplot([df_filtered['ease_1'], df_filtered['ease_2'].fillna(0)],  names=["pre", "post"],whis=np.inf, color="coral",  join_rm=True)

# %%
sns.boxplot([df_filtered['time_1'], df_filtered['time_2'].fillna(0)],  names=["pre", "post"],whis=np.inf, color="coral",  join_rm=True)

# %%
sns.boxplot([df_filtered['support_1'], df_filtered['support_2'].fillna(0)],  names=["pre", "post"],whis=np.inf, color="coral",  join_rm=True)

# %%
sns.boxplot(titanic.Age, titanic.Sex, vert=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-179-b20db869d150> in <module>()
# ----> 1 sns.boxplot(titanic.Age, titanic.Sex, vert=False)
#
# NameError: name 'titanic' is not defined

# %%
sns.boxplot(server.Time)

# %%
sns.boxplot(mlb.Salary)

# %% [markdown]
# ### 3: Kernel Density Estimate Plot

# %%
sns.kdeplot(titanic.Age.dropna(), shade=True)

# %%
 sns.kdeplot(server.Time.dropna(), shade=True)

# %%
sns.kdeplot(mlb.Salary.dropna(), shade=True)

# %%
sns.distplot(titanic.Age.dropna())

# %%
 sns.distplot(server.Time.dropna())

# %%
 sns.distplot(mlb.Salary.dropna())

# %% [markdown]
# ### 4: Violin Plot

# %%
sns.violinplot(titanic.Age.dropna())

# %%
sns.violinplot(titanic.Age.dropna(), titanic.Sex)

# %%
sns.violinplot(mlb.Salary)

# %% [markdown]
# ### 5: Cumulative Distribution Function¶

# %%
sns.kdeplot(titanic.Age.dropna(), cumulative=True)

# %%
 sns.kdeplot(server.Time.dropna(), cumulative=True)

# %%
 sns.kdeplot(mlb.Salary.dropna(), cumulative=True)
# Out:
# /Users/malpaso/anaconda/lib/python2.7/site-packages/scipy/integrate/quadpack.py:321: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   warnings.warn(msg, IntegrationWarning)
