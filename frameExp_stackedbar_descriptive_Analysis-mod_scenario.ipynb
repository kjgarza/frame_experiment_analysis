# %% [markdown]
# # Frame Experiment Descriptive Analysis
#
# <i>Created by Kristian G</i>

# %% [markdown]
# ### Preliminaries

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from extract_data import datatoFrame
from code_data import *
from wordcloud import WordCloud
from ggplot import *
import json
from frame_experiment_table import FrameExperimentTable

# %%
# %pylab inline
# %load_ext rmagic
import pylab
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['xlim', 'ylim']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#seaborn settings
# sns.set_palette("deep", desat=.6)
# sns.set_context(rc={"figure.figsize": (8,4)})

# %% [markdown]
# #Data

# %% [markdown]
# ###Loading

# %%
# data1 = datatoFrame('logs/data_jennifer_bham', 'dummy4', 'old')
# data2 = datatoFrame('logs/data_two_records', 'dummy4','new')
# data3 = datatoFrame('logs/data_incremental_file', 'dummy4','new')
# # data4 = datatoFrame('/Users/kristian/RubymineProjects/seek-frames-prod/public/FrameExperiment', 'dummy4','new')
# data = pd.DataFrame.from_csv('logs/data_scramble_filled_csv.csv', sep=',', index_col=0)

# %%
# pieces = [data, data1, data2, data3]
# master_dataset = pd.concat(pieces)

# %%
# data2.ix[:,:'academic']

# %%
# master_dataset.ix[:,'academic':]

# %% [markdown]
# ###Filtering

# %%
c = FrameExperimentTable('logs/data_scenario_changed')
c.filter_noise()
c.code_survey_numeric()
master_dataset = c.get_plotdata()
master_dataset = master_dataset.replace(['stackeholders'],['stakeholders'])

df_filtered = master_dataset
# Out:
# (55, 40)
# classify_field - Fields Excluded
# (6,)
# (55, 42)
# New Usability Columns
# (55, 44)
# /Users/kristian/miniconda/lib/python2.7/site-packages/pandas/util/decorators.py:81: FutureWarning: the 'cols' keyword is deprecated, use 'subset' instead
#   warnings.warn(msg, FutureWarning)

# %%
df_filtered.ix[:,'discipline':]
# Out:
#                                                                          discipline  \
# sessionid
# 0687ef14d441706b211ff0edf9f2ebea                                       biochemistry
# 0ddaf25718c6b4c35bf05ae6335150d4                                         biophysics
# 18da94199bf2471a70d0298958543bb4                                            biology
# 23ba4e6b2b149ba6294bd7e0125b2948                             bioprocess engineering
# 2bd5b76b8fac74b062c1a99c9bbc0a75                                    systems biology
# 2be130732b05502a4a631bc01291b25b           computational biophysics, bioinformatics
# 38c7d17c9d41c293afe9d368d45a629c                                     bioinformatics
# 3ea2814b0443687ea2400e6c1726d7ab                                     bioinformatics
# 4306bad121fb3ad1fb2365dda1a32440                                     bioinformatics
# 4d9db524466a6d05f29fb721f842de77             neuroscience (of nociception and pain)
# 52d3867f738f6cff74269cf62e3b7251                                     bioinformatics
# 5b114f95a429eb982fc0b378c64a23f9                            biology, bioinformatics
# 690e88138d83a8ec5fea4230b364aae0                                    systems biology
# 6b216d7a04c90e3490fb335b6dc39314                               experimental biology
# 6fd7664989b2b16f85c63169595bb66e                                     bioinformatics
# 78764885189f4abe3a13ee47ebe3d1fa                                            biology
# 78a96862e5913958feedfe14d1fab097                                         hepatology
# 78d147e21c80109dbbd9d20b4c0e9599                                       microbiology
# 7f28b3efad0d8ae171c6b1ef5f121fae                                     bioinformatics
# 7f6ad16cca9e095737b8ad8089f11f51                                     bioinformatics
# 690e88138d83a8ec5fea4230b364aae0              Agree     ...
# 6b216d7a04c90e3490fb335b6dc39314              Agree     ...
# 6fd7664989b2b16f85c63169595bb66e            Neither     ...
# 78764885189f4abe3a13ee47ebe3d1fa     Strongly Agree     ...
# 78a96862e5913958feedfe14d1fab097           Disagree     ...
# 78d147e21c80109dbbd9d20b4c0e9599            Neither     ...
# 7f28b3efad0d8ae171c6b1ef5f121fae     Strongly Agree     ...
# 7f6ad16cca9e095737b8ad8089f11f51              Agree     ...
# 82767106b0a1223876d8e83a304c0ebb              Agree     ...
# 84435907d0139de1cd4eaf5a4992ee6c     Strongly Agree     ...
# 84876d35deb805f65d6a102cb79760f9            Neither     ...
# 84c2942a7672bd26bf4fe5712b305583              Agree     ...
# 8cb5d8f0b3e4d37a521ae650c4419c87              Agree     ...
# 8d302b9b42e172fd68dc46cdde1bde56              Agree     ...
# 904ea89665852be4d0df452236a32395              Agree     ...
# 93db2c509aad8d09d515c8e71ea60fce            Neither     ...
# 9ea45926a9c8ed339eb51007083b6d56              Agree     ...
# aaab26582025ca57df98adab9c821786           Disagree     ...
# b216c2e229949e81796327f3a133252e              Agree     ...
# b57ae216d47820a5a597768ddc48fdca           Disagree     ...
# c0ba478916443e75928dc18d1bc8e468              Agree     ...
# c122797a0a6e34e5c7159bb839ab9cec            Neither     ...
# c424cb968746b9c146cfda7af86bd46f            Neither     ...
# c4855b2635f52a5f8f10a13348b2e688              Agree     ...
# c4af4b34d71a116d49cfd1bbc37115dc            Neither     ...
# ce4dd38c1a2b00597a5937d82828d532              Agree     ...
# d05374703295171ee7746105b806e10b     Strongly Agree     ...
# d88bf82976822f5950e5bc4cf56e700a  Strongly Disagree     ...
# dce82b0bd1c889c42227c7290aa6cec0           Disagree     ...
# ed4707fdbf643cdb6651a9d7807d8048            Neither     ...
# f3906c5106e79f3165050a0fcbbf4cc3     Strongly Agree     ...
# fa251851931ddd1b63a9d66bd90ca95c              Agree     ...
# fc5bb1982077af9dd12aa7de0a5660c3              Agree     ...
#
#                                                                   data_file_title_2  \
# sessionid
# 0687ef14d441706b211ff0edf9f2ebea                                        mydata test
# 0ddaf25718c6b4c35bf05ae6335150d4                               2D PMF NaH exchanger
# 18da94199bf2471a70d0298958543bb4                                        My data set
# 23ba4e6b2b149ba6294bd7e0125b2948                                          more data
# 2bd5b76b8fac74b062c1a99c9bbc0a75                                Dataset for paper X
# 2be130732b05502a4a631bc01291b25b                                My cool new Dataset
# 38c7d17c9d41c293afe9d368d45a629c  Sodium concentrations in patients and controls...
# 3ea2814b0443687ea2400e6c1726d7ab                                             mydate
# 4306bad121fb3ad1fb2365dda1a32440                                                Foo
# 4d9db524466a6d05f29fb721f842de77                                        mydataset-1
# 52d3867f738f6cff74269cf62e3b7251                                            mydata2
# 5b114f95a429eb982fc0b378c64a23f9                 DraperA_etal_2015_Nature_SupplMat1
# 690e88138d83a8ec5fea4230b364aae0                                         crzy-stuff
# 6b216d7a04c90e3490fb335b6dc39314                                          cite test
# 6fd7664989b2b16f85c63169595bb66e                                         My dataset
# 4d9db524466a6d05f29fb721f842de77        nan         public       True    LS
# 52d3867f738f6cff74269cf62e3b7251         1y  collaborators       True    LS
# 5b114f95a429eb982fc0b378c64a23f9        nan         public       True    LS
# 690e88138d83a8ec5fea4230b364aae0        nan         public       True    LS
# 6b216d7a04c90e3490fb335b6dc39314        nan         public       True    LS
# 6fd7664989b2b16f85c63169595bb66e        nan         public       True    LS
# 78764885189f4abe3a13ee47ebe3d1fa        nan         public       True    LS
# 78a96862e5913958feedfe14d1fab097         6m  collaborators       True    LS
# 78d147e21c80109dbbd9d20b4c0e9599        nan         public       True    LS
# 7f28b3efad0d8ae171c6b1ef5f121fae        10y   stakeholders       True    LS
# 7f6ad16cca9e095737b8ad8089f11f51        nan         public       True    LS
# 82767106b0a1223876d8e83a304c0ebb        nan         public       True    LS
# 84435907d0139de1cd4eaf5a4992ee6c        nan         public       True    LS
# 84876d35deb805f65d6a102cb79760f9        nan         public       True    LS
# 84c2942a7672bd26bf4fe5712b305583        nan         public       True    LS
# 8cb5d8f0b3e4d37a521ae650c4419c87         1y   stakeholders       True    LS
# 8d302b9b42e172fd68dc46cdde1bde56         6m   stakeholders       True    LS
# 904ea89665852be4d0df452236a32395        10y   stakeholders       True    LS
# 93db2c509aad8d09d515c8e71ea60fce         1y   stakeholders       True    LS
# 9ea45926a9c8ed339eb51007083b6d56        nan         public       True    LS
# aaab26582025ca57df98adab9c821786        nan         public       True    LS
# b216c2e229949e81796327f3a133252e        nan         public       True    LS
# b57ae216d47820a5a597768ddc48fdca        nan         public       True    LS
# c0ba478916443e75928dc18d1bc8e468        10y   stakeholders       True    LS
# c122797a0a6e34e5c7159bb839ab9cec        nan         public       True    LS
# c424cb968746b9c146cfda7af86bd46f        nan         public       True    LS
# c4855b2635f52a5f8f10a13348b2e688        nan         public       True    LS
# c4af4b34d71a116d49cfd1bbc37115dc        nan         public       True    LS
# ce4dd38c1a2b00597a5937d82828d532        nan         public       True    LS
# d05374703295171ee7746105b806e10b        nan         public       True    LS
# d88bf82976822f5950e5bc4cf56e700a        nan         public       True    LS
# dce82b0bd1c889c42227c7290aa6cec0        nan         public       True    LS
# ed4707fdbf643cdb6651a9d7807d8048        nan         public       True    LS
# f3906c5106e79f3165050a0fcbbf4cc3        nan         public       True    LS
# fa251851931ddd1b63a9d66bd90ca95c        nan         public       True    LS
# fc5bb1982077af9dd12aa7de0a5660c3        nan         public       True    LS
#
#                                  usability_2  usability_1
# sessionid
# 0687ef14d441706b211ff0edf9f2ebea           4            4
# 0ddaf25718c6b4c35bf05ae6335150d4           4            4
# 18da94199bf2471a70d0298958543bb4           5            5
# 23ba4e6b2b149ba6294bd7e0125b2948           4            4
# 2bd5b76b8fac74b062c1a99c9bbc0a75           5            5
# 2be130732b05502a4a631bc01291b25b           5            5
# 38c7d17c9d41c293afe9d368d45a629c           5            5
# 3ea2814b0443687ea2400e6c1726d7ab           4            4
# 4306bad121fb3ad1fb2365dda1a32440           4            4
# 4d9db524466a6d05f29fb721f842de77           5            5
# 52d3867f738f6cff74269cf62e3b7251           4            3
# 5b114f95a429eb982fc0b378c64a23f9           5            5
# 690e88138d83a8ec5fea4230b364aae0           5            5
# 6b216d7a04c90e3490fb335b6dc39314           3            4
# 6fd7664989b2b16f85c63169595bb66e           4            4
# 78764885189f4abe3a13ee47ebe3d1fa           5            5
# 78a96862e5913958feedfe14d1fab097           5            3
# 78d147e21c80109dbbd9d20b4c0e9599           5            4
# 7f28b3efad0d8ae171c6b1ef5f121fae           4            4
# 7f6ad16cca9e095737b8ad8089f11f51           4            4
# 82767106b0a1223876d8e83a304c0ebb           5            4
# 84435907d0139de1cd4eaf5a4992ee6c           5            5
# 84876d35deb805f65d6a102cb79760f9           4            4
# 84c2942a7672bd26bf4fe5712b305583           5            5
# 8cb5d8f0b3e4d37a521ae650c4419c87           4            4
# 8d302b9b42e172fd68dc46cdde1bde56           4            4
# 904ea89665852be4d0df452236a32395           4            4
# 93db2c509aad8d09d515c8e71ea60fce           5            5
# 9ea45926a9c8ed339eb51007083b6d56           4            4
# aaab26582025ca57df98adab9c821786           2            2
# b216c2e229949e81796327f3a133252e           5            5
# b57ae216d47820a5a597768ddc48fdca           2            2
# c0ba478916443e75928dc18d1bc8e468           4            4
# c122797a0a6e34e5c7159bb839ab9cec           4            3
# c424cb968746b9c146cfda7af86bd46f           4            5
# c4855b2635f52a5f8f10a13348b2e688           5            5
# c4af4b34d71a116d49cfd1bbc37115dc           4            4
# ce4dd38c1a2b00597a5937d82828d532           4            4
# d05374703295171ee7746105b806e10b           5            5
# d88bf82976822f5950e5bc4cf56e700a           1            1
# dce82b0bd1c889c42227c7290aa6cec0           4            3
# ed4707fdbf643cdb6651a9d7807d8048           4            4
# f3906c5106e79f3165050a0fcbbf4cc3           5            5
# fa251851931ddd1b63a9d66bd90ca95c           4            4
# fc5bb1982077af9dd12aa7de0a5660c3           4            4
#
# [45 rows x 44 columns]

# %%
df_filtered['measure_1'] = df_filtered.apply(lambda row: code_openess_labels(row['treatment_eval_1'], row['with_who_1']), axis=1)
df_filtered['measure_2'] = df_filtered.apply(lambda row: code_openess_labels(row['treatment_eval_2'], row['with_who_2']), axis=1)

# %% [markdown]
# ##Research Question 1: Is a treatment better than the other one?
# Comparison all Control vs All Treatment

# %% [markdown]
# ###Data Re-shape

# %%
df_filtered.head(10)
pd.DataFrame.to_csv(df_filtered,'logs/data_coded_csv')

gg = df_filtered

# df = gg[gg.treatment_eval_1 != gg.treatment_eval_2]

df = gg

# x = batch_code(df)

x = df


dataUnderShareA = x[x['treatment_eval_1'] == 'Jam Share Data']
dataUnderShareB = x[x['treatment_eval_2'] == 'Jam Share Data']

dataUnderShareA = dataUnderShareA.reset_index()
dataUnderShareB = dataUnderShareB.reset_index()

dataUnderShare = dataUnderShareA['measure_1'].append(dataUnderShareB['measure_2'])

dataUnderCiteA = x[x['treatment_eval_1'] == 'cite DataLabour']
dataUnderCiteB = x[x['treatment_eval_2'] == 'cite DataLabour']

dataUnderCiteA = dataUnderCiteA.reset_index()
dataUnderCiteB = dataUnderCiteB.reset_index()

dataUnderCite = dataUnderCiteA['measure_1'].append(dataUnderCiteB['measure_2'])
DFdataUnderCite = pd.DataFrame({'Treatment_GAIN' :dataUnderCite})

DFdataUnderShare = pd.DataFrame({'Treatment_LOSS' :dataUnderShare})

# %% [markdown]
# #### Sharing Behaviour Aggregated Both Periods (EF)
#
# Makes no claim on carry over effects

# %%
# %%R -i DFdataUnderCite -i DFdataUnderShare
# source("stacked_bars.R")
# graph_with_who(DFdataUnderCite, DFdataUnderShare)

# %%
dataUnderShare       = dataUnderShareA['ease_1'].append(dataUnderShareB['ease_2'])
dataUnderCite        = dataUnderCiteA['ease_1'].append(dataUnderCiteB['ease_2'])
DFdataUnderCiteEase  = pd.DataFrame({'Treatment_GAIN_ease' :dataUnderCite})
DFdataUnderShareEase = pd.DataFrame({'Treatment_LOSS_ease' :dataUnderShare})

dataUnderShare       = dataUnderShareA['support_1'].append(dataUnderShareB['support_2'])
dataUnderCite        = dataUnderCiteA['support_1'].append(dataUnderCiteB['support_2'])
DFdataUnderCiteSupport  = pd.DataFrame({'Treatment_GAIN_support' :dataUnderCite})
DFdataUnderShareSupport = pd.DataFrame({'Treatment_LOSS_support' :dataUnderShare})

dataUnderShare       = dataUnderShareA['time_1'].append(dataUnderShareB['time_2'])
dataUnderCite        = dataUnderCiteA['time_1'].append(dataUnderCiteB['time_2'])
DFdataUnderCiteTime  = pd.DataFrame({'Treatment_GAIN_time' :dataUnderCite})
DFdataUnderShareTime = pd.DataFrame({'Treatment_LOSS_time' :dataUnderShare})

dataUnderShare       = dataUnderShareA['regret_1'].append(dataUnderShareB['regret_2'])
dataUnderCite        = dataUnderCiteA['regret_1'].append(dataUnderCiteB['regret_2'])
DFdataUnderCiteRegret  = pd.DataFrame({'Treatment_GAIN_regret' :dataUnderCite})
DFdataUnderShareRegret = pd.DataFrame({'Treatment_LOSS_regret' :dataUnderShare})




dataUnderShare       = dataUnderShareA['when_to_1'].append(dataUnderShareB['when_to_2'])
dataUnderCite        = dataUnderCiteA['when_to_1'].append(dataUnderCiteB['when_to_2'])
DFdataUnderCiteWhento  = pd.DataFrame({'GAIN_SCC' :dataUnderCite})
DFdataUnderShareWhento = pd.DataFrame({'LOSS_SCC' :dataUnderShare})

# %% [markdown]
# #### Sharing Behaviour Aggregated Both Periods (SCC)
#
# Makes no claim on carry over effects

# %%
# %%R -i DFdataUnderCiteWhento -i DFdataUnderShareWhento
# source("stacked_bars.R")
# graph_when(DFdataUnderCiteWhento, DFdataUnderShareWhento)

# %% [markdown]
# #### Usability Aggregated Both Periods

# %%
# %%R -i DFdataUnderCiteEase -i DFdataUnderShareEase -i DFdataUnderCiteSupport -i DFdataUnderShareSupport -i DFdataUnderCiteTime -iDFdataUnderShareTime
# source("stacked_bars.R")
# graph_usability(DFdataUnderCiteEase, DFdataUnderShareEase, DFdataUnderCiteSupport, DFdataUnderShareSupport, DFdataUnderCiteTime, DFdataUnderShareTime)

# %% [markdown]
# ####Regret Aggregated Both Periods

# %%
# %%R -i DFdataUnderCiteRegret -i DFdataUnderShareRegret
# source("stacked_bars.R")
# graph_linkert(DFdataUnderCiteRegret, DFdataUnderShareRegret)

# %% [markdown]
# ##Research Question 2: Is a treatment better than the other one when accounting for carry-over effects?
# Comparison Control vs Treatment only in first measure.

# %%
DFdataUnderCiteMeasure  = pd.DataFrame({'GAIN_P1' : x.measure_1[x.treatment_eval_1 == 'cite DataLabour']})
DFdataUnderShareMeasure = pd.DataFrame({'LOSS_P1' : x.measure_1[x.treatment_eval_1 == 'Jam Share Data']})

# %% [markdown]
# ####Sharing Behavior Treatment vs Control for P1 (EF)

# %%
# %%R -i DFdataUnderCiteMeasure -i DFdataUnderShareMeasure
# source("stacked_bars.R")
# graph_with_who(DFdataUnderCiteMeasure, DFdataUnderShareMeasure)
# Out:
# NULL

# %%
DFdataUnderCiteMeasure_2  = pd.DataFrame({'GAIN_P2' : x.measure_2[x.treatment_eval_2 == 'cite DataLabour']})
DFdataUnderShareMeasure_2 = pd.DataFrame({'LOSS_P2' : x.measure_2[x.treatment_eval_2 == 'Jam Share Data']})

# %% [markdown]
# ####Sharing Behavior Treatment vs Control for P2 (EF)

# %%
# %%R -i DFdataUnderCiteMeasure_2 -i DFdataUnderShareMeasure_2
# source("stacked_bars.R")
# graph_with_who(DFdataUnderCiteMeasure_2, DFdataUnderShareMeasure_2)
# Out:
# NULL

# %%
DFdataUnderCiteRegret  = pd.DataFrame({'GAIN_regret_P1' : x.regret_1[x.treatment_eval_1 == 'cite DataLabour']})
DFdataUnderShareRegret = pd.DataFrame({'LOSS_regret_P1' : x.regret_1[x.treatment_eval_1 == 'Jam Share Data']})

# %% [markdown]
# ####Regret Comapriso Period 1 (EF)

# %%
# %%R -i DFdataUnderCiteRegret -i DFdataUnderShareRegret
# source("stacked_bars.R")
# graph_linkert(DFdataUnderCiteRegret, DFdataUnderShareRegret)

# %% [markdown]
# ###Are the effects of the sequence?
# Comparison First vs Second.
# #### Sharing Behaviour P1 vs P2 (EF)

# %%
# %%R -i x
# require(likert)
# require(reshape)
# library(RColorBrewer)
# library(plyr)
# cc <-brewer.pal(4, "PuBu")
#
# likertLabels<- c("private", "collaborators", "stakeholders", "public")
#
#
#    mydata2 <- x[c("measure_1","measure_2")]
# #   DFG2 <- lapply(mydata2, factor, labels = likertLabels)
# #   DFG <- lapply(DFG2, factor, levels = likertLabels)
#
#
#    DFG <- lapply(mydata2, factor, levels = likertLabels)
#    d <- data.frame(DFG)
#    df24<-likert(d)
# s<-  plot(df24, color=cc, text.size=4,center=3, plot.percents=TRUE, plot.percent.neutral=FALSE,plot.percent.low=FALSE, plot.percent.high=FALSE, ordered=FALSE, group.order=names(d))
# s

# %% [markdown]
# #### Usability P1 vs P2

# %%
# %%R -i x
# require(likert)
# require(reshape)
# library(RColorBrewer)
# library(plyr)
# cc <-brewer.pal(5, "PuBu")
#
#   likertLabels<- c("Strongly Disagree", "Disagree", "Neither", "Agree", "Strongly Agree")
#
#    mydata2 <- x[c("ease_1","ease_2",  "time_1","time_2","support_1","support_2")]
#    DFG <- lapply(mydata2, factor, levels = likertLabels)
#    d <- data.frame(DFG)
#    df24<-likert(d)
#   plot(df24, color=cc, text.size=4,center=3, plot.percents=TRUE, plot.percent.low=TRUE, plot.percent.neutral=FALSE,plot.percent.high=TRUE, ordered=FALSE, group.order=names(d))

# %% [markdown]
# ##How the measurements compare by sequence?
# Comparison all Baseline vs Control vs All Treatment.
# #### Sharing Behaviour

# %% [markdown]
# #How the measurements compare with the opinion of users?
# Comparison all Baseline vs Control vs All Treatment.
# #### Sharing Behaviour
# #### Usability

# %% [markdown]
# ### Survey

# %% [markdown]
# ### Demographics

# %%
df_filtered = master_dataset

# %%
text =', '.join(str(x) for x in df_filtered.discipline)
wordcloud = WordCloud(font_path='/Library/Fonts/Courier New.ttf').generate(text)
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# A similar classification would need to be done for the type of data participants produce/collect.

# %%
text =', '.join(str(x) for x in df_filtered.materials_type)
wordcloud = WordCloud(font_path='/Library/Fonts/Courier New.ttf', stopwords="data, and, with, of, from, analysis").generate(text)
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# The sample is mostly consituted by PhD's in their mid-20s.

# %%
s = df_filtered.year_born[df_filtered.year_born != 2000]


plt.hist(s.dropna())
import scipy as sp

s = df_filtered.year_born[df_filtered.year_born != 2000]

sp.stats.describe(s.dropna())
# Out:
# (45,
#  (1950.0, 1989.0),
#  1976.8888888888889,
#  91.191919191919197,
#  -0.850059139835662,
#  0.299183609884798)

# %%
s = df_filtered.groupby('ways')['ways'].count()
s.plot(kind='bar')

# %%
s = df_filtered.groupby('man_hours')['man_hours'].count()
s.plot(kind='bar')

# %% [markdown]
# The pseudo random allocation of subjects has been balacing the treatment sequence administration fine.
#
# - CONTROL: participant that received the CONTROL product first.
# - TREATMENT: participant that received the TREATMENT product first.

# %%
s = df_filtered.groupby('treatment_eval_2')['treatment_eval_2'].count()
s.plot(kind='bar')

# %%
s = df_filtered.groupby('treatment_eval_1')['treatment_eval_1'].count()
s.plot(kind='bar')

# %%
s = df_filtered.groupby('howmany')['howmany'].count()
s.plot(kind='bar')

# %%
df_filtered['updating'] = df_filtered['updating'].fillna('not')

s = df_filtered.groupby('updating')['updating'].count()
s.plot(kind='bar')

# %%
df_filtered['when_best'] = df_filtered['when_best'].replace([1,2,3,4,5,6],['10 years','5 years','3 years','1 year','ASAP','before'])
s = df_filtered.groupby('when_best')['when_best'].count()
s.plot(kind='bar')

# %%
df_filtered.groupby('treatment_eval_1').describe()
# Out:
#                          academic  frequency gibberish   man_hours  \
# treatment_eval_1
# Jam Share Data   count  17.000000  16.000000        17   16.000000
#                  mean    1.117647   3.437500         1   44.250000
#                  std     0.332106   1.459166         0   72.182639
#                  min     1.000000   1.000000      True   10.000000
#                  25%     1.000000   2.750000         1   13.000000
#                  50%     1.000000   4.000000         1   17.500000
#                  75%     1.000000   4.250000         1   42.250000
#                  max     2.000000   5.000000      True  300.000000
# cite DataLabour  count  15.000000  14.000000        15   15.000000
#                  mean    1.000000   3.071429         1   24.533333
#                  std     0.000000   1.685426         0   19.845355
#                  min     1.000000   1.000000      True   10.000000
#                  25%     1.000000   2.000000         1   10.000000
#                  50%     1.000000   2.500000         1   15.000000
#                  75%     1.000000   5.000000         1   30.000000
#                  max     1.000000   5.000000      True   75.000000
#
#                         time_awareness_evaluation  time_create_1  \
# treatment_eval_1
# Jam Share Data   count               1.700000e+01   1.700000e+01
#                  mean                1.429223e+09   1.429223e+09
#                  std                 4.800416e+05   4.800477e+05
#                  min                 1.428593e+09   1.428592e+09
#                  25%                 1.429018e+09   1.429018e+09
#                  50%                 1.429032e+09   1.429032e+09
#                  75%                 1.429800e+09   1.429800e+09
#                  max                 1.430126e+09   1.430126e+09
# cite DataLabour  count               1.500000e+01   1.500000e+01
#                  mean                1.429135e+09   1.429134e+09
#                  std                 6.301125e+05   6.301587e+05
#                  min                 1.427879e+09   1.427879e+09
#                  25%                 1.428621e+09   1.428621e+09
#                  50%                 1.429037e+09   1.429037e+09
#                  75%                 1.429701e+09   1.429700e+09
#                  max                 1.430212e+09   1.430211e+09
#
#                         time_create_2  time_first_evaluation  \
# treatment_eval_1
# Jam Share Data   count   1.700000e+01           1.700000e+01
#                  mean    1.429223e+09           1.429223e+09
#                  std     4.800398e+05           4.800352e+05
#                  min     1.428593e+09           1.428592e+09
#                  25%     1.429018e+09           1.429018e+09
#                  50%     1.429032e+09           1.429032e+09
#                  75%     1.429800e+09           1.429800e+09
#                  max     1.430126e+09           1.430126e+09
# cite DataLabour  count   1.500000e+01           1.500000e+01
#                  mean    1.429134e+09           1.429134e+09
#                  std     6.301597e+05           6.301605e+05
#                  min     1.427879e+09           1.427879e+09
#                  25%     1.428621e+09           1.428621e+09
#                  50%     1.429037e+09           1.429037e+09
#                  75%     1.429701e+09           1.429701e+09
#                  max     1.430211e+09           1.430211e+09
#
#                         time_second_evaluation  trial_1  trial_2    year_born
# treatment_eval_1
# Jam Share Data   count            1.700000e+01       17       17    17.000000
#                  mean             1.429223e+09        0        1  1978.823529
#                  std              4.800384e+05        0        0     6.903217
#                  min              1.428593e+09        0        1  1968.000000
#                  25%              1.429018e+09        0        1  1973.000000
#                  50%              1.429032e+09        0        1  1980.000000
#                  75%              1.429800e+09        0        1  1985.000000
#                  max              1.430126e+09        0        1  1989.000000
# cite DataLabour  count            1.500000e+01       15       15    15.000000
#                  mean             1.429134e+09        0        1  1979.400000
#                  std              6.300934e+05        0        0     7.129416
#                  min              1.427879e+09        0        1  1963.000000
#                  25%              1.428621e+09        0        1  1975.000000
#                  50%              1.429037e+09        0        1  1980.000000
#                  75%              1.429701e+09        0        1  1985.500000
#                  max              1.430211e+09        0        1  1989.000000

# %% [markdown]
# ### Results

# %%
s = df_filtered.groupby(['treatment_eval_2','when_to_2'])['when_to_2'].count()
s.plot(kind='bar')

# %%
s = df_filtered.groupby(['treatment_eval_1','when_to_1'])['when_to_1'].count()
s.plot(kind='bar')
