# %% [markdown]
# #Frame Experiment Statistical Within Subject Analysis
#
# <i>Created by Kristian G</i>

# %% [markdown]
# Preliminaries

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from extract_data import datatoFrame
from code_data import *
from ggplot import *
import json
from frame_experiment_table import FrameExperimentTable

# %%
# %pylab inline
# %load_ext rmagic
# %load_ext rpy2.ipython
import pylab
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['xlim', 'ylim']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# # EF Analysis
#
#
# Emphasis framing Analysis (EF) referes to the analysis of the of the treatment usig the Emphaisi framing this is the  framing the interface design.
#
# We run this analysis using 3 different datasets: Old Scenario, the New Scenario and the Both Scenarios at the same time.
#
# - Old Scenario: data collected under the  old scenario does not makes explicit the element of competition in the experiment setup.
# - New Scenario: data collected under the new sceneario is that in which the subjects are frame to consider competition in the experiment.
# - Full: data putting together both scenarios.
#
# In order to check each scenario we fitted the data to Cummulitative link mixed model for ordinal data. Then we review the coeffients, p-values and Likehood ratio of the treatment in the old and new scenario. For the full dataset we include the scenario type in the model as a new variable to check if this variable was significant.

# %% [markdown]
# ##Loading Old Scenario dataset (OSD)

# %%
c = FrameExperimentTable('logs/data_incremental_file')
c.add_records('logs/data_two_records','new')
c.add_records_csv('logs/data_scramble_filled_csv.csv')
# c.add_records('logs/data_scenario_changed','new')
c.filter_noise()
c.code_for_stat_ana()
c.code_survey_numeric()
to_SAS = c.get_rm_ws_dataframe()
# Out:
# (21, 40)
# classify_field - Fields Excluded
# (4,)
# (30, 42)
# rm_ws_dataframe - Droping missing records
# (27, 5)
# rm_ws_dataframe - remove missing data
# (23, 5)
# rm_ws_dataframe - no duplicates
# (23, 6)

# %% [markdown]
# ##Filtering

# %%
# master_dataset = master_dataset.replace(['stackeholders'],['stakeholders'])
# df_filtered = master_dataset
# master_dataset.shape
# df_filtered = master_dataset[master_dataset['honest'] == 'on']

# %%
# %R rm(list=ls())

# %% [markdown]
# ##Running Logistic Regression (OSD)

# %%
# %%R -i to_SAS
# library(ordinal)
#
# getCLMM<- function(xx){
#     s <- data.frame(xx)
#     s$response <- factor(s$response)
#     s$trt <- factor(s$trt)
#     s$sequ <- factor(s$sequ)
#     s$period <- factor(s$period)
#     ##s <- within(s, Grp <- factor(id:sequ))
#     mm2 <- clmm(response ~ sequ  + trt + period  + (1 | id:sequ), s,  Hess = TRUE )
#     print (summary(mm2))
#     exp(cbind(OR =coef(mm2), confint(mm2)))
#     return(mm2)
# }
# model2<-getCLMM(to_SAS)
# Out:
# Cumulative Link Mixed Model fitted with the Laplace approximation
#
# formula: response ~ sequ + trt + period + (1 | id:sequ)
# data:    s
#
#  link  threshold nobs logLik AIC   niter     max.grad cond.H
#  logit flexible  44   -32.29 78.57 490(4904) 3.74e-06 3.2e+03
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  id:sequ (Intercept) 238.3    15.44
# Number of groups:  id:sequ 22
#
# Coefficients:
#         Estimate Std. Error z value Pr(>|z|)
# sequBA   -0.4768     3.4064  -0.140    0.889
# trtB      0.5546     1.8159   0.305    0.760
# period2   3.5341     2.5905   1.364    0.172
#
# Threshold coefficients:
#     Estimate Std. Error z value
# 1|2  -20.881     12.068  -1.730
# 2|3  -11.859      4.555  -2.604
# 3|4   -7.663      3.050  -2.512

# %% [markdown]
# ###Check ODDs Ratios (OSD)

# %%
# %%R -i to_SAS
#
# getCLMMW<- function(xx){
#     s <- data.frame(xx)
#     s$response <- factor(s$response)
#     s$trt <- factor(s$trt)
#     s$sequ <- factor(s$sequ)
#     s$period <- factor(s$period)
#     ##s <- within(s, Grp <- factor(id:sequ))
#     mm7 <-clmm(response ~ sequ + period + (1 | id:sequ), s,  Hess = TRUE )
#     print (summary(mm7))
#     exp(cbind(OR =coef(mm7), confint(mm7)))
#     return(mm7)
# }
# model3<-getCLMMW(to_SAS)
# anova(model2, model3)
# ###plot(fitted(mm2),residuals(mm2))
# Out:
# Cumulative Link Mixed Model fitted with the Laplace approximation
#
# formula: response ~ sequ + period + (1 | id:sequ)
# data:    s
#
#  link  threshold nobs logLik AIC   niter     max.grad cond.H
#  logit flexible  44   -32.34 76.68 308(3193) 9.59e-06 1.9e+03
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  id:sequ (Intercept) 198.6    14.09
# Number of groups:  id:sequ 22
#
# Coefficients:
#         Estimate Std. Error z value Pr(>|z|)
# sequBA  -0.03853    2.95665  -0.013    0.990
# period2  3.17159    1.93763   1.637    0.102
#
# Threshold coefficients:
#     Estimate Std. Error z value
# 1|2  -19.210      8.739  -2.198
# 2|3  -11.483      3.908  -2.938
# 3|4   -7.391      2.659  -2.779
# Likelihood ratio tests of cumulative link models:
#
#        formula:                                       link: threshold:
# model3 response ~ sequ + period + (1 | id:sequ)       logit flexible
# model2 response ~ sequ + trt + period + (1 | id:sequ) logit flexible
#
#        no.par    AIC  logLik LR.stat df Pr(>Chisq)
# model3      6 76.683 -32.342
# model2      7 78.575 -32.287  0.1088  1     0.7415

# %%
# %R rm(list=ls())

# %% [markdown]
# The results under the old scenario shown not effect from the treatment (p = 0.7230 ) and the presence of carry over effect (p = 0.0699).

# %% [markdown]
# ##Loading New Scenario dataset (NSD)

# %%
f = FrameExperimentTable('logs/data_scenario_changed')
f.filter_noise()
f.code_for_stat_ana()
f.code_survey_numeric()
new_data = f.get_rm_ws_dataframe()
# Out:
# (99, 40)
# classify_field - Fields Excluded
# (45,)
# (47, 42)
# rm_ws_dataframe - Droping missing records
# (47, 5)
# rm_ws_dataframe - remove missing data
# (47, 5)
# rm_ws_dataframe - no duplicates
# (47, 6)

# %% [markdown]
# ##Filtering

# %% [markdown]
# ##Running Logistic Regression (NSD)

# %%
# %%R -i new_data
# library(ordinal)
#
#
# getCLMMo<- function(xx){
#     s <- data.frame(xx)
#     s$response <- factor(s$response)
#     s$trt <- factor(s$trt)
#     s$sequ <- factor(s$sequ)
#     s$period <- factor(s$period)
#
#     ##s <- within(s, Grp <- factor(id:sequ))
#
#     mm2ff <- clmm(response ~ period + trt + sequ   + (1 | id:sequ), s, Hess = TRUE )
#
#     print (summary(mm2ff))
#     exp(cbind(OR =coef(mm2ff), confint(mm2ff)))
#     return(mm2ff)
# }
#
# model5<-getCLMMo(new_data)
#
# ###plot(fitted(mm2),residuals(mm2))
# Out:
# Cumulative Link Mixed Model fitted with the Laplace approximation
#
# formula: response ~ period + trt + sequ + (1 | id:sequ)
# data:    s
#
#  link  threshold nobs logLik AIC   niter     max.grad cond.H
#  logit flexible  90   -38.03 88.07 299(8124) 7.83e+01 1.2e+00
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  id:sequ (Intercept) 570.7    23.89
# Number of groups:  id:sequ 45
#
# Coefficients:
#           Estimate Std. Error z value Pr(>|z|)
# period2  2.7189233  0.0008006  3396.3   <2e-16 ***
# trtB    -6.9980463  0.0007994 -8754.3   <2e-16 ***
# sequBA   0.6378626  0.0008004   796.9   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Threshold coefficients:
#       Estimate Std. Error z value
# 2|3 -2.664e+01  8.005e-04  -33277
# 3|4 -1.530e+01  7.993e-04  -19142

# %% [markdown]
# ###Check ODDs Ratios (NSD)

# %%
# %%R -i new_data
#
# getCLMMW<- function(xx){
#
#
#     s <- data.frame(xx)
#     s$response <- factor(s$response)
#     s$trt <- factor(s$trt)
#     s$sequ <- factor(s$sequ)
#     s$period <- factor(s$period)
#
#     ##s <- within(s, Grp <- factor(id:sequ))
#
#     mm7 <-clmm(response ~ sequ + period + (1 | id:sequ), s,  Hess = TRUE )
#
#
#     print (summary(mm7))
#     exp(cbind(OR =coef(mm7), confint(mm7)))
#     return(mm7)
# }
#
#
#
#
# model6<-getCLMMW(new_data)
#
#
# anova(model5, model6)
# Out:
# Cumulative Link Mixed Model fitted with the Laplace approximation
#
# formula: response ~ sequ + period + (1 | id:sequ)
# data:    s
#
#  link  threshold nobs logLik AIC   niter     max.grad cond.H
#  logit flexible  90   -43.09 96.18 187(1268) 5.20e-05 3.7e+02
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  id:sequ (Intercept) 128.6    11.34
# Number of groups:  id:sequ 45
#
# Coefficients:
#         Estimate Std. Error z value Pr(>|z|)
# sequBA   -0.9032     2.0773  -0.435   0.6637
# period2   2.2435     1.2298   1.824   0.0681 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Threshold coefficients:
#     Estimate Std. Error z value
# 2|3  -12.531      2.643  -4.742
# 3|4   -7.896      1.874  -4.214
# Likelihood ratio tests of cumulative link models:
#
#        formula:                                       link: threshold:
# model6 response ~ sequ + period + (1 | id:sequ)       logit flexible
# model5 response ~ period + trt + sequ + (1 | id:sequ) logit flexible
#
#        no.par    AIC  logLik LR.stat df Pr(>Chisq)
# model6      5 96.183 -43.092
# model5      6 88.068 -38.034  10.116  1    0.00147 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %R rm(list=ls())

# %% [markdown]
# ##Load Full dataset

# %%
gg = FrameExperimentTable('logs/data_incremental_file')
gg.add_records('logs/data_two_records','new')
gg.add_records_csv('logs/data_scramble_filled_csv.csv')
gg.add_records('logs/data_scenario_changed','new')
gg.filter_noise()
gg.code_for_stat_ana()
gg.code_survey_numeric()

full_set = gg.get_rm_ws_dataframe()
# Out:
# (21, 40)
# classify_field - Fields Excluded
# (49,)
# (77, 42)
# rm_ws_dataframe - Droping missing records
# (74, 5)
# rm_ws_dataframe - remove missing data
# (70, 5)
# rm_ws_dataframe - no duplicates
# (70, 6)

# %% [markdown]
# ##Running Logistic Regression (FULL)

# %%
# %%R -i full_set
# library(ordinal)
#
# getCLMM22<- function(xx){
#     s <- data.frame(xx)
#     s$response <- factor(s$response)
#     s$trt <- factor(s$trt)
#     s$sequ <- factor(s$sequ)
#     s$period <- factor(s$period)
#     ##s$scenario <- factor(s$scenario)
#
#     ##s <- within(s, Grp <- factor(id:sequ))
#
#     mm2f <- clmm(response ~ sequ  + trt + period +(1 | id:sequ), s, Hess = TRUE )
#     print (summary(mm2f))
#     exp(cbind(OR =coef(mm2f), confint(mm2f)))
#     return(mm2f)
# }
#
# model7<-getCLMM22(full_set)
# ###plot(fitted(mm2),residuals(mm2))
# Out:
# Cumulative Link Mixed Model fitted with the Laplace approximation
#
# formula: response ~ sequ + trt + period + (1 | id:sequ)
# data:    s
#
#  link  threshold nobs logLik AIC    niter     max.grad cond.H
#  logit flexible  134  -74.39 162.78 493(7095) 2.81e-02 1.2e+03
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  id:sequ (Intercept) 199.4    14.12
# Number of groups:  id:sequ 67
#
# Coefficients:
#         Estimate Std. Error z value Pr(>|z|)
# sequBA    0.9272     1.9680   0.471   0.6375
# trtB     -1.9282     1.0614  -1.817   0.0693 .
# period2   2.6786     1.1531   2.323   0.0202 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Threshold coefficients:
#     Estimate Std. Error z value
# 1|2  -22.605      4.075  -5.547
# 2|3  -14.168      2.828  -5.009
# 3|4   -8.498      1.601  -5.306

# %% [markdown]
# ###Check ODDs ration (Full)

# %%
# %%R -i full_set
#
# getCLMMW2<- function(xx){
#
#     s <- data.frame(xx)
#     s$response <- factor(s$response)
#     s$trt <- factor(s$trt)
#     s$sequ <- factor(s$sequ)
#     s$period <- factor(s$period)
#     ##s$scenario <- factor(s$scenario)
#
#
#     ##s <- within(s, Grp <- factor(id:sequ))
#
#     mm7 <-clmm(response ~ sequ + period  + (1 | id:sequ), s,  Hess = TRUE )
#
#
#     print (summary(mm7))
#     exp(cbind(OR =coef(mm7), confint(mm7)))
#     return(mm7)
# }
#
#
# model8<-getCLMMW2(full_set)
#
#
# anova(model7, model8)
# Out:
# Cumulative Link Mixed Model fitted with the Laplace approximation
#
# formula: response ~ sequ + period + (1 | id:sequ)
# data:    s
#
#  link  threshold nobs logLik AIC    niter     max.grad cond.H
#  logit flexible  134  -76.42 164.85 265(2149) 4.91e-05 2.1e+03
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  id:sequ (Intercept) 182.7    13.52
# Number of groups:  id:sequ 67
#
# Coefficients:
#         Estimate Std. Error z value Pr(>|z|)
# sequBA   -0.4636     1.7493  -0.265   0.7910
# period2   2.6819     1.0464   2.563   0.0104 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Threshold coefficients:
#     Estimate Std. Error z value
# 1|2  -21.836      4.687  -4.659
# 2|3  -12.539      2.103  -5.963
# 3|4   -7.984      1.476  -5.409
# Likelihood ratio tests of cumulative link models:
#
#        formula:                                       link: threshold:
# model8 response ~ sequ + period + (1 | id:sequ)       logit flexible
# model7 response ~ sequ + trt + period + (1 | id:sequ) logit flexible
#
#        no.par    AIC  logLik LR.stat df Pr(>Chisq)
# model8      6 164.85 -76.423
# model7      7 162.78 -74.388  4.0702  1    0.04365 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %R rm(list=ls())

# %% [markdown]
# #SCC Within Subejcts Analysis
#
# When to cannot be done in within subject study because of the lack of subjects and subjects not following the same responses.
# This could be done only a between subject experiment.
#
#
# So what we will run is a between subjects experiment as:
#
# 1. Subjects were all independent and just have one intervention
# 1.
#
# I can do a wthin subjects if i combine levels

# %%
d = gg.get_rm_ws_dataframe_whent()
d['response'] = d['response'].replace(['10y','later','3y','1y','6m'],[5,5,4,3,2]) 
d = d.dropna()
d = d[d.response != 'null']
d
# Out:
# (77, 42)
# sasa
# (77, 5)
# (73, 5)
# (140, 5)
#     response trt sequ period                                id
# 2        nan   A   AB      1  0edc7c52e0ccb1714e9a39ea75af43fe
# 4        nan   A   AB      1  3cff31dfa808cff92541784186c8243a
# 5          5   A   AB      1  43f10113e67dff73361c235ee10bd14b
# 8        nan   A   AB      1  6481c74f482bb574529fcfe12f7247c2
# 9        nan   A   AB      1  85d35a71ea3dbd9e452e4c9a0b83016b
# 15         2   A   AB      1  c2026cc168583afd72bbfbb284c0f1e9
# 16         3   A   AB      1  9f739b36a1f91569017b5ab36be07f7f
# 22         3   A   AB      1  8ed6774338c3fee17bbdca2dfbc7f1d6
# 30       nan   A   AB      1  2bd5b76b8fac74b062c1a99c9bbc0a75
# 33       nan   A   AB      1  3ea2814b0443687ea2400e6c1726d7ab
# 35       nan   A   AB      1  4d9db524466a6d05f29fb721f842de77
# 36         2   A   AB      1  52d3867f738f6cff74269cf62e3b7251
# 37       nan   A   AB      1  5b114f95a429eb982fc0b378c64a23f9
# 38       nan   A   AB      1  690e88138d83a8ec5fea4230b364aae0
# 40       nan   A   AB      1  6fd7664989b2b16f85c63169595bb66e
# 41       nan   A   AB      1  78764885189f4abe3a13ee47ebe3d1fa
# 42         2   A   AB      1  78a96862e5913958feedfe14d1fab097
# 43       nan   A   AB      1  78d147e21c80109dbbd9d20b4c0e9599
# 44       nan   A   AB      1  7f28b3efad0d8ae171c6b1ef5f121fae
# 46       nan   A   AB      1  82767106b0a1223876d8e83a304c0ebb
# 49       nan   A   AB      1  84c2942a7672bd26bf4fe5712b305583
# 55       nan   A   AB      1  9ea45926a9c8ed339eb51007083b6d56
# 57       nan   A   AB      1  b216c2e229949e81796327f3a133252e
# 59       nan   A   AB      1  b57ae216d47820a5a597768ddc48fdca
# 60         4   A   AB      1  c0ba478916443e75928dc18d1bc8e468
# 63       nan   A   AB      1  c4855b2635f52a5f8f10a13348b2e688
# 67       nan   A   AB      1  d88bf82976822f5950e5bc4cf56e700a
# 68       nan   A   AB      1  dce82b0bd1c889c42227c7290aa6cec0
# 69       nan   A   AB      1  ed4707fdbf643cdb6651a9d7807d8048
# 70       nan   A   AB      1  f3906c5106e79f3165050a0fcbbf4cc3
# ..       ...  ..  ...    ...                               ...
# 76       nan   A   BA      2  358e6df6c02309c57fd05b27540fb8e8
# 79       nan   A   BA      2  4daf9ac2c73522a2339d564abc33f2d4
# 80       nan   A   BA      2  62d5d75aa5c5c673ff839565556057cd
# 83         5   A   BA      2  86ed6760b4a6fc54cff9850e090c7b5f
# 84       nan   A   BA      2  9bdb3c0e8ae917d2fe5dc746a4fe24c6
# 85         2   A   BA      2  b540afa5300616f5a6ed80106fb6b20e
# 86       nan   A   BA      2  e9e357d280b62fde1f5c9b718ee3ea36
# 87       nan   A   BA      2  68ec3fb55059c118977c24cbd4fca91c
# 90       nan   A   BA      2  66f12cf71b45603b5b5bded2142fb89c
# 99       nan   A   BA      2  0687ef14d441706b211ff0edf9f2ebea
# 100      nan   A   BA      2  0ddaf25718c6b4c35bf05ae6335150d4
# 101      nan   A   BA      2  18da94199bf2471a70d0298958543bb4
# 102      nan   A   BA      2  23ba4e6b2b149ba6294bd7e0125b2948
# 104      nan   A   BA      2  2be130732b05502a4a631bc01291b25b
# 105      nan   A   BA      2  38c7d17c9d41c293afe9d368d45a629c
# 107      nan   A   BA      2  4306bad121fb3ad1fb2365dda1a32440
# 112      nan   A   BA      2  6b216d7a04c90e3490fb335b6dc39314
# 118      nan   A   BA      2  7f6ad16cca9e095737b8ad8089f11f51
# 120      nan   A   BA      2  84435907d0139de1cd4eaf5a4992ee6c
# 121      nan   A   BA      2  84876d35deb805f65d6a102cb79760f9
# 123        3   A   BA      2  8cb5d8f0b3e4d37a521ae650c4419c87
# 124        2   A   BA      2  8d302b9b42e172fd68dc46cdde1bde56
# 125        5   A   BA      2  904ea89665852be4d0df452236a32395
# 127        3   A   BA      2  93db2c509aad8d09d515c8e71ea60fce
# 129      nan   A   BA      2  aaab26582025ca57df98adab9c821786
# 134      nan   A   BA      2  c122797a0a6e34e5c7159bb839ab9cec
# 135      nan   A   BA      2  c424cb968746b9c146cfda7af86bd46f
# 137      nan   A   BA      2  c4af4b34d71a116d49cfd1bbc37115dc
# 138      nan   A   BA      2  ce4dd38c1a2b00597a5937d82828d532
# 139      nan   A   BA      2  d05374703295171ee7746105b806e10b
#
# [130 rows x 5 columns]

# %%
# %%R -i d
# library(MASS)
# library(lme4)
# library(qqman)
#
# s <- data.frame(d)
# s$response <- factor(s$response)
# s$trt <- factor(s$trt)
# s$sequ <- factor(s$sequ)
# s$period <- factor(s$period)
#
# s <- within(s, Grp <- factor(id:sequ))
#
# options(contrasts = c(factor = "contr.SAS",ordered = "contr.poly"))
# mm1 <- lmer(response ~ sequ  + trt + period  + (sequ:trt) + (1 | id:sequ), s )
# print(summary(mm1))
# print(anova(mm1))
#
# plot(fitted(mm1),residuals(mm1))
#
# res_lme=residuals(mm1)
# plot(res_lme)
# qqnorm(res_lme)
# qqline(res_lme)
# Out:
# Loading required package: Matrix
# Loading required package: Rcpp
#
# Attaching package: ‘lme4’
#
# The following objects are masked from ‘package:ordinal’:
#
#     ranef, VarCorr
#
#
# For example usage please run: vignette('qqman')
#
# Citation appreciated but not required:
# Turner, S.D. qqman: an R package for visualizing GWAS results using Q-Q and manhattan plots. biorXiv DOI: 10.1101/005165 (2014).
#
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
# Linear mixed model fit by REML ['lmerMod']
# Formula: response ~ sequ + trt + period + (sequ:trt) + (1 | id:sequ)
#    Data: s
#
# REML criterion at convergence: 370.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.4505 -0.0516  0.1402  0.3804  2.4601
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  id:sequ  (Intercept) 0.7715   0.8783
#  Residual             0.4729   0.6877
# Number of obs: 130, groups:  id:sequ, 67
#
# Fixed effects:
#             Estimate Std. Error t value
# (Intercept)  4.60016    0.19936  23.074
# sequAB       0.06651    0.24734   0.269
# trtA        -0.11628    0.12190  -0.954
# period1     -0.18080    0.12190  -1.483
#
# Correlation of Fixed Effects:
#         (Intr) sequAB trtA
# sequAB  -0.673
# trtA    -0.298  0.022
# period1 -0.298  0.022 -0.027
# Analysis of Variance Table
#        Df  Sum Sq Mean Sq F value
# sequ    1 0.04973 0.04973  0.1052
# trt     1 0.46688 0.46688  0.9873
# period  1 1.04024 1.04024  2.1997

# %%
# %%R -i d
# library(ordinal)
# library(lme4)
#
# s <- data.frame(d)
# s$response <- factor(s$response)
# s$trt <- factor(s$trt)
# s$sequ <- factor(s$sequ)
# s$period <- factor(s$period)
#
# s <- within(s, Grp <- factor(id:sequ))
#
# mm2 <- clmm(response ~ sequ  + trt + period  +(1 | id:sequ), s, link="probit", Hess = TRUE )
#
#
# print (summary(mm2))
#
# ###exp(cbind(OR =coef(mm2), confint(mm2)))
#
# plot(fitted(mm2),residuals(mm2))
# Out:
# Cumulative Link Mixed Model fitted with the Laplace approximation
#
# formula: response ~ sequ + trt + period + (1 | id:sequ)
# data:    s
#
#  link   threshold nobs logLik AIC    niter     max.grad cond.H
#  probit flexible  130  -84.49 184.97 463(2070) 2.18e-05 3.5e+02
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  id:sequ (Intercept) 27.22    5.217
# Number of groups:  id:sequ 67
#
# Coefficients:
#         Estimate Std. Error z value Pr(>|z|)
# sequAB    0.3250     0.6781   0.479    0.632
# trtA     -0.2060     0.3726  -0.553    0.580
# period1  -0.7225     0.3796  -1.903    0.057 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Threshold coefficients:
#       Estimate Std. Error z value
# 2|3    -7.0740     0.9495  -7.450
# 3|4    -5.9831     0.8398  -7.124
# 4|5    -5.8561     0.8266  -7.084
# 5|nan  -4.2831     0.6523  -6.567

# %% [markdown]
# #Test all the interactions using Wilcox
#
#
# For this design the main comparison is the first interaction Treatment vs Control. All the others interactions are controls to see there is not bias.
# T1 = T2
# C1 = C2
#
#
# The difference between T and C must be very similar
# T1-C1 = T1-C2 = C1-T2 = C2-T2

# %% [markdown]
# ### T1 vs C1

# %%
master_dataset = gg.code_for_stat_ana()
# Out:
# (77, 42)

# %%
df = master_dataset.replace(['cite DataLabour','Jam Share Data'],['A','B'])
print df.shape
df = df[['treatment_eval_1','treatment_eval_2','with_who_1','with_who_2']]
df = df.dropna()
print df.shape
df = df[df.treatment_eval_1 != df.treatment_eval_2]
df = df.replace(['stackeholders'],['stakeholders'])
df = df.replace(['private','collaborators','stakeholders','public'],[1,2,3,4])
# t1 = df['with_who_1'][df['treatment_eval_1'] == 'A'].head(10)
# c1 = df['with_who_1'][df['treatment_eval_1'] == 'B'].head(10)
# Out:
# (77, 42)
# (74, 4)

# %%
df_new = master_dataset[['treatment_eval_1','treatment_eval_2','with_who_1','with_who_2']].dropna()
df_new = df_new.replace(['stackeholders'],['stakeholders'])
df_new = df_new.replace(['with_who_1'],[1])
df_new = df_new.replace(['private','collaborators','stakeholders','public'],[1,2,3,4])
df_new = df_new.replace(['cite DataLabour','Jam Share Data'],['A','B'])

s = pd.melt(df_new, id_vars=['with_who_1','with_who_2'])
# print df_new['with_who_2'].value_counts()
t1 = df['with_who_1'][df['treatment_eval_1'] == 'A'].value_counts()
c1 = df['with_who_1'][df['treatment_eval_1'] == 'B'].value_counts()
dd = pd.DataFrame({'t1' : t1, 'c1':c1}).fillna(0)
# d = dd.append(c1,ignore_index=True)
dd
# # s['with_who_1'].value_counts()
# w=s.pivot_table(['value',], rows=['with_who_1'], index=Grouper(freq='A', key='B'))
# w

# # w = s.groupby(['with_who_2'])
# # w.count()
# Out:
#    c1  t1
# 1   0   2
# 2   4   3
# 3   9   2
# 4  20  30

# %%
# %%R -i dd
# library(MASS)
# print(summary(dd))
# print(chisq.test(dd))
# #print(assocstats(dd))
# wilcox.test(dd$t1,dd$c1, paired=FALSE, conf.int = TRUE, alternative = "greater")
# Out:
#        c1              t1
#  Min.   : 0.00   Min.   : 2.00
#  1st Qu.: 3.00   1st Qu.: 2.00
#  Median : 6.50   Median : 2.50
#  Mean   : 8.25   Mean   : 9.25
#  3rd Qu.:11.75   3rd Qu.: 9.75
#  Max.   :20.00   Max.   :30.00
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 8.3962, df = 3, p-value = 0.03849
#
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  dd$t1 and dd$c1
# W = 7, p-value = 0.6684
# alternative hypothesis: true location shift is greater than 0
# 95 percent confidence interval:
#  -17.99993       Inf
# sample estimates:
# difference in location
#              -1.198189

# %% [markdown]
# ### T2 vs C2

# %%
t2 = df['with_who_2'][df['treatment_eval_2'] == 'A'].value_counts()
c2 = df['with_who_2'][df['treatment_eval_2'] == 'B'].value_counts()
dd = pd.DataFrame({'t2' : t2, 'c2':c2}).fillna(0)

# %%
# %%R -i dd
# library(MASS)
# library(vcd)
# print(dd)
# print(summary(dd))
# print(chisq.test(dd))
# print(fisher.test(dd))
# #print(assocstats(dd))
# wilcox.test(dd$t2,dd$c2, paired=FALSE, conf.int = TRUE, alternative = "greater")
# Out:
# Loading required package: grid
#     c2 t2
# 1.0  1  0
# 2.0  4  0
# 3.0  2  7
# 4.0 30 26
#        c2              t2
#  Min.   : 1.00   Min.   : 0.00
#  1st Qu.: 1.75   1st Qu.: 0.00
#  Median : 3.00   Median : 3.50
#  Mean   : 9.25   Mean   : 8.25
#  3rd Qu.:10.50   3rd Qu.:11.75
#  Max.   :30.00   Max.   :26.00
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 7.8606, df = 3, p-value = 0.04898
#
#
# 	Fisher's Exact Test for Count Data
#
# data:  dd
# p-value = 0.03125
# alternative hypothesis: two.sided
#
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  dd$t2 and dd$c2
# W = 6, p-value = 0.7661
# alternative hypothesis: true location shift is greater than 0
# 95 percent confidence interval:
#  -29.99991       Inf
# sample estimates:
# difference in location
#              -1.631706

# %% [markdown]
# ### T1 vs C2

# %%
t1 = df['with_who_1'][df['treatment_eval_1'] == 'A'].value_counts()
c2 = df['with_who_2'][df['treatment_eval_2'] == 'B'].value_counts()
dd = pd.DataFrame({'t1' : t1, 'c2':c2}).fillna(0)

# %%
# %%R -i dd
# library(MASS)
# library(vcd)
# print(dd)
# print(summary(dd))
# print(chisq.test(dd))
# print(fisher.test(dd))
# #print(assocstats(dd))
# wilcox.test(dd$t1, dd$c2, paired=TRUE, alternative = "greater")
# Out:
#     c2 t1
# 4.0 30 30
# 2.0  4  3
# 3.0  2  2
# 1.0  1  2
#        c2              t1
#  Min.   : 1.00   Min.   : 2.00
#  1st Qu.: 1.75   1st Qu.: 2.00
#  Median : 3.00   Median : 2.50
#  Mean   : 9.25   Mean   : 9.25
#  3rd Qu.:10.50   3rd Qu.: 9.75
#  Max.   :30.00   Max.   :30.00
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 0.4762, df = 3, p-value = 0.9241
#
#
# 	Fisher's Exact Test for Count Data
#
# data:  dd
# p-value = 1
# alternative hypothesis: two.sided
#
#
# 	Wilcoxon signed rank test with continuity correction
#
# data:  dd$t1 and dd$c2
# V = 1.5, p-value = 0.6813
# alternative hypothesis: true location shift is greater than 0

# %% [markdown]
# ### T2 vs C1

# %%
t2 = df['with_who_2'][df['treatment_eval_2'] == 'A'].value_counts()
c1 = df['with_who_1'][df['treatment_eval_1'] == 'B'].value_counts()
dd = pd.DataFrame({'t2' : t2, 'c1':c1}).fillna(0)

# %%
# %%R -i dd
# library(MASS)
# print(dd)
# print(summary(dd))
# print(chisq.test(dd))
# #print(assocstats(dd))
# wilcox.test(dd$t2, dd$c1, paired=TRUE, alternative = "greater")
# Out:
#   c1 t2
# 2  4  0
# 3  9  7
# 4 20 26
#        c1             t2
#  Min.   : 4.0   Min.   : 0.0
#  1st Qu.: 6.5   1st Qu.: 3.5
#  Median : 9.0   Median : 7.0
#  Mean   :11.0   Mean   :11.0
#  3rd Qu.:14.5   3rd Qu.:16.5
#  Max.   :20.0   Max.   :26.0
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 5.0326, df = 2, p-value = 0.08076
#
#
# 	Wilcoxon signed rank test
#
# data:  dd$t2 and dd$c1
# V = 3, p-value = 0.625
# alternative hypothesis: true location shift is greater than 0

# %% [markdown]
# ### T1 vs T2

# %%
t1 = df['with_who_1'][df['treatment_eval_1'] == 'A'].value_counts()
t2 = df['with_who_2'][df['treatment_eval_2'] == 'A'].value_counts()
dd = pd.DataFrame({'t1' : t1, 't2': t2}).fillna(0)

# %%
# %%R -i dd
# library(MASS)
# print(dd)
# print(summary(dd))
# print(chisq.test(dd))
# #print(assocstats(dd))
#
# wilcox.test(dd$t1, dd$t2, paired=FALSE, conf.int = TRUE, alternative = "greater")
# Out:
#   t1 t2
# 1  2  0
# 2  3  0
# 3  2  7
# 4 30 26
#        t1              t2
#  Min.   : 2.00   Min.   : 0.00
#  1st Qu.: 2.00   1st Qu.: 0.00
#  Median : 2.50   Median : 3.50
#  Mean   : 9.25   Mean   : 8.25
#  3rd Qu.: 9.75   3rd Qu.:11.75
#  Max.   :30.00   Max.   :26.00
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 7.8606, df = 3, p-value = 0.04898
#
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  dd$t1 and dd$t2
# W = 10, p-value = 0.3306
# alternative hypothesis: true location shift is greater than 0
# 95 percent confidence interval:
#  -23.99991       Inf
# sample estimates:
# difference in location
#               1.999961

# %% [markdown]
# ### C1 vs C2

# %%
c1 = df['with_who_1'][df['treatment_eval_1'] == 'B'].value_counts()
c2 = df['with_who_2'][df['treatment_eval_2'] == 'B'].value_counts()
dd = pd.DataFrame({'c1' : c1, 'c2': c2}).fillna(0)

# %%
# %%R -i dd
# library(MASS)
# print(dd)
# print(summary(dd))
# print(chisq.test(dd))
# #print(assocstats(dd))
#
# wilcox.test(dd$c1,dd$c2, paired=FALSE, conf.int = TRUE, alternative = "greater")
# Out:
#     c1 c2
# 1.0  0  1
# 2.0  4  4
# 3.0  9  2
# 4.0 20 30
#        c1              c2
#  Min.   : 0.00   Min.   : 1.00
#  1st Qu.: 3.00   1st Qu.: 1.75
#  Median : 6.50   Median : 3.00
#  Mean   : 8.25   Mean   : 9.25
#  3rd Qu.:11.75   3rd Qu.:10.50
#  Max.   :20.00   Max.   :30.00
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 7.2496, df = 3, p-value = 0.06435
#
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  dd$c1 and dd$c2
# W = 8.5, p-value = 0.5
# alternative hypothesis: true location shift is greater than 0
# 95 percent confidence interval:
#  -25.99998       Inf
# sample estimates:
# difference in location
#               1.290792

# %% [markdown]
# There is not a Statistical difference between the distributions (T1 vs C1).
#
#
# Actually the null hypothesis seems to be true in all interactions.
#
#
# T1-C1 = T1-C2 = C1-T2 = C2-T2

# %% [markdown]
# ### Chi square Analysi

# %%
df_filtered['measure_1'] = df_filtered.apply(lambda row: code_openess_labels(row['treatment_eval_1'], row['with_who_1']), axis=1)
df_filtered['measure_2'] = df_filtered.apply(lambda row: code_openess_labels(row['treatment_eval_2'], row['with_who_2']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-f2f10a6bcf5e> in <module>()
# ----> 1 df_filtered['measure_1'] = df_filtered.apply(lambda row: code_openess_labels(row['treatment_eval_1'], row['with_who_1']), axis=1)
#       2 df_filtered['measure_2'] = df_filtered.apply(lambda row: code_openess_labels(row['treatment_eval_2'], row['with_who_2']), axis=1)
#
# NameError: name 'df_filtered' is not defined

# %% [markdown]
# ###Logistic regression analysis

# %%
gg = df_new[['treatment_eval_1', 'treatment_eval_2','with_who_1','with_who_2']]
df_x = pd.melt(gg, id_vars=['treatment_eval_1', 'treatment_eval_2'])
df_x['trt'] = df_x.apply(lambda row: sepa_trt(row), axis=1)
df_x['trt'] = df_x['trt'].replace(['A','B'],['1','0'])
ddf = df_x.sort(columns=['trt'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-4a19f79a84a5> in <module>()
#       1 gg = df_new[['treatment_eval_1', 'treatment_eval_2','with_who_1','with_who_2']]
#       2 df_x = pd.melt(gg, id_vars=['treatment_eval_1', 'treatment_eval_2'])
# ----> 3 df_x['trt'] = df_x.apply(lambda row: sepa_trt(row), axis=1)
#       4 df_x['trt'] = df_x['trt'].replace(['A','B'],['1','0'])
#       5 ddf = df_x.sort(columns=['trt'])
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    3594                     if reduce is None:
#    3595                         reduce = True
# -> 3596                     return self._apply_standard(f, axis, reduce=reduce)
#    3597             else:
#    3598                 return self._apply_broadcast(f, axis)
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    3684             try:
#    3685                 for i, v in enumerate(series_gen):
# -> 3686                     results[i] = func(v)
#    3687                     keys.append(v.name)
#    3688             except Exception as e:
#
# <ipython-input-39-4a19f79a84a5> in <lambda>(row)
#       1 gg = df_new[['treatment_eval_1', 'treatment_eval_2','with_who_1','with_who_2']]
#       2 df_x = pd.melt(gg, id_vars=['treatment_eval_1', 'treatment_eval_2'])
# ----> 3 df_x['trt'] = df_x.apply(lambda row: sepa_trt(row), axis=1)
#       4 df_x['trt'] = df_x['trt'].replace(['A','B'],['1','0'])
#       5 ddf = df_x.sort(columns=['trt'])
#
# NameError: ("global name 'sepa_trt' is not defined", u'occurred at index 0')

# %% [markdown]
# ###T1 ~ C2

# %%
t1c2 = ddf[(ddf['variable'] == 'with_who_1') & (ddf['trt'] == '1') | (ddf['variable'] == 'with_who_2') & (ddf['trt'] == '0')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-edc580247af0> in <module>()
# ----> 1 t1c2 = ddf[(ddf['variable'] == 'with_who_1') & (ddf['trt'] == '1') | (ddf['variable'] == 'with_who_2') & (ddf['trt'] == '0')]
#
# NameError: name 'ddf' is not defined

# %%
# %%R -i t1c2
# library(MASS)
# ddf2 <- data.frame(t1c2)
# ddf2$value <- factor(ddf2$value)
# ddf2$trt <- factor(ddf2$trt)
#
# mymodel = polr(value ~ trt, data=ddf2,  Hess=TRUE)
#
# n1 <- data.frame(trt='1')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Treatment')
# print(s)
# n1 <- data.frame(trt='0')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Control')
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-8988d0639b55> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'R', u'-i t1c2', u'library(MASS)\nddf2 <- data.frame(t1c2)\nddf2$value <- factor(ddf2$value)\nddf2$trt <- factor(ddf2$trt)\n\nmymodel = polr(value ~ trt, data=ddf2,  Hess=TRUE)\n\nn1 <- data.frame(trt=\'1\')\ns<-predict(mymodel,n1, type="probs")\nprint(\'Probabilities for Treatment\')\nprint(s)\nn1 <- data.frame(trt=\'0\')\ns<-predict(mymodel,n1, type="probs")\nprint(\'Probabilities for Control\')\nprint(s)\n\nexp(cbind(OR =coef(mymodel), confint(mymodel)))')
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2160             magic_arg_s = self.var_expand(line, stack_depth)
#    2161             with self.builtin_trap:
# -> 2162                 result = fn(magic_arg_s, cell)
#    2163             return result
#    2164
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.pyc in R(self, line, cell, local_ns)
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.pyc in R(self, line, cell, local_ns)
#     620                         val = self.shell.user_ns[input]
#     621                     except KeyError:
# --> 622                         raise NameError("name '%s' is not defined" % input)
#     623                 ro.r.assign(input, self.pyconverter(val))
#     624
#
# NameError: name 't1c2' is not defined

# %% [markdown]
# ###T2 ~ C1

# %%
t2c1 = ddf[(ddf['variable'] == 'with_who_1') & (ddf['trt'] == '0') | (ddf['variable'] == 'with_who_2') & (ddf['trt'] == '1')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-af38b810b5cf> in <module>()
# ----> 1 t2c1 = ddf[(ddf['variable'] == 'with_who_1') & (ddf['trt'] == '0') | (ddf['variable'] == 'with_who_2') & (ddf['trt'] == '1')]
#
# NameError: name 'ddf' is not defined

# %%
# %%R -i t2c1
# library(MASS)
# ddf2 <- data.frame(t2c1)
# ddf2$value <- factor(ddf2$value)
# ddf2$trt <- factor(ddf2$trt)
#
# mymodel = polr(value ~ trt, data=ddf2,  Hess=TRUE)
#
# n1 <- data.frame(trt='1')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Treatment')
# print(s)
# n1 <- data.frame(trt='0')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Control')
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-49f9903fc587> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'R', u'-i t2c1', u'library(MASS)\nddf2 <- data.frame(t2c1)\nddf2$value <- factor(ddf2$value)\nddf2$trt <- factor(ddf2$trt)\n\nmymodel = polr(value ~ trt, data=ddf2,  Hess=TRUE)\n\nn1 <- data.frame(trt=\'1\')\ns<-predict(mymodel,n1, type="probs")\nprint(\'Probabilities for Treatment\')\nprint(s)\nn1 <- data.frame(trt=\'0\')\ns<-predict(mymodel,n1, type="probs")\nprint(\'Probabilities for Control\')\nprint(s)\n\nexp(cbind(OR =coef(mymodel), confint(mymodel)))')
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2160             magic_arg_s = self.var_expand(line, stack_depth)
#    2161             with self.builtin_trap:
# -> 2162                 result = fn(magic_arg_s, cell)
#    2163             return result
#    2164
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.pyc in R(self, line, cell, local_ns)
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.pyc in R(self, line, cell, local_ns)
#     620                         val = self.shell.user_ns[input]
#     621                     except KeyError:
# --> 622                         raise NameError("name '%s' is not defined" % input)
#     623                 ro.r.assign(input, self.pyconverter(val))
#     624
#
# NameError: name 't2c1' is not defined

# %% [markdown]
# ###T1 ~ C1

# %%
t1c1 = ddf[ddf['variable'] == 'with_who_1']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-637f2f74af70> in <module>()
# ----> 1 t1c1 = ddf[ddf['variable'] == 'with_who_1']
#
# NameError: name 'ddf' is not defined

# %%
# %%R -i t1c1
# library(MASS)
# ddf2 <- data.frame(t1c1)
# ddf2$value <- factor(ddf2$value)
# ddf2$trt <- factor(ddf2$trt)
#
# mymodel = polr(value ~ trt, data=ddf2,  Hess=TRUE, na.action=na.omit)
#
# n1 <- data.frame(trt='1')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Treatment')
# print(s)
# n1 <- data.frame(trt='0')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Control')
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-587562324a74> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'R', u'-i t1c1', u'library(MASS)\nddf2 <- data.frame(t1c1)\nddf2$value <- factor(ddf2$value)\nddf2$trt <- factor(ddf2$trt)\n\nmymodel = polr(value ~ trt, data=ddf2,  Hess=TRUE, na.action=na.omit)\n\nn1 <- data.frame(trt=\'1\')\ns<-predict(mymodel,n1, type="probs")\nprint(\'Probabilities for Treatment\')\nprint(s)\nn1 <- data.frame(trt=\'0\')\ns<-predict(mymodel,n1, type="probs")\nprint(\'Probabilities for Control\')\nprint(s)\n\nexp(cbind(OR =coef(mymodel), confint(mymodel)))')
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2160             magic_arg_s = self.var_expand(line, stack_depth)
#    2161             with self.builtin_trap:
# -> 2162                 result = fn(magic_arg_s, cell)
#    2163             return result
#    2164
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.pyc in R(self, line, cell, local_ns)
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.pyc in R(self, line, cell, local_ns)
#     620                         val = self.shell.user_ns[input]
#     621                     except KeyError:
# --> 622                         raise NameError("name '%s' is not defined" % input)
#     623                 ro.r.assign(input, self.pyconverter(val))
#     624
#
# NameError: name 't1c1' is not defined

# %% [markdown]
# ###T2 ~ C2

# %%
t2c2 = ddf[ddf['variable'] == 'with_who_2']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-ac42031fe030> in <module>()
# ----> 1 t2c2 = ddf[ddf['variable'] == 'with_who_2']
#
# NameError: name 'ddf' is not defined

# %%
# %%R -i t2c2
# library(MASS)
# ddw2 <- data.frame(t2c2)
# ddw2$value <- factor(ddw2$value)
# ddw2$trt <- factor(ddw2$trt)
#
# mymodel = polr(value ~ trt, data=ddw2,  Hess=TRUE, na.action=na.omit)
#
# n1 <- data.frame(trt='1')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Treatment')
# print(s)
# n1 <- data.frame(trt='0')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Control')
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-06c5f06e1213> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'R', u'-i t2c2', u'library(MASS)\nddw2 <- data.frame(t2c2)\nddw2$value <- factor(ddw2$value)\nddw2$trt <- factor(ddw2$trt)\n\nmymodel = polr(value ~ trt, data=ddw2,  Hess=TRUE, na.action=na.omit)\n\nn1 <- data.frame(trt=\'1\')\ns<-predict(mymodel,n1, type="probs")\nprint(\'Probabilities for Treatment\')\nprint(s)\nn1 <- data.frame(trt=\'0\')\ns<-predict(mymodel,n1, type="probs")\nprint(\'Probabilities for Control\')\nprint(s)\n\nexp(cbind(OR =coef(mymodel), confint(mymodel)))')
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2160             magic_arg_s = self.var_expand(line, stack_depth)
#    2161             with self.builtin_trap:
# -> 2162                 result = fn(magic_arg_s, cell)
#    2163             return result
#    2164
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.pyc in R(self, line, cell, local_ns)
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.pyc in R(self, line, cell, local_ns)
#     620                         val = self.shell.user_ns[input]
#     621                     except KeyError:
# --> 622                         raise NameError("name '%s' is not defined" % input)
#     623                 ro.r.assign(input, self.pyconverter(val))
#     624
#
# NameError: name 't2c2' is not defined

# %% [markdown]
# ##Research Question 1: Is a treatment better than the other one?
# Comparison all Control vs All Treatment

# %%
df = master_dataset.replace(['cite DataLabour','Jam Share Data'],['A','B'])
df = df[['treatment_eval_1','treatment_eval_2','with_who_1','with_who_2']].dropna()
df = df[df.treatment_eval_1 != df.treatment_eval_2]
df = df.replace(['stackeholders'],['stakeholders'])
df = df.replace(['private','collaborators','stakeholders','public'],[1,2,3,4])


t1 = df['with_who_1'][df['treatment_eval_1'] == 'A'].head(10)
c1 = df['with_who_1'][df['treatment_eval_1'] == 'B'].head(10)
print t1
print c1
# Out:
# sessionid
# 3ea2814b0443687ea2400e6c1726d7ab    4
# 52d3867f738f6cff74269cf62e3b7251    2
# 58d0e078f29b6a75e930333a851b5cb3    3
# 5b114f95a429eb982fc0b378c64a23f9    4
# 690e88138d83a8ec5fea4230b364aae0    4
# 6fd7664989b2b16f85c63169595bb66e    4
# 78764885189f4abe3a13ee47ebe3d1fa    4
# 78a96862e5913958feedfe14d1fab097    2
# 82767106b0a1223876d8e83a304c0ebb    4
# 9ea45926a9c8ed339eb51007083b6d56    4
# Name: with_who_1, dtype: int64
# sessionid
# 0ddaf25718c6b4c35bf05ae6335150d4    2
# 38c7d17c9d41c293afe9d368d45a629c    4
# 4306bad121fb3ad1fb2365dda1a32440    4
# 6b216d7a04c90e3490fb335b6dc39314    3
# 7f6ad16cca9e095737b8ad8089f11f51    2
# 84435907d0139de1cd4eaf5a4992ee6c    4
# 84876d35deb805f65d6a102cb79760f9    4
# 8cb5d8f0b3e4d37a521ae650c4419c87    3
# 904ea89665852be4d0df452236a32395    3
# 904ea89665852be4d0df452236a32395    3
# Name: with_who_1, dtype: int64

# %%
# %%R -i t1 -i c1
# library(MASS)
#
# tbl = table(t1, c1)
# chisq.test(tbl)
# Out:
# 	Pearson's Chi-squared test
#
# data:  tbl
# X-squared = 2.5, df = 4, p-value = 0.6446

# %% [markdown]
# ###Data Re-shape

# %%
df_filtered.head(10)
pd.DataFrame.to_csv(df_filtered,'logs/data_coded_csv')

gg = df_filtered

x = batch_code(gg)

dataUnderShareA = x[x['treatment_eval_1'] == 'Jam Share Data']
dataUnderShareB = x[x['treatment_eval_2'] == 'Jam Share Data']

dataUnderShareA = dataUnderShareA.reset_index()
dataUnderShareB = dataUnderShareB.reset_index()

dataUnderShare = dataUnderShareA['measure_1'].append(dataUnderShareB['measure_2'])

dataUnderCiteA = x[x['treatment_eval_1'] == 'cite DataLabour']
dataUnderCiteB = x[x['treatment_eval_2'] == 'cite DataLabour']

dataUnderCiteA = dataUnderCiteA.reset_index()
dataUnderCiteB = dataUnderCiteB.reset_index()

dataUnderCite = dataUnderCiteA['measure_1'].append(dataUnderCiteB['measure_2'])
DFdataUnderCite = pd.DataFrame({'Treatment_GAIN' :dataUnderCite})

DFdataUnderShare = pd.DataFrame({'Treatment_LOSS' :dataUnderShare})

# %%
dataUnderShare       = dataUnderShareA['ease_1'].append(dataUnderShareB['ease_2'])
dataUnderCite        = dataUnderCiteA['ease_1'].append(dataUnderCiteB['ease_2'])
DFdataUnderCiteEase  = pd.DataFrame({'Treatment_GAIN_ease' :dataUnderCite})
DFdataUnderShareEase = pd.DataFrame({'Treatment_LOSS_ease' :dataUnderShare})

dataUnderShare       = dataUnderShareA['support_1'].append(dataUnderShareB['support_2'])
dataUnderCite        = dataUnderCiteA['support_1'].append(dataUnderCiteB['support_2'])
DFdataUnderCiteSupport  = pd.DataFrame({'Treatment_GAIN_support' :dataUnderCite})
DFdataUnderShareSupport = pd.DataFrame({'Treatment_LOSS_support' :dataUnderShare})

dataUnderShare       = dataUnderShareA['time_1'].append(dataUnderShareB['time_2'])
dataUnderCite        = dataUnderCiteA['time_1'].append(dataUnderCiteB['time_2'])
DFdataUnderCiteTime  = pd.DataFrame({'Treatment_GAIN_time' :dataUnderCite})
DFdataUnderShareTime = pd.DataFrame({'Treatment_LOSS_time' :dataUnderShare})

dataUnderShare       = dataUnderShareA['regret_1'].append(dataUnderShareB['regret_2'])
dataUnderCite        = dataUnderCiteA['regret_1'].append(dataUnderCiteB['regret_2'])
DFdataUnderCiteRegret  = pd.DataFrame({'Treatment_GAIN_regret' :dataUnderCite})
DFdataUnderShareRegret = pd.DataFrame({'Treatment_LOSS_regret' :dataUnderShare})




dataUnderShare       = dataUnderShareA['when_to_1'].append(dataUnderShareB['when_to_2'])
dataUnderCite        = dataUnderCiteA['when_to_1'].append(dataUnderCiteB['when_to_2'])
DFdataUnderCiteWhento  = pd.DataFrame({'GAIN_when_to' :dataUnderCite})
DFdataUnderShareWhento = pd.DataFrame({'LOSS_when_to' :dataUnderShare})

# %%
def axbow(t):
    r = ""
    if t == 'Jam Share Data':
        r =0
    elif t == 'cite DataLabour':
        r = 1
    return r
    
df_filtered['treatment_1'] = df_filtered.apply(lambda row: code_treatment_numeric(row['treatment_eval_1']), axis=1)
df_filtered['treatment_2'] = df_filtered.apply(lambda row: code_treatment_numeric(row['treatment_eval_2']), axis=1)

# %%
df_filtered['measure_1'] = df_filtered.apply(lambda row: code_openess_numeric(row['treatment_eval_1'], row['with_who_1']), axis=1)
df_filtered['measure_1']
mydatatable_1 = df_filtered[['measure_1','year_born','treatment_1']]
mydatatable_1 = mydatatable_1.drop(['c2026cc168583afd72bbfbb284c0f1e9','73cd08d3f841f5a9f085fd88a7694216'])
mydatatable_1

df_filtered['measure_2'] = df_filtered.apply(lambda row: code_openess_numeric(row['treatment_eval_2'], row['with_who_2']), axis=1)
df_filtered['measure_2']
mydatatable = df_filtered[['measure_2','year_born','treatment_2']]
mydatatable = mydatatable.dropna()
mydatatable
# Out:
#                                   measure_2  year_born  treatment_2
# sessionid
# 0ddaf25718c6b4c35bf05ae6335150d4          4       1971            1
# 38c7d17c9d41c293afe9d368d45a629c          4       1981            1
# 3ea2814b0443687ea2400e6c1726d7ab          4       1976            0
# 4306bad121fb3ad1fb2365dda1a32440          4       1973            1
# 52d3867f738f6cff74269cf62e3b7251          2       1986            0
# 58d0e078f29b6a75e930333a851b5cb3          2       1973            0
# 5b114f95a429eb982fc0b378c64a23f9          4       1989            0
# 690e88138d83a8ec5fea4230b364aae0          4       1985            0
# 6b216d7a04c90e3490fb335b6dc39314          4       1973            1
# 6fd7664989b2b16f85c63169595bb66e          4       1973            0
# 78764885189f4abe3a13ee47ebe3d1fa          4       1963            0
# 78a96862e5913958feedfe14d1fab097          2       1975            0
# 7f6ad16cca9e095737b8ad8089f11f51          4       1968            1
# 82767106b0a1223876d8e83a304c0ebb          4       1983            0
# 84435907d0139de1cd4eaf5a4992ee6c          4       1987            1
# 84876d35deb805f65d6a102cb79760f9          4       1974            1
# 8cb5d8f0b3e4d37a521ae650c4419c87          3       1989            1
# 904ea89665852be4d0df452236a32395          3       1980            1
# 904ea89665852be4d0df452236a32395          3       1980            1
# 93db2c509aad8d09d515c8e71ea60fce          3       1968            1
# 9cdbd6ec8df0f2d350c1d5bd74f7ebb0          4       1987            1
# 9ea45926a9c8ed339eb51007083b6d56          4       1975            0
# aaab26582025ca57df98adab9c821786          4       1974            1
# b57ae216d47820a5a597768ddc48fdca          4       1977            0
# c122797a0a6e34e5c7159bb839ab9cec          4       1981            1
# c424cb968746b9c146cfda7af86bd46f          4       1985            1
# c4855b2635f52a5f8f10a13348b2e688          4       1988            0
# ce4dd38c1a2b00597a5937d82828d532          4       1984            1
# d05374703295171ee7746105b806e10b          4       1985            1
# d88bf82976822f5950e5bc4cf56e700a          4       1980            0
# dce82b0bd1c889c42227c7290aa6cec0          4       1986            0
# f3906c5106e79f3165050a0fcbbf4cc3          4       1982            0

# %%
# %%R -i mydatatable
# library(MASS)
# df_filtered <- data.frame(mydatatable)
# df_filtered$measure_2 <- factor(df_filtered$measure_2)
# df_filtered$year_born <- as.numeric(df_filtered$year_born)
#
# print (head(df_filtered,10))
#
# mymodel = polr(measure_2 ~ treatment_2, data=df_filtered, Hess=TRUE, na.action=na.omit)
#
# n1 <- data.frame(treatment_2='0')
# s<-predict(mymodel,n1, type="probs")
#
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
#    measure_2 year_born treatment_2
# 1          4      1971           1
# 2          4      1981           1
# 3          4      1976           0
# 4          4      1973           1
# 5          2      1986           0
# 6          2      1973           0
# 7          4      1989           0
# 8          4      1985           0
# 9          4      1973           1
# 10         4      1973           0
# Error: variable 'treatment_2' was fitted with type "numeric" but type "factor" was supplied
# In addition: There were 13 warnings (use warnings() to see them)
# Error: variable 'treatment_2' was fitted with type "numeric" but type "factor" was supplied

# %%
print mydatatable
print mydatatable_1

mydatatable.columns = ['measure', 'year_born','treatment']
mydatatable_1.columns = ['measure', 'year_born','treatment']
c = mydatatable_1.append(mydatatable, ignore_index=True )
c
# Out:
#                                   measure_2  year_born  treatment_2
# sessionid
# 0ddaf25718c6b4c35bf05ae6335150d4          4       1971            1
# 38c7d17c9d41c293afe9d368d45a629c          4       1981            1
# 3ea2814b0443687ea2400e6c1726d7ab          4       1976            0
# 4306bad121fb3ad1fb2365dda1a32440          4       1973            1
# 52d3867f738f6cff74269cf62e3b7251          2       1986            0
# 58d0e078f29b6a75e930333a851b5cb3          2       1973            0
# 5b114f95a429eb982fc0b378c64a23f9          4       1989            0
# 690e88138d83a8ec5fea4230b364aae0          4       1985            0
# 6b216d7a04c90e3490fb335b6dc39314          4       1973            1
# 6fd7664989b2b16f85c63169595bb66e          4       1973            0
# 78764885189f4abe3a13ee47ebe3d1fa          4       1963            0
# 78a96862e5913958feedfe14d1fab097          2       1975            0
# 7f6ad16cca9e095737b8ad8089f11f51          4       1968            1
# 82767106b0a1223876d8e83a304c0ebb          4       1983            0
# 84435907d0139de1cd4eaf5a4992ee6c          4       1987            1
# 84876d35deb805f65d6a102cb79760f9          4       1974            1
# 8cb5d8f0b3e4d37a521ae650c4419c87          3       1989            1
# 904ea89665852be4d0df452236a32395          3       1980            1
# 904ea89665852be4d0df452236a32395          3       1980            1
# 93db2c509aad8d09d515c8e71ea60fce          3       1968            1
# 9cdbd6ec8df0f2d350c1d5bd74f7ebb0          4       1987            1
# 9ea45926a9c8ed339eb51007083b6d56          4       1975            0
# aaab26582025ca57df98adab9c821786          4       1974            1
# b57ae216d47820a5a597768ddc48fdca          4       1977            0
# c122797a0a6e34e5c7159bb839ab9cec          4       1981            1
# c424cb968746b9c146cfda7af86bd46f          4       1985            1
# c4855b2635f52a5f8f10a13348b2e688          4       1988            0
# ce4dd38c1a2b00597a5937d82828d532          4       1984            1
# d05374703295171ee7746105b806e10b          4       1985            1
# d88bf82976822f5950e5bc4cf56e700a          4       1980            0
# dce82b0bd1c889c42227c7290aa6cec0          4       1986            0
# f3906c5106e79f3165050a0fcbbf4cc3          4       1982            0
#                                   measure_1  year_born  treatment_1
# sessionid
# 0ddaf25718c6b4c35bf05ae6335150d4          2       1971            0
# 38c7d17c9d41c293afe9d368d45a629c          4       1981            0
# 3ea2814b0443687ea2400e6c1726d7ab          4       1976            1
# 4306bad121fb3ad1fb2365dda1a32440          4       1973            0
# 52d3867f738f6cff74269cf62e3b7251          2       1986            1
# 58d0e078f29b6a75e930333a851b5cb3          3       1973            1
# 5b114f95a429eb982fc0b378c64a23f9          4       1989            1
# 690e88138d83a8ec5fea4230b364aae0          4       1985            1
# 6b216d7a04c90e3490fb335b6dc39314          3       1973            0
# 6fd7664989b2b16f85c63169595bb66e          4       1973            1
# 78764885189f4abe3a13ee47ebe3d1fa          4       1963            1
# 78a96862e5913958feedfe14d1fab097          2       1975            1
# 7f6ad16cca9e095737b8ad8089f11f51          2       1968            0
# 82767106b0a1223876d8e83a304c0ebb          4       1983            1
# 84435907d0139de1cd4eaf5a4992ee6c          4       1987            0
# 84876d35deb805f65d6a102cb79760f9          4       1974            0
# 8cb5d8f0b3e4d37a521ae650c4419c87          3       1989            0
# 904ea89665852be4d0df452236a32395          3       1980            0
# 904ea89665852be4d0df452236a32395          3       1980            0
# 93db2c509aad8d09d515c8e71ea60fce          2       1968            0
# 9cdbd6ec8df0f2d350c1d5bd74f7ebb0          4       1987            0
# 9ea45926a9c8ed339eb51007083b6d56          4       1975            1
# aaab26582025ca57df98adab9c821786          4       1974            0
# b57ae216d47820a5a597768ddc48fdca          4       1977            1
# c122797a0a6e34e5c7159bb839ab9cec          4       1981            0
# c424cb968746b9c146cfda7af86bd46f          3       1985            0
# c4855b2635f52a5f8f10a13348b2e688          4       1988            1
# ce4dd38c1a2b00597a5937d82828d532          4       1984            0
# d05374703295171ee7746105b806e10b          4       1985            0
# d88bf82976822f5950e5bc4cf56e700a          4       1980            1
# dce82b0bd1c889c42227c7290aa6cec0          4       1986            1
# f3906c5106e79f3165050a0fcbbf4cc3          4       1982            1
#     measure  year_born  treatment
# 0         2       1971          0
# 1         4       1981          0
# 2         4       1976          1
# 3         4       1973          0
# 4         2       1986          1
# 5         3       1973          1
# 6         4       1989          1
# 7         4       1985          1
# 8         3       1973          0
# 9         4       1973          1
# 10        4       1963          1
# 11        2       1975          1
# 12        2       1968          0
# 13        4       1983          1
# 14        4       1987          0
# 15        4       1974          0
# 16        3       1989          0
# 17        3       1980          0
# 18        3       1980          0
# 19        2       1968          0
# 20        4       1987          0
# 21        4       1975          1
# 22        4       1974          0
# 23        4       1977          1
# 24        4       1981          0
# 25        3       1985          0
# 26        4       1988          1
# 27        4       1984          0
# 28        4       1985          0
# 29        4       1980          1
# ..      ...        ...        ...
# 34        4       1976          0
# 35        4       1973          1
# 36        2       1986          0
# 37        2       1973          0
# 38        4       1989          0
# 39        4       1985          0
# 40        4       1973          1
# 41        4       1973          0
# 42        4       1963          0
# 43        2       1975          0
# 44        4       1968          1
# 45        4       1983          0
# 46        4       1987          1
# 47        4       1974          1
# 48        3       1989          1
# 49        3       1980          1
# 50        3       1980          1
# 51        3       1968          1
# 52        4       1987          1
# 53        4       1975          0
# 54        4       1974          1
# 55        4       1977          0
# 56        4       1981          1
# 57        4       1985          1
# 58        4       1988          0
# 59        4       1984          1
# 60        4       1985          1
# 61        4       1980          0
# 62        4       1986          0
# 63        4       1982          0
#
# [64 rows x 3 columns]

# %%
# %%R -i c
# library(MASS)
# df_filtered <- data.frame(c)
# df_filtered$measure <- factor(df_filtered$measure)
# df_filtered$year_born <- as.numeric(df_filtered$year_born)
#
# print (head(df_filtered,10))
#
# mymodel = polr(measure ~ treatment, data=df_filtered, Hess=TRUE, na.action=na.omit)
#
# n1 <- data.frame(treatment='0')
# s<-predict(mymodel,n1, type="probs")
#
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
#   measure year_born treatment
# 0       2      1971         0
# 1       4      1981         0
# 2       4      1976         1
# 3       4      1973         0
# 4       2      1986         1
# 5       3      1973         1
# 6       4      1989         1
# 7       4      1985         1
# 8       3      1973         0
# 9       4      1973         1
# Error: variable 'treatment' was fitted with type "numeric" but type "factor" was supplied

# %% [markdown]
# ##Research Question 2: Is a treatment better than the other one when accounting for carry-over effects?
# Comparison Control vs Treatment only in first measure.

# %%
DFdataUnderCiteMeasure  = pd.DataFrame({'GAIN_P1' : x.measure_1[x.treatment_eval_1 == 'cite DataLabour']})
DFdataUnderShareMeasure = pd.DataFrame({'LOSS_P1' : x.measure_1[x.treatment_eval_1 == 'Jam Share Data']})

# %% [markdown]
# ####Sharing Behavior

# %%
# %%R -i DFdataUnderCiteMeasure -i DFdataUnderShareMeasure
# require(likert)
# require(reshape)
# library(RColorBrewer)
# library(plyr)
# cc <-brewer.pal(4, "PuBu")
# #mydata = read.csv("../../delete_two_records_csv")
#
# #Product_Gain <- c(x$measure_1[x$treatment_eval_1 == 'cite DataLabour'])
# #Product_Loss <- c(x$measure_1[x$treatment_eval_1 == 'Jam Share Data'])
# #Product_Gain <- c(mydata$regret_1[mydata$treatment_eval_1 == 'cite DataLabour'], mydata$regret_2[mydata$treatment_eval_2 == 'cite DataLabour'])
# #Product_Loss <- c(mydata$regret_1[mydata$treatment_eval_1 == 'Jam Share Data'], mydata$regret_2[mydata$treatment_eval_2 == 'Jam Share Data'])
#
# likertLabels<- c("private", "collaborators", "stackeholders", "public")
#
#    dAlcite <- data.frame(DFdataUnderCiteMeasure)
#    dAshare <- data.frame(DFdataUnderShareMeasure)
#
#    myList5 <- list(dAshare, dAlcite)
#    junto <-do.call(rbind.fill, myList5)
#    djunto <- data.frame(junto)
#    mydata2 <- junto
#
# DFG <- lapply(mydata2, factor, levels = likertLabels)
# d <- data.frame(DFG)
# df24<-likert(d)
# s<- plot(df24, color=cc,center=3, text.size=4,plot.percents=TRUE, plot.percent.neutral=FALSE,plot.percent.low=FALSE, plot.percent.high=FALSE, ordered=FALSE, group.order=names(d))
# s
# Out:
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-58-1835996c1253> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'R', u'-i DFdataUnderCiteMeasure -i DFdataUnderShareMeasure', u'require(likert)\nrequire(reshape)\nlibrary(RColorBrewer)\nlibrary(plyr)\ncc <-brewer.pal(4, "PuBu")\n#mydata = read.csv("../../delete_two_records_csv")\n\n#Product_Gain <- c(x$measure_1[x$treatment_eval_1 == \'cite DataLabour\'])\n#Product_Loss <- c(x$measure_1[x$treatment_eval_1 == \'Jam Share Data\'])\n#Product_Gain <- c(mydata$regret_1[mydata$treatment_eval_1 == \'cite DataLabour\'], mydata$regret_2[mydata$treatment_eval_2 == \'cite DataLabour\'])\n#Product_Loss <- c(mydata$regret_1[mydata$treatment_eval_1 == \'Jam Share Data\'], mydata$regret_2[mydata$treatment_eval_2 == \'Jam Share Data\'])\n   \nlikertLabels<- c("private", "collaborators", "stackeholders", "public")\n  \n   dAlcite <- data.frame(DFdataUnderCiteMeasure)\n   dAshare <- data.frame(DFdataUnderShareMeasure)\n\n   myList5 <- list(dAshare, dAlcite)\n   junto <-do.call(rbind.fill, myList5)\n   djunto <- data.frame(junto)\n   mydata2 <- junto\n\nDFG <- lapply(mydata2, factor, levels = likertLabels)\nd <- data.frame(DFG)\ndf24<-likert(d)\ns<- plot(df24, color=cc,center=3, text.size=4,plot.percents=TRUE, plot.percent.neutral=FALSE,plot.percent.low=FALSE, plot.percent.high=FALSE, ordered=FALSE, group.order=names(d)) \ns ')
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2160             magic_arg_s = self.var_expand(line, stack_depth)
#    2161             with self.builtin_trap:
# -> 2162                 result = fn(magic_arg_s, cell)
#    2163             return result
#    2164
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.pyc in R(self, line, cell, local_ns)
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.pyc in R(self, line, cell, local_ns)
#     640                     old_writeconsole = ri.get_writeconsole()
#     641                     ri.set_writeconsole(self.write_console)
# --> 642                     ro.r.show(result)
#     643                     text_output += self.flush()
#     644                     ri.set_writeconsole(old_writeconsole)
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/robjects/functions.pyc in __call__(self, *args, **kwargs)
#     168                 v = kwargs.pop(k)
#     169                 kwargs[r_k] = v
# --> 170         return super(SignatureTranslatedFunction, self).__call__(*args, **kwargs)
#     171
#     172 pattern_link = re.compile(r'\\link\{(.+?)\}')
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/robjects/functions.pyc in __call__(self, *args, **kwargs)
#      98         for k, v in kwargs.items():
#      99             new_kwargs[k] = conversion.py2ri(v)
# --> 100         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     101         res = conversion.ri2ro(res)
#     102         return res
#
# RRuntimeError: Error in eval(expr, envir, enclos) : object 'pos' not found

# %%
DFdataUnderCiteRegret  = pd.DataFrame({'GAIN_regret_P1' : x.regret_1[x.treatment_eval_1 == 'cite DataLabour']})
DFdataUnderShareRegret = pd.DataFrame({'LOSS_regret_P1' : x.regret_1[x.treatment_eval_1 == 'Jam Share Data']})

# %%
# %reload_ext writeandexecute
# Out:
# 'writeandexecute' magic loaded.
