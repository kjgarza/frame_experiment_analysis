# %% [markdown]
# # Frame Experiment Between Subject Analysis
#
# <i>Created by Kristian G</i>

# %% [markdown]
# ### Preliminaries

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
from extract_data import datatoFrame
from code_data import *
from ggplot import *
import json
from frame_experiment_table import FrameExperimentTable
# Out:
# (21, 41)
# Fields Excluded
# (49,)
# sessionid
# 88f18269f0d7ff772f8a3f89fc8c81cb                                                asasa
# 88f18269f0d7ff772f8a3f89fc8c81cb    djdjdjdjjdjdjdjdjdjdjdjdjdjdjdjdjdjdjdjdjdjkdk...
# 96d141400e48d48311882f7cde6344fc                                    Political Science
# f14a64d2f8ec48ce4cee9b2982bec68b                                                  NaN
# 58d0e078f29b6a75e930333a851b5cb3                                 Software Development
# 8f3ffab2333bbd52df8bfae3ece74b7a                                                 XXXX
# 9cdbd6ec8df0f2d350c1d5bd74f7ebb0                                           Statistics
# b3b25386946e6bba8a0d267a6b17c819                                                  NaN
# b3b25386946e6bba8a0d267a6b17c819                                                  NaN
# b3b25386946e6bba8a0d267a6b17c819                                                  NaN
# b3b25386946e6bba8a0d267a6b17c819                                                  NaN
# b3b25386946e6bba8a0d267a6b17c819                                                WWWWW
# b3b25386946e6bba8a0d267a6b17c819                                               xxxxxx
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# e57134ffac386481e78550d53e544198                                               azzzzz
# e57134ffac386481e78550d53e544198                                               looooo
# e57134ffac386481e78550d53e544198                                                oolll
# e57134ffac386481e78550d53e544198                                                qqqqq
# Name: discipline, dtype: object
# (65, 43)
# (65, 43)
# (65, 44)
# sasa
# (65, 5)
# (65, 5)
# (124, 5)
# (65, 44)
# sasa
# (65, 6)
# (65, 6)
# (124, 6)
# frame_experiment_table.py:423: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['id']= df.index.values

# %%
# %pylab inline
# %load_ext rmagic
# %load_ext rpy2.ipython
import pylab
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# #Data

# %% [markdown]
# ###Loading

# %%
c = FrameExperimentTable('logs/data_incremental_file')
c.add_records('logs/data_two_records')
c.add_records('logs/scenario_changed')
c.add_records_csv('logs/data_scramble_filled_csv.csv')
master_dataset = c.filter_noise()
c.code_for_stat_ana()
c.code_survey_numeric()
c
# Out:
# (21, 41)
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-35-b35d39031f09> in <module>()
#       1 c = FrameExperimentTable('logs/data_incremental_file')
#       2 c.add_records('logs/data_two_records')
# ----> 3 c.add_records('logs/changed_scenario')
#       4 c.add_records_csv('logs/data_scramble_filled_csv.csv')
#       5 master_dataset = c.filter_noise()
#
# /Users/kristian/PycharmProjects/Frame_experiment_analysis/frame_experiment_table.pyc in add_records(self, source)
#      29         """
#      30         #define method either new or old
# ---> 31         new_data = datatoFrame(source, 'dummy4', 'new')
#      32         pieces = [self.data, new_data]
#      33         self.data = pd.concat(pieces)
#
# /Users/kristian/PycharmProjects/Frame_experiment_analysis/extract_data.pyc in datatoFrame(fn, output, method)
#     306         main(fn, output)
#     307     elif method == 'new':
# --> 308         second_extract(fn, output)
#     309
#     310     # main(fn, output)
#
# /Users/kristian/PycharmProjects/Frame_experiment_analysis/extract_data.pyc in second_extract(fn, output)
#     163     create_1 = []
#     164     create_2 = []
# --> 165     with open(fn) as f:
#     166         for line in f:
#     167             obj = json.loads(line)
#
# IOError: [Errno 2] No such file or directory: 'logs/changed_scenario'

# %% [markdown]
# ###Filtering

# %%
master_dataset = master_dataset.replace(['stackeholders'],['stakeholders'])
df_filtered = master_dataset
master_dataset.shape
# df_filtered = master_dataset[master_dataset['honest'] == 'on']
# Out:
# (30, 43)

# %%
# d = c.code_survey_numeric()
d = c.get_plotdata()
pd.DataFrame.to_csv(d,'frame_exp_mondrian.csv')

# %%
# %%R -i d
# df<- data.frame(d)
#
# saveRDS(df, "frame_exp.rds")
# save(df, file = "frame_exp.rda")
# write.table(df,"~/PycharmProjects/MondrianTmpImport.txt",quote=FALSE,sep="\t",row.names = FALSE)

# %%
df = c.get_plotdata()

# %% [markdown]
# ##Between subjects Comparison Period 1 EF (Emphasis Frame)

# %%
DFdataUnderCiteMeasure  = pd.DataFrame({'GAIN_P1' : df.with_who_1[df.treatment_eval_1 == 'cite DataLabour']})
DFdataUnderShareMeasure = pd.DataFrame({'LOSS_P1' : df.with_who_1[df.treatment_eval_1 == 'Jam Share Data']})
# DFdataUnderCiteMeasure = DFdataUnderCiteMeasure[DFdataUnderCiteMeasure.GAIN_P1 != 'private']
# DFdataUnderCiteMeasure

# %%
# %%R -i DFdataUnderCiteMeasure -i DFdataUnderShareMeasure
# source("stacked_bars.R")
# graph_with_who(DFdataUnderCiteMeasure, DFdataUnderShareMeasure)
# Out:
# Loading required package: likert
# Loading required package: ggplot2
# Loading required package: xtable
# Loading required package: reshape
#
# Attaching package: ‘plyr’
#
# The following objects are masked from ‘package:reshape’:
#
#     rename, round_any

# %% [markdown]
# ##Between Subject Analysis  Period 1 EF

# %% [markdown]
# #### Wilcox Comparison during Period 1

# %%
# c.code_for_stat_ana()
c
# Out:
# <frame_experiment_table.FrameExperimentTable instance at 0x10be43d40>

# %%
dd =  c.get_between_subject_dataframe(1)

# remove the large data set
# dd.loc[1, "t"] = 0
dd = dd
dd
# Out:
# (30, 43)
#    c   t
# 1  0   2
# 2  2   2
# 3  3   1
# 4  7  13

# %%
# %%R -i dd
# library(MASS)
# print(summary(dd))
#
#
# library(coin)
#
# z<-wilcoxsign_test(t ~ c, data = dd, distribution="exact")
# print(z)
# print(0.74/sqrt(15))
#
# print(chisq.test(dd))
# #print(assocstats(dd))
# wilcox.test(dd$t,dd$c, paired=F, conf.int = TRUE, alternative = "g")
# Out:
#        c             t
#  Min.   :0.0   Min.   : 1.00
#  1st Qu.:1.5   1st Qu.: 1.75
#  Median :2.5   Median : 2.00
#  Mean   :3.0   Mean   : 4.50
#  3rd Qu.:4.0   3rd Qu.: 4.75
#  Max.   :7.0   Max.   :13.00
# Loading required package: survival
# Loading required package: splines
#
# 	Exact Wilcoxon-Signed-Rank Test (zeros handled a la Pratt)
#
# data:  y by x (neg, pos)
# 	 stratified by block
# Z = 0.7493, p-value = 0.75
# alternative hypothesis: true mu is not equal to 0
#
# [1] 0.1910672
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 3.75, df = 3, p-value = 0.2898
#
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  dd$t and dd$c
# W = 8, p-value = 0.5588
# alternative hypothesis: true location shift is greater than 0
# 95 percent confidence interval:
#  -5.000038       Inf
# sample estimates:
# difference in location
#           2.543132e-05

# %% [markdown]
# #### Comaprison using Logistic Regression (odds Ratio) EF P1

# %%
df = c.get_rm_ws_dataframe()
sd = df
df = df[df['period'] == '1']
df
# Out:
# (30, 45)
# sasa
# (27, 5)
# (23, 5)
# (44, 5)
#     response trt sequ period                                id
# 2          4   A   AB      1  0edc7c52e0ccb1714e9a39ea75af43fe
# 4          4   A   AB      1  3cff31dfa808cff92541784186c8243a
# 5          1   A   AB      1  43f10113e67dff73361c235ee10bd14b
# 8          4   A   AB      1  6481c74f482bb574529fcfe12f7247c2
# 9          4   A   AB      1  85d35a71ea3dbd9e452e4c9a0b83016b
# 15         3   A   AB      1  c2026cc168583afd72bbfbb284c0f1e9
# 16         1   A   AB      1  9f739b36a1f91569017b5ab36be07f7f
# 18         4   A   AB      1  2916e59453604e0bf19d4b3b60b75fdd
# 19         4   A   AB      1  28d0f45805f4a2e9ec4d8fe4cf2e517e
# 20         2   A   AB      1  8ed6774338c3fee17bbdca2dfbc7f1d6
# 21         4   A   AB      1  f1deeddb2588e790d7425adfa7ffb307
# 22         4   A   AB      1  d1cf1e2bd3e41f2bd3576a32593e2f73
# 0          4   B   BA      1  03ebd33fe07a1226f3b98aa8aa13e76e
# 3          2   B   BA      1  358e6df6c02309c57fd05b27540fb8e8
# 6          4   B   BA      1  4daf9ac2c73522a2339d564abc33f2d4
# 7          3   B   BA      1  62d5d75aa5c5c673ff839565556057cd
# 10         3   B   BA      1  86ed6760b4a6fc54cff9850e090c7b5f
# 11         3   B   BA      1  9bdb3c0e8ae917d2fe5dc746a4fe24c6
# 12         4   B   BA      1  b540afa5300616f5a6ed80106fb6b20e
# 13         4   B   BA      1  e9e357d280b62fde1f5c9b718ee3ea36
# 14         4   B   BA      1  68ec3fb55059c118977c24cbd4fca91c
# 17         4   B   BA      1  66f12cf71b45603b5b5bded2142fb89c

# %%
# %%R -i df
# library(MASS)
# df$response <- as.factor(df$response)
# r <- polr(response ~ trt, df, Hess=TRUE)
# print(summary(r))
# exp(cbind(OR= coef(r), confint(r)))
# Out:
# Call:
# polr(formula = response ~ trt, data = df, Hess = TRUE)
#
# Coefficients:
#        Value Std. Error t value
# trtB 0.06767     0.8627 0.07844
#
# Intercepts:
#     Value   Std. Error t value
# 1|2 -2.2693  0.8527    -2.6615
# 2|3 -1.4689  0.7096    -2.0701
# 3|4 -0.5252  0.6218    -0.8446
#
# Residual Deviance: 45.47058
# AIC: 53.47058
# Waiting for profiling to be done...
#              OR
# 2.5 %  1.070016 0.1907324
# 97.5 % 1.070016 6.0176630

# %% [markdown]
# ###Comparing sequence (P1 vs P2) in repeated experiment EF

# %%
sd  = sd.sort(columns=['id','period','trt'])
sd
# Out:
#     response trt sequ period                                id
# 0          4   B   BA      1  03ebd33fe07a1226f3b98aa8aa13e76e
# 23         4   A   BA      2  03ebd33fe07a1226f3b98aa8aa13e76e
# 2          4   A   AB      1  0edc7c52e0ccb1714e9a39ea75af43fe
# 25         4   B   AB      2  0edc7c52e0ccb1714e9a39ea75af43fe
# 19         4   A   AB      1  28d0f45805f4a2e9ec4d8fe4cf2e517e
# 42         4   B   AB      2  28d0f45805f4a2e9ec4d8fe4cf2e517e
# 18         4   A   AB      1  2916e59453604e0bf19d4b3b60b75fdd
# 41         4   B   AB      2  2916e59453604e0bf19d4b3b60b75fdd
# 3          2   B   BA      1  358e6df6c02309c57fd05b27540fb8e8
# 26         4   A   BA      2  358e6df6c02309c57fd05b27540fb8e8
# 4          4   A   AB      1  3cff31dfa808cff92541784186c8243a
# 27         4   B   AB      2  3cff31dfa808cff92541784186c8243a
# 5          1   A   AB      1  43f10113e67dff73361c235ee10bd14b
# 28         2   B   AB      2  43f10113e67dff73361c235ee10bd14b
# 6          4   B   BA      1  4daf9ac2c73522a2339d564abc33f2d4
# 29         4   A   BA      2  4daf9ac2c73522a2339d564abc33f2d4
# 7          3   B   BA      1  62d5d75aa5c5c673ff839565556057cd
# 30         4   A   BA      2  62d5d75aa5c5c673ff839565556057cd
# 8          4   A   AB      1  6481c74f482bb574529fcfe12f7247c2
# 31         4   B   AB      2  6481c74f482bb574529fcfe12f7247c2
# 17         4   B   BA      1  66f12cf71b45603b5b5bded2142fb89c
# 40         4   A   BA      2  66f12cf71b45603b5b5bded2142fb89c
# 14         4   B   BA      1  68ec3fb55059c118977c24cbd4fca91c
# 37         4   A   BA      2  68ec3fb55059c118977c24cbd4fca91c
# 9          4   A   AB      1  85d35a71ea3dbd9e452e4c9a0b83016b
# 32         4   B   AB      2  85d35a71ea3dbd9e452e4c9a0b83016b
# 10         3   B   BA      1  86ed6760b4a6fc54cff9850e090c7b5f
# 33         3   A   BA      2  86ed6760b4a6fc54cff9850e090c7b5f
# 20         2   A   AB      1  8ed6774338c3fee17bbdca2dfbc7f1d6
# 43         2   B   AB      2  8ed6774338c3fee17bbdca2dfbc7f1d6
# 11         3   B   BA      1  9bdb3c0e8ae917d2fe5dc746a4fe24c6
# 34         4   A   BA      2  9bdb3c0e8ae917d2fe5dc746a4fe24c6
# 16         1   A   AB      1  9f739b36a1f91569017b5ab36be07f7f
# 39         1   B   AB      2  9f739b36a1f91569017b5ab36be07f7f
# 12         4   B   BA      1  b540afa5300616f5a6ed80106fb6b20e
# 35         3   A   BA      2  b540afa5300616f5a6ed80106fb6b20e
# 15         3   A   AB      1  c2026cc168583afd72bbfbb284c0f1e9
# 38         4   B   AB      2  c2026cc168583afd72bbfbb284c0f1e9
# 22         4   A   AB      1  d1cf1e2bd3e41f2bd3576a32593e2f73
# 45         4   B   AB      2  d1cf1e2bd3e41f2bd3576a32593e2f73
# 13         4   B   BA      1  e9e357d280b62fde1f5c9b718ee3ea36
# 36         4   A   BA      2  e9e357d280b62fde1f5c9b718ee3ea36
# 21         4   A   AB      1  f1deeddb2588e790d7425adfa7ffb307
# 44         4   B   AB      2  f1deeddb2588e790d7425adfa7ffb307

# %%
# %%R -i sd
# library(MASS)
# library(repolr)
# df<-sd
# df$response <- as.factor(df$response)
# df$sequ <- as.factor(df$sequ)
# df$period <- as.factor(df$period)
#
#
# fitted.mod <- repolr(formula=response~sequ*period, subjects="id",
# data=sd, categories=4, times=c(1,2), corstr="uniform",  alpha=0.5, po.test=TRUE, fixed=FALSE)
# summary(fitted.mod[["gee"]])
# Out:
# Loading required package: gee
#  working correlation model:  uniform
# Beginning Cgee S-function, @(#) geeformula.q 4.13 98/01/27
# running glm to get initial regression estimate
# factor(cuts)1 factor(cuts)2 factor(cuts)3          sequ        period
#    -1.9798712    -1.0097226    -0.1797988     0.1743756     0.3757160
#   sequ:period
#    -0.7256750
# Beginning Cgee S-function, @(#) geeformula.q 4.13 98/01/27
# user's initial regression estimate
#            [,1]
# [1,] -1.9798712
# [2,] -1.0097226
# [3,] -0.1797988
# [4,]  0.1743756
# [5,]  0.3757160
# [6,] -0.7256750
# Beginning Cgee S-function, @(#) geeformula.q 4.13 98/01/27
# user's initial regression estimate
#            [,1]
# [1,] -2.5241446
# [2,] -1.5571545
# [3,] -0.7401644
# [4,]  0.5586680
# [5,]  0.2250119
# [6,] -0.5963781
# Beginning Cgee S-function, @(#) geeformula.q 4.13 98/01/27
# user's initial regression estimate
#            [,1]
# [1,] -2.5209207
# [2,] -1.5546997
# [3,] -0.7377724
# [4,]  0.5566558
# [5,]  0.2169616
# [6,] -0.5905256
# Beginning Cgee S-function, @(#) geeformula.q 4.13 98/01/27
# user's initial regression estimate
#            [,1]
# [1,] -2.4847338
# [2,] -1.5195681
# [3,] -0.7042090
# [4,]  0.5305189
# [5,]  0.1943440
# [6,] -0.5724994
# Beginning Cgee S-function, @(#) geeformula.q 4.13 98/01/27
# user's initial regression estimate
#            [,1]
# [1,] -2.4577866
# [2,] -1.4930684
# [3,] -0.6786700
# [4,]  0.5105507
# [5,]  0.1763133
# [6,] -0.5582260
# Beginning Cgee S-function, @(#) geeformula.q 4.13 98/01/27
# user's initial regression estimate
#            [,1]
# [1,] -2.4411842
# [2,] -1.4766228
# [3,] -0.6627445
# [4,]  0.4981613
# [5,]  0.1650525
# [6,] -0.5493750
# Beginning Cgee S-function, @(#) geeformula.q 4.13 98/01/27
# user's initial regression estimate
#            [,1]
# [1,] -2.4336658
# [2,] -1.4691522
# [3,] -0.6554948
# [4,]  0.4925420
# [5,]  0.1598800
# [6,] -0.5453309
# Beginning Cgee S-function, @(#) geeformula.q 4.13 98/01/27
# user's initial regression estimate
#            [,1]
# [1,] -2.4309783
# [2,] -1.4664839
# [3,] -0.6529026
# [4,]  0.4905320
# [5,]  0.1580215
# [6,] -0.5438805
# Beginning Cgee S-function, @(#) geeformula.q 4.13 98/01/27
# user's initial regression estimate
#            [,1]
# [1,] -2.4299926
# [2,] -1.4655025
# [3,] -0.6519490
# [4,]  0.4897976
# [5,]  0.1573346
# [6,] -0.5433469
#
#  REPOLR: 2013-03-20 version 2.0
#  Working correlation model:  uniform
#  Convergence monitor
#
#     iter 	     crit 	    alpha 	    grad1 	    grad2
#        1 	  0.04599 	  0.48442 	  0.00655 	  0.10503
#        2 	  0.00953 	  0.38366 	  0.08203 	  0.19924
#        3 	  0.04761 	  0.31242 	  0.02712 	  0.08617
#        4 	  0.03932 	  0.27161 	  0.00860 	  0.04352
#        5 	  0.02540 	  0.25392 	  0.00253 	  0.02773
#        6 	  0.01178 	  0.24765 	  0.00075 	  0.02242
#        7 	  0.00424 	  0.24543 	  0.00025 	  0.02075
#        8 	  0.00157 	  0.24469 	  0.00008 	  0.02018
#        9 	  0.00053 	  0.24442 	  0.00003 	  0.02000
#
#  Score test =  6.773 : d.f.  6  and p-value  0.342
#  Correlation parameter: 0.244
#
#  GEE:  GENERALIZED LINEAR MODELS FOR DEPENDENT DATA
#  gee S-function, version 4.13 modified 98/01/27 (1998)
#
# Model:
#  Link:                      Logit
#  Variance to Mean Relation: Binomial
#  Correlation Structure:     Fixed
#
# Call:
# gee(formula = formula, id = exdata$exdata$subjects, data = exdata$exdata,
#     R = R_mat, b = as.numeric(coeffs), maxiter = 10, family = "binomial",
#     corstr = "fixed", silent = TRUE, scale.fix = TRUE, scale.value = scalevalue)
#
# Summary of Residuals:
#         Min          1Q      Median          3Q         Max
# -0.36629570 -0.19539914 -0.08897828 -0.05550699  0.93774500
#
#
# Coefficients:
#                 Estimate Naive S.E.     Naive z Robust S.E.   Robust z
# factor(cuts)1 -2.4296602   2.770578 -0.87695066   2.1154286 -1.1485427
# factor(cuts)2 -1.4651714   2.730919 -0.53651228   1.9527859 -0.7502980
# factor(cuts)3 -0.6516272   2.720108 -0.23955935   1.9023601 -0.3425362
# sequ           0.4895504   1.791786  0.27321924   1.4978559  0.3268341
# period         0.1571019   1.750354  0.08975437   1.0937729  0.1436330
# sequ:period   -0.5431666   1.179367 -0.46055757   0.9705144 -0.5596688
#
# Estimated Scale Parameter:  1
# Number of Iterations:  2
#
# Working Correlation
# NULL

# %%
# %%R -i df
# library(MASS)
# df$response <- as.factor(df$response)
# r <- polr(response ~ trt + man_hours , df, Hess=TRUE)
# print(summary(r))
# exp(cbind(OR= coef(r), confint(r)))
# Out:
# Error in eval(expr, envir, enclos) : object 'man_hours' not found
# In addition: Warning messages:
# 1: In wilcoxsign_test.IndependenceProblem(object = <S4 object of class "IndependenceProblem">,  :
#   Handling of zeros defaults to ‘Pratt’ in newer versions of coin
# 2: In chisq.test(dd) : Chi-squared approximation may be incorrect
# 3: In wilcox.test.default(dd$t, dd$c, paired = F, conf.int = TRUE,  :
#   cannot compute exact p-value with ties
# 4: In wilcox.test.default(dd$t, dd$c, paired = F, conf.int = TRUE,  :
#   cannot compute exact confidence intervals with ties
# Error in eval(expr, envir, enclos) : object 'man_hours' not found

# %% [markdown]
# #### We Analysed Regret differences EF for P1

# %%
df = c.get_plotdata()
DFdataUnderCiteRegret  = pd.DataFrame({'GAIN_regret_P1' : df.regret_1[df.treatment_eval_1 == 'cite DataLabour']})
DFdataUnderShareRegret = pd.DataFrame({'LOSS_regret_P1' : df.regret_1[df.treatment_eval_1 == 'Jam Share Data']})

# %%
# %%R -i DFdataUnderCiteRegret -i DFdataUnderShareRegret
# graph_linkert(DFdataUnderCiteRegret, DFdataUnderShareRegret)

# %%
def add_seq2(row):
    r_1=''
    if row['treatment_eval_1'] == 'A':
        r_1 = 'AB'
    if row['treatment_eval_1'] == 'B':
        r_1 = 'BA'
    return r_1


df = c.get_anadata()

df['id']= df.index.values
df['seq'] = df.apply(lambda row: add_seq2(row), axis=1)


df_wx = df[['regret_1','regret_2','seq','id']]
df_fwx = pd.melt(df_wx, id_vars=['seq','id'])
df_fwx  = df_fwx.sort(columns=['seq','variable','id'])


df_fwxAB = df_fwx[(df_fwx['seq'] == 'AB') & (df_fwx['variable'] == 'regret_1')]
df_fwxBA = df_fwx[(df_fwx['seq'] == 'BA') & (df_fwx['variable'] == 'regret_1')]
# w_toSas = df_fwx[df_fwx['variable'] == 'with_who_1']

t = df_fwxAB['value'].value_counts()
co = df_fwxBA['value'].value_counts()
dd = pd.DataFrame({'t' : t, 'c':co}).fillna(0)
dd = dd

# %%
# %%R -i dd
# library(MASS)
# print(summary(dd))
# print(chisq.test(dd))
# #print(assocstats(dd))
# wilcox.test(dd$t,dd$co, paired=F, conf.int = TRUE)
# Out:
#        c              t
#  Min.   :0.00   Min.   :1.00
#  1st Qu.:0.75   1st Qu.:1.75
#  Median :1.50   Median :4.50
#  Mean   :3.00   Mean   :4.25
#  3rd Qu.:3.75   3rd Qu.:7.00
#  Max.   :9.00   Max.   :7.00
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 3.6062, df = 3, p-value = 0.3072
#
#
# 	Wilcoxon signed rank test with continuity correction
#
# data:  dd$t
# V = 10, p-value = 0.09751
# alternative hypothesis: true location is not equal to 0
# 60 percent confidence interval:
#  1.999995 7.000000
# sample estimates:
# (pseudo)median
#       4.293837

# %% [markdown]
# ##Between Subject Analysis  Period 2 EF

# %%
dd =  c.get_between_subject_dataframe(2)

dd = dd+50
dd
# Out:
# (30, 45)
#     c   t
# 1  51  51
# 2  50  53
# 3  52  50
# 4  59  61

# %%
# %%R -i dd
# library(MASS)
# print(summary(dd))
# print(chisq.test(dd))
# #print(assocstats(dd))
# wilcox.test(dd$t,dd$c, paired=F, conf.int = TRUE,  alternative = "g")
# Out:
#        c               t
#  Min.   :50.00   Min.   :50.00
#  1st Qu.:50.75   1st Qu.:50.75
#  Median :51.50   Median :52.00
#  Mean   :53.00   Mean   :53.75
#  3rd Qu.:53.75   3rd Qu.:55.00
#  Max.   :59.00   Max.   :61.00
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 0.1389, df = 3, p-value = 0.9868
#
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  dd$t and dd$c
# W = 9, p-value = 0.4419
# alternative hypothesis: true location shift is greater than 0
# 95 percent confidence interval:
#  -7.999919       Inf
# sample estimates:
# difference in location
#              0.5409952

# %% [markdown]
# ## Test all the interactions using Wilcox
#
#
# For this design the main comparison is the first interaction Treatment vs Control. All the others interactions are controls to see there is not bias.
# T1 = T2
# C1 = C2
#
#
# The difference between T and C must be very similar
# T1-C1 = T1-C2 = C1-T2 = C2-T2

# %% [markdown]
# ##Checking for SCC (Structural complex choice)
#
# The  has to be between subjects and assuming to carry over or sequence effects.
# Because Not all the subjects took it and those that did not do it consistently

# %%
fc = FrameExperimentTable('logs/data_incremental_file')
# fc = FrameExperimentTable('logs/data_scenario_changed')
fc.add_records('logs/data_scenario_changed')
fc.add_records('logs/data_two_records')
fc.add_records_csv('logs/data_scramble_filled_csv.csv')
fc.filter_noise()
fc.code_for_stat_ana()
fc.code_survey_numeric()
# Out:
# (21, 41)
# Fields Excluded
# (49,)
# sessionid
# 88f18269f0d7ff772f8a3f89fc8c81cb                                                asasa
# 88f18269f0d7ff772f8a3f89fc8c81cb    djdjdjdjjdjdjdjdjdjdjdjdjdjdjdjdjdjdjdjdjdjkdk...
# 96d141400e48d48311882f7cde6344fc                                    Political Science
# f14a64d2f8ec48ce4cee9b2982bec68b                                                  NaN
# 58d0e078f29b6a75e930333a851b5cb3                                 Software Development
# 8f3ffab2333bbd52df8bfae3ece74b7a                                                 XXXX
# 9cdbd6ec8df0f2d350c1d5bd74f7ebb0                                           Statistics
# b3b25386946e6bba8a0d267a6b17c819                                                  NaN
# b3b25386946e6bba8a0d267a6b17c819                                                  NaN
# b3b25386946e6bba8a0d267a6b17c819                                                  NaN
# b3b25386946e6bba8a0d267a6b17c819                                                  NaN
# b3b25386946e6bba8a0d267a6b17c819                                                WWWWW
# b3b25386946e6bba8a0d267a6b17c819                                               xxxxxx
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# e57134ffac386481e78550d53e544198                                               azzzzz
# e57134ffac386481e78550d53e544198                                               looooo
# e57134ffac386481e78550d53e544198                                                oolll
# e57134ffac386481e78550d53e544198                                                qqqqq
# Name: discipline, dtype: object
# (77, 43)
#                                   academic     awareness  \
# sessionid
# 03ebd33fe07a1226f3b98aa8aa13e76e         1        [u'4']
# 03ebd33fe07a1226f3b98aa8aa13e76e         1        [u'4']
# 0edc7c52e0ccb1714e9a39ea75af43fe         1        [u'3']
# 358e6df6c02309c57fd05b27540fb8e8         1        [u'3']
# 3cff31dfa808cff92541784186c8243a         1  [u'1', u'2']
# 43f10113e67dff73361c235ee10bd14b         1        [u'4']
# 4daf9ac2c73522a2339d564abc33f2d4         1        [u'3']
# 62d5d75aa5c5c673ff839565556057cd         1        [u'3']
# 6481c74f482bb574529fcfe12f7247c2         2        [u'3']
# 85d35a71ea3dbd9e452e4c9a0b83016b         1        [u'3']
# 86ed6760b4a6fc54cff9850e090c7b5f         1        [u'1']
# 9bdb3c0e8ae917d2fe5dc746a4fe24c6         1        [u'3']
# b540afa5300616f5a6ed80106fb6b20e         1  [u'2', u'3']
# e9e357d280b62fde1f5c9b718ee3ea36         1        [u'3']
# 0687ef14d441706b211ff0edf9f2ebea         2        [u'3']
# 0ddaf25718c6b4c35bf05ae6335150d4         1        [u'3']
# 18da94199bf2471a70d0298958543bb4         1        [u'3']
# 23ba4e6b2b149ba6294bd7e0125b2948         1        [u'4']
# 2bd5b76b8fac74b062c1a99c9bbc0a75         1        [u'2']
# 2be130732b05502a4a631bc01291b25b         1        [u'3']
# 38c7d17c9d41c293afe9d368d45a629c         1        [u'3']
# 3ea2814b0443687ea2400e6c1726d7ab         1        [u'4']
# 4306bad121fb3ad1fb2365dda1a32440         1        [u'4']
# 4d9db524466a6d05f29fb721f842de77         1        [u'3']
# 52d3867f738f6cff74269cf62e3b7251         1        [u'1']
# 5b114f95a429eb982fc0b378c64a23f9         1        [u'3']
# 690e88138d83a8ec5fea4230b364aae0         1        [u'3']
# 6b216d7a04c90e3490fb335b6dc39314         1        [u'4']
# 6fd7664989b2b16f85c63169595bb66e         1           NaN
# 78764885189f4abe3a13ee47ebe3d1fa         1        [u'3']
# ...                                    ...           ...
# b57ae216d47820a5a597768ddc48fdca         1        [u'4']
# c0ba478916443e75928dc18d1bc8e468         1        [u'1']
# c122797a0a6e34e5c7159bb839ab9cec         1        [u'3']
# c424cb968746b9c146cfda7af86bd46f         1        [u'3']
# c4855b2635f52a5f8f10a13348b2e688         1        [u'3']
# c4af4b34d71a116d49cfd1bbc37115dc         2        [u'3']
# ce4dd38c1a2b00597a5937d82828d532         2        [u'3']
# d05374703295171ee7746105b806e10b         1        [u'3']
# d88bf82976822f5950e5bc4cf56e700a         1        [u'3']
# dce82b0bd1c889c42227c7290aa6cec0         1        [u'3']
# ed4707fdbf643cdb6651a9d7807d8048         2        [u'3']
# f3906c5106e79f3165050a0fcbbf4cc3         1        [u'3']
# fa251851931ddd1b63a9d66bd90ca95c         1        [u'3']
# fc5bb1982077af9dd12aa7de0a5660c3         1        [u'3']
# 68ec3fb55059c118977c24cbd4fca91c         1        [u'3']
# c2026cc168583afd72bbfbb284c0f1e9         1        [u'1']
# 9f739b36a1f91569017b5ab36be07f7f         1  [u'1', u'3']
# 66f12cf71b45603b5b5bded2142fb89c         1        [u'3']
# b4bd8ddfbcf302338f7898eec8382690         1         ["3"]
# 90c08c4bb24fd7715f6dce58d09061f4         1         ["1"]
# 2916e59453604e0bf19d4b3b60b75fdd         1         ["3"]
# 28d0f45805f4a2e9ec4d8fe4cf2e517e         2         ["3"]
# 0ad6197707803a31a98aa69dccc39bad         1         ["1"]
# d8695dead80bb8f3ba0caa25e5ca785c         2         ["3"]
# 4379192aef2087ff9a349056bcbb6bb4         1         ["3"]
# 8ed6774338c3fee17bbdca2dfbc7f1d6         2         ["3"]
# f1deeddb2588e790d7425adfa7ffb307         1         ["3"]
# a3fb71f8688c810c126ede0a989b79cc         1         ["4"]
# d1cf1e2bd3e41f2bd3576a32593e2f73         1         ["3"]
# 15977d31cfde3f67cdf3ca9e9f8995a0         1           NaN
#
#                                                       data_file_title_1  \
# sessionid
# 03ebd33fe07a1226f3b98aa8aa13e76e                             My dataset
# 03ebd33fe07a1226f3b98aa8aa13e76e                      Fictional dataset
# 0edc7c52e0ccb1714e9a39ea75af43fe                      Fictional dataset
# 358e6df6c02309c57fd05b27540fb8e8           Some really really cool data
# 3cff31dfa808cff92541784186c8243a                 My Data Set To Publish
# 43f10113e67dff73361c235ee10bd14b                                   test
# 4daf9ac2c73522a2339d564abc33f2d4                              mydataset
# 62d5d75aa5c5c673ff839565556057cd  Triglyceride Profiles (FED, FAS, HFD)
# 6481c74f482bb574529fcfe12f7247c2                                Fiction
# 85d35a71ea3dbd9e452e4c9a0b83016b                             My dataset
# 86ed6760b4a6fc54cff9850e090c7b5f                         Fictional Data
# 9bdb3c0e8ae917d2fe5dc746a4fe24c6                                   Test
# b540afa5300616f5a6ed80106fb6b20e             results from DFKZ analysis
# e9e357d280b62fde1f5c9b718ee3ea36                              Mydataset
# 0687ef14d441706b211ff0edf9f2ebea                            mydata-test
# 0ddaf25718c6b4c35bf05ae6335150d4                2D PMF in NaH exchanger
# 18da94199bf2471a70d0298958543bb4                            My data set
# 23ba4e6b2b149ba6294bd7e0125b2948                            My new data
# 2bd5b76b8fac74b062c1a99c9bbc0a75                   Dataset from paper X
# 2be130732b05502a4a631bc01291b25b                        My New Datafile
# 38c7d17c9d41c293afe9d368d45a629c      Quantifications of project XXLLPP
# 3ea2814b0443687ea2400e6c1726d7ab                                 mydata
# 4306bad121fb3ad1fb2365dda1a32440                                    Foo
# 4d9db524466a6d05f29fb721f842de77                              mydataset
# 52d3867f738f6cff74269cf62e3b7251                              Mydataset
# 5b114f95a429eb982fc0b378c64a23f9     DraperA_etal_Nature_2015_SupplMat1
# 690e88138d83a8ec5fea4230b364aae0                          crzy-biostuff
# 6b216d7a04c90e3490fb335b6dc39314                              test data
# 6fd7664989b2b16f85c63169595bb66e                             My dataset
# 78764885189f4abe3a13ee47ebe3d1fa                      Fisher_et_al_2015
# ...                                                                 ...
# b57ae216d47820a5a597768ddc48fdca                  Helping with a Thesis
# c0ba478916443e75928dc18d1bc8e468                                    bla
# c122797a0a6e34e5c7159bb839ab9cec                              mydataset
# c424cb968746b9c146cfda7af86bd46f             My very important data set
# c4855b2635f52a5f8f10a13348b2e688                             My dataset
# c4af4b34d71a116d49cfd1bbc37115dc                              Mydataset
# ce4dd38c1a2b00597a5937d82828d532                                My Data
# d05374703295171ee7746105b806e10b                              mydataset
# d88bf82976822f5950e5bc4cf56e700a                             My dataset
# dce82b0bd1c889c42227c7290aa6cec0                             My dataset
# ed4707fdbf643cdb6651a9d7807d8048                                My data
# f3906c5106e79f3165050a0fcbbf4cc3                             my dataset
# fa251851931ddd1b63a9d66bd90ca95c                             My dataset
# fc5bb1982077af9dd12aa7de0a5660c3                   Glucose Growth Model
# 68ec3fb55059c118977c24cbd4fca91c                             My DATASET
# c2026cc168583afd72bbfbb284c0f1e9                                   Test
# 9f739b36a1f91569017b5ab36be07f7f                     My lipidomics data
# 66f12cf71b45603b5b5bded2142fb89c                              mydataset
# b4bd8ddfbcf302338f7898eec8382690                                    NaN
# 90c08c4bb24fd7715f6dce58d09061f4                                    NaN
# 2916e59453604e0bf19d4b3b60b75fdd                                    NaN
# 28d0f45805f4a2e9ec4d8fe4cf2e517e                                    NaN
# 0ad6197707803a31a98aa69dccc39bad                                    NaN
# d8695dead80bb8f3ba0caa25e5ca785c                                    NaN
# 4379192aef2087ff9a349056bcbb6bb4                                    NaN
# 8ed6774338c3fee17bbdca2dfbc7f1d6                                    NaN
# f1deeddb2588e790d7425adfa7ffb307                                    NaN
# a3fb71f8688c810c126ede0a989b79cc                                    NaN
# d1cf1e2bd3e41f2bd3576a32593e2f73                                    NaN
# 15977d31cfde3f67cdf3ca9e9f8995a0                                    NaN
#
#                                                                   data_file_title_2  \
# sessionid
# 03ebd33fe07a1226f3b98aa8aa13e76e                                  Fictional dataset
# 03ebd33fe07a1226f3b98aa8aa13e76e                                  Fictional dataset
# 0edc7c52e0ccb1714e9a39ea75af43fe                           Sample fictional dataset
# 358e6df6c02309c57fd05b27540fb8e8                           Some even more cool data
# 3cff31dfa808cff92541784186c8243a                             My Data Set to publish
# 43f10113e67dff73361c235ee10bd14b                                            bla bla
# 4daf9ac2c73522a2339d564abc33f2d4                                          mydataset
# 62d5d75aa5c5c673ff839565556057cd                                        TG profiles
# 6481c74f482bb574529fcfe12f7247c2                                            fiction
# 85d35a71ea3dbd9e452e4c9a0b83016b                                     My new dataset
# 86ed6760b4a6fc54cff9850e090c7b5f                                      fictious data
# 9bdb3c0e8ae917d2fe5dc746a4fe24c6                                               test
# b540afa5300616f5a6ed80106fb6b20e                                  Fictional results
# e9e357d280b62fde1f5c9b718ee3ea36                                          Mydataset
# 0687ef14d441706b211ff0edf9f2ebea                                        mydata test
# 0ddaf25718c6b4c35bf05ae6335150d4                               2D PMF NaH exchanger
# 18da94199bf2471a70d0298958543bb4                                        My data set
# 23ba4e6b2b149ba6294bd7e0125b2948                                          more data
# 2bd5b76b8fac74b062c1a99c9bbc0a75                                Dataset for paper X
# 2be130732b05502a4a631bc01291b25b                                My cool new Dataset
# 38c7d17c9d41c293afe9d368d45a629c  Sodium concentrations in patients and controls...
# 3ea2814b0443687ea2400e6c1726d7ab                                             mydate
# 4306bad121fb3ad1fb2365dda1a32440                                                Foo
# 4d9db524466a6d05f29fb721f842de77                                        mydataset-1
# 52d3867f738f6cff74269cf62e3b7251                                            mydata2
# 5b114f95a429eb982fc0b378c64a23f9                 DraperA_etal_2015_Nature_SupplMat1
# 690e88138d83a8ec5fea4230b364aae0                                         crzy-stuff
# 6b216d7a04c90e3490fb335b6dc39314                                          cite test
# 6fd7664989b2b16f85c63169595bb66e                                         My dataset
# 78764885189f4abe3a13ee47ebe3d1fa                               Draper et al dataset
# ...                                                                             ...
# b57ae216d47820a5a597768ddc48fdca                              Helping with a Thesis
# c0ba478916443e75928dc18d1bc8e468                                           new data
# c122797a0a6e34e5c7159bb839ab9cec                                             Mydata
# c424cb968746b9c146cfda7af86bd46f                                  My important data
# c4855b2635f52a5f8f10a13348b2e688                                               Data
# c4af4b34d71a116d49cfd1bbc37115dc                                        My data set
# ce4dd38c1a2b00597a5937d82828d532                                                AXC
# d05374703295171ee7746105b806e10b                                               data
# d88bf82976822f5950e5bc4cf56e700a                                         My dataset
# dce82b0bd1c889c42227c7290aa6cec0                                      new test data
# ed4707fdbf643cdb6651a9d7807d8048                                             Test 2
# f3906c5106e79f3165050a0fcbbf4cc3                                         my dataset
# fa251851931ddd1b63a9d66bd90ca95c                                     My dataset (1)
# fc5bb1982077af9dd12aa7de0a5660c3          Growth Experiments of different C-Sources
# 68ec3fb55059c118977c24cbd4fca91c                                        my datatset
# c2026cc168583afd72bbfbb284c0f1e9                                              test2
# 9f739b36a1f91569017b5ab36be07f7f                                 My lipidomics data
# 66f12cf71b45603b5b5bded2142fb89c                                          mydataset
# b4bd8ddfbcf302338f7898eec8382690                                                NaN
# 90c08c4bb24fd7715f6dce58d09061f4                                                NaN
# 2916e59453604e0bf19d4b3b60b75fdd                                                NaN
# 28d0f45805f4a2e9ec4d8fe4cf2e517e                                                NaN
# 0ad6197707803a31a98aa69dccc39bad                                                NaN
# d8695dead80bb8f3ba0caa25e5ca785c                                                NaN
# 4379192aef2087ff9a349056bcbb6bb4                                                NaN
# 8ed6774338c3fee17bbdca2dfbc7f1d6                                                NaN
# f1deeddb2588e790d7425adfa7ffb307                                                NaN
# a3fb71f8688c810c126ede0a989b79cc                                                NaN
# d1cf1e2bd3e41f2bd3576a32593e2f73                                                NaN
# 15977d31cfde3f67cdf3ca9e9f8995a0                                                NaN
#
#                                                                 discipline  \
# sessionid
# 03ebd33fe07a1226f3b98aa8aa13e76e                            bioinformatics
# 03ebd33fe07a1226f3b98aa8aa13e76e                            bioinformatics
# 0edc7c52e0ccb1714e9a39ea75af43fe                              microbiology
# 358e6df6c02309c57fd05b27540fb8e8                           comp physiology
# 3cff31dfa808cff92541784186c8243a                     chemistry and biology
# 43f10113e67dff73361c235ee10bd14b                           systems biology
# 4daf9ac2c73522a2339d564abc33f2d4                            bioinformatics
# 62d5d75aa5c5c673ff839565556057cd                           systems biology
# 6481c74f482bb574529fcfe12f7247c2                              biochemistry
# 85d35a71ea3dbd9e452e4c9a0b83016b                           systems biology
# 86ed6760b4a6fc54cff9850e090c7b5f                           systems biology
# 9bdb3c0e8ae917d2fe5dc746a4fe24c6                            bioinformatics
# b540afa5300616f5a6ed80106fb6b20e                           systems biology
# e9e357d280b62fde1f5c9b718ee3ea36                            bioinformatics
# 0687ef14d441706b211ff0edf9f2ebea                              biochemistry
# 0ddaf25718c6b4c35bf05ae6335150d4                                biophysics
# 18da94199bf2471a70d0298958543bb4                                   biology
# 23ba4e6b2b149ba6294bd7e0125b2948                    bioprocess engineering
# 2bd5b76b8fac74b062c1a99c9bbc0a75                           systems biology
# 2be130732b05502a4a631bc01291b25b  computational biophysics, bioinformatics
# 38c7d17c9d41c293afe9d368d45a629c                            bioinformatics
# 3ea2814b0443687ea2400e6c1726d7ab                            bioinformatics
# 4306bad121fb3ad1fb2365dda1a32440                            bioinformatics
# 4d9db524466a6d05f29fb721f842de77    neuroscience (of nociception and pain)
# 52d3867f738f6cff74269cf62e3b7251                            bioinformatics
# 5b114f95a429eb982fc0b378c64a23f9                   biology, bioinformatics
# 690e88138d83a8ec5fea4230b364aae0                           systems biology
# 6b216d7a04c90e3490fb335b6dc39314                      experimental biology
# 6fd7664989b2b16f85c63169595bb66e                            bioinformatics
# 78764885189f4abe3a13ee47ebe3d1fa                                   biology
# ...                                                                    ...
# b57ae216d47820a5a597768ddc48fdca                             biotechnology
# c0ba478916443e75928dc18d1bc8e468                     computational biology
# c122797a0a6e34e5c7159bb839ab9cec                             palaeobiology
# c424cb968746b9c146cfda7af86bd46f                      analytical chemistry
# c4855b2635f52a5f8f10a13348b2e688                      behavioural genetics
# c4af4b34d71a116d49cfd1bbc37115dc                            bioinformatics
# ce4dd38c1a2b00597a5937d82828d532                            bioinformatics
# d05374703295171ee7746105b806e10b                            bioinformatics
# d88bf82976822f5950e5bc4cf56e700a                            cancer biology
# dce82b0bd1c889c42227c7290aa6cec0                            bioinformatics
# ed4707fdbf643cdb6651a9d7807d8048           systems biology, bioinformatics
# f3906c5106e79f3165050a0fcbbf4cc3                            bioinformatics
# fa251851931ddd1b63a9d66bd90ca95c                        microbial genetics
# fc5bb1982077af9dd12aa7de0a5660c3                           systems biology
# 68ec3fb55059c118977c24cbd4fca91c                                   biology
# c2026cc168583afd72bbfbb284c0f1e9                            bioinformatics
# 9f739b36a1f91569017b5ab36be07f7f                           systems biology
# 66f12cf71b45603b5b5bded2142fb89c                              cell biology
# b4bd8ddfbcf302338f7898eec8382690                                  genetics
# 90c08c4bb24fd7715f6dce58d09061f4                           systems biology
# 2916e59453604e0bf19d4b3b60b75fdd                           systems biology
# 28d0f45805f4a2e9ec4d8fe4cf2e517e                                 chemistry
# 0ad6197707803a31a98aa69dccc39bad                           systems biology
# d8695dead80bb8f3ba0caa25e5ca785c                              pharmacology
# 4379192aef2087ff9a349056bcbb6bb4                                 evolution
# 8ed6774338c3fee17bbdca2dfbc7f1d6                                immunology
# f1deeddb2588e790d7425adfa7ffb307                              cell biology
# a3fb71f8688c810c126ede0a989b79cc                         synthetic biology
# d1cf1e2bd3e41f2bd3576a32593e2f73                                   biology
# 15977d31cfde3f67cdf3ca9e9f8995a0                                 chemistry
#
#                                              ease_1             ease_2  \
# sessionid
# 03ebd33fe07a1226f3b98aa8aa13e76e              Agree              Agree
# 03ebd33fe07a1226f3b98aa8aa13e76e              Agree              Agree
# 0edc7c52e0ccb1714e9a39ea75af43fe              Agree              Agree
# 358e6df6c02309c57fd05b27540fb8e8            Neither           Disagree
# 3cff31dfa808cff92541784186c8243a              Agree            Neither
# 43f10113e67dff73361c235ee10bd14b              Agree              Agree
# 4daf9ac2c73522a2339d564abc33f2d4              Agree              Agree
# 62d5d75aa5c5c673ff839565556057cd              Agree              Agree
# 6481c74f482bb574529fcfe12f7247c2              Agree              Agree
# 85d35a71ea3dbd9e452e4c9a0b83016b              Agree              Agree
# 86ed6760b4a6fc54cff9850e090c7b5f              Agree           Disagree
# 9bdb3c0e8ae917d2fe5dc746a4fe24c6              Agree              Agree
# b540afa5300616f5a6ed80106fb6b20e  Strongly Disagree              Agree
# e9e357d280b62fde1f5c9b718ee3ea36     Strongly Agree              Agree
# 0687ef14d441706b211ff0edf9f2ebea              Agree              Agree
# 0ddaf25718c6b4c35bf05ae6335150d4              Agree              Agree
# 18da94199bf2471a70d0298958543bb4     Strongly Agree     Strongly Agree
# 23ba4e6b2b149ba6294bd7e0125b2948              Agree              Agree
# 2bd5b76b8fac74b062c1a99c9bbc0a75     Strongly Agree     Strongly Agree
# 2be130732b05502a4a631bc01291b25b  Strongly Disagree     Strongly Agree
# 38c7d17c9d41c293afe9d368d45a629c     Strongly Agree     Strongly Agree
# 3ea2814b0443687ea2400e6c1726d7ab              Agree                NaN
# 4306bad121fb3ad1fb2365dda1a32440            Neither              Agree
# 4d9db524466a6d05f29fb721f842de77     Strongly Agree     Strongly Agree
# 52d3867f738f6cff74269cf62e3b7251           Disagree              Agree
# 5b114f95a429eb982fc0b378c64a23f9     Strongly Agree     Strongly Agree
# 690e88138d83a8ec5fea4230b364aae0     Strongly Agree     Strongly Agree
# 6b216d7a04c90e3490fb335b6dc39314              Agree            Neither
# 6fd7664989b2b16f85c63169595bb66e              Agree              Agree
# 78764885189f4abe3a13ee47ebe3d1fa     Strongly Agree     Strongly Agree
# ...                                             ...                ...
# b57ae216d47820a5a597768ddc48fdca           Disagree            Neither
# c0ba478916443e75928dc18d1bc8e468              Agree              Agree
# c122797a0a6e34e5c7159bb839ab9cec            Neither              Agree
# c424cb968746b9c146cfda7af86bd46f     Strongly Agree     Strongly Agree
# c4855b2635f52a5f8f10a13348b2e688     Strongly Agree     Strongly Agree
# c4af4b34d71a116d49cfd1bbc37115dc              Agree              Agree
# ce4dd38c1a2b00597a5937d82828d532              Agree              Agree
# d05374703295171ee7746105b806e10b     Strongly Agree              Agree
# d88bf82976822f5950e5bc4cf56e700a  Strongly Disagree  Strongly Disagree
# dce82b0bd1c889c42227c7290aa6cec0            Neither            Neither
# ed4707fdbf643cdb6651a9d7807d8048              Agree              Agree
# f3906c5106e79f3165050a0fcbbf4cc3     Strongly Agree     Strongly Agree
# fa251851931ddd1b63a9d66bd90ca95c     Strongly Agree     Strongly Agree
# fc5bb1982077af9dd12aa7de0a5660c3              Agree              Agree
# 68ec3fb55059c118977c24cbd4fca91c              Agree              Agree
# c2026cc168583afd72bbfbb284c0f1e9     Strongly Agree     Strongly Agree
# 9f739b36a1f91569017b5ab36be07f7f              Agree              Agree
# 66f12cf71b45603b5b5bded2142fb89c              Agree              Agree
# b4bd8ddfbcf302338f7898eec8382690     Strongly Agree     Strongly Agree
# 90c08c4bb24fd7715f6dce58d09061f4              Agree                NaN
# 2916e59453604e0bf19d4b3b60b75fdd              Agree              Agree
# 28d0f45805f4a2e9ec4d8fe4cf2e517e              Agree              Agree
# 0ad6197707803a31a98aa69dccc39bad     Strongly Agree     Strongly Agree
# d8695dead80bb8f3ba0caa25e5ca785c              Agree                NaN
# 4379192aef2087ff9a349056bcbb6bb4  Strongly Disagree              Agree
# 8ed6774338c3fee17bbdca2dfbc7f1d6              Agree              Agree
# f1deeddb2588e790d7425adfa7ffb307              Agree              Agree
# a3fb71f8688c810c126ede0a989b79cc              Agree           Disagree
# d1cf1e2bd3e41f2bd3576a32593e2f73              Agree              Agree
# 15977d31cfde3f67cdf3ca9e9f8995a0              Agree                NaN
#
#                                   frequency honest            howmany  ...   \
# sessionid                                                              ...
# 03ebd33fe07a1226f3b98aa8aa13e76e          1     on            only me  ...
# 03ebd33fe07a1226f3b98aa8aa13e76e          1     on            only me  ...
# 0edc7c52e0ccb1714e9a39ea75af43fe          4     on    between 2 and 4  ...
# 358e6df6c02309c57fd05b27540fb8e8          1     on       more than 20  ...
# 3cff31dfa808cff92541784186c8243a          4     on            only me  ...
# 43f10113e67dff73361c235ee10bd14b          3    NaN  between 13 and 20  ...
# 4daf9ac2c73522a2339d564abc33f2d4          3     on    between 2 and 4  ...
# 62d5d75aa5c5c673ff839565556057cd          2     on            only me  ...
# 6481c74f482bb574529fcfe12f7247c2          5    NaN    between 2 and 4  ...
# 85d35a71ea3dbd9e452e4c9a0b83016b          4    NaN    between 2 and 4  ...
# 86ed6760b4a6fc54cff9850e090c7b5f          4    NaN            only me  ...
# 9bdb3c0e8ae917d2fe5dc746a4fe24c6          4     on            only me  ...
# b540afa5300616f5a6ed80106fb6b20e          4     on    between 2 and 4  ...
# e9e357d280b62fde1f5c9b718ee3ea36          3     on  between 5 and  12  ...
# 0687ef14d441706b211ff0edf9f2ebea          4    NaN            only me  ...
# 0ddaf25718c6b4c35bf05ae6335150d4          3    NaN    between 2 and 4  ...
# 18da94199bf2471a70d0298958543bb4          5    NaN    between 2 and 4  ...
# 23ba4e6b2b149ba6294bd7e0125b2948          4     on  between 5 and  12  ...
# 2bd5b76b8fac74b062c1a99c9bbc0a75          5    NaN    between 2 and 4  ...
# 2be130732b05502a4a631bc01291b25b          4    NaN            only me  ...
# 38c7d17c9d41c293afe9d368d45a629c          4     on    between 2 and 4  ...
# 3ea2814b0443687ea2400e6c1726d7ab          2     on  between 13 and 20  ...
# 4306bad121fb3ad1fb2365dda1a32440          4     on            only me  ...
# 4d9db524466a6d05f29fb721f842de77          3     on  between 5 and  12  ...
# 52d3867f738f6cff74269cf62e3b7251          4     on  between 5 and  12  ...
# 5b114f95a429eb982fc0b378c64a23f9          5     on  between 5 and  12  ...
# 690e88138d83a8ec5fea4230b364aae0          1     on    between 2 and 4  ...
# 6b216d7a04c90e3490fb335b6dc39314          2     on    between 2 and 4  ...
# 6fd7664989b2b16f85c63169595bb66e          1     on  between 13 and 20  ...
# 78764885189f4abe3a13ee47ebe3d1fa          2     on  between 13 and 20  ...
# ...                                     ...    ...                ...  ...
# b57ae216d47820a5a597768ddc48fdca          5     on    between 2 and 4  ...
# c0ba478916443e75928dc18d1bc8e468          3     on    between 2 and 4  ...
# c122797a0a6e34e5c7159bb839ab9cec        NaN    NaN    between 2 and 4  ...
# c424cb968746b9c146cfda7af86bd46f          4     on    between 2 and 4  ...
# c4855b2635f52a5f8f10a13348b2e688          5     on    between 2 and 4  ...
# c4af4b34d71a116d49cfd1bbc37115dc          2     on       more than 20  ...
# ce4dd38c1a2b00597a5937d82828d532          1     on    between 2 and 4  ...
# d05374703295171ee7746105b806e10b          5     on            only me  ...
# d88bf82976822f5950e5bc4cf56e700a        NaN     on  between 5 and  12  ...
# dce82b0bd1c889c42227c7290aa6cec0          2     on    between 2 and 4  ...
# ed4707fdbf643cdb6651a9d7807d8048          2     on    between 2 and 4  ...
# f3906c5106e79f3165050a0fcbbf4cc3          3     on    between 2 and 4  ...
# fa251851931ddd1b63a9d66bd90ca95c          2     on  between 5 and  12  ...
# fc5bb1982077af9dd12aa7de0a5660c3          4     on  between 5 and  12  ...
# 68ec3fb55059c118977c24cbd4fca91c          5     on    between 2 and 4  ...
# c2026cc168583afd72bbfbb284c0f1e9          5     on    between 2 and 4  ...
# 9f739b36a1f91569017b5ab36be07f7f          4     on    between 2 and 4  ...
# 66f12cf71b45603b5b5bded2142fb89c          5     on            only me  ...
# b4bd8ddfbcf302338f7898eec8382690          4     on    between 2 and 4  ...
# 90c08c4bb24fd7715f6dce58d09061f4          5   null            only me  ...
# 2916e59453604e0bf19d4b3b60b75fdd          3     on  between 13 and 20  ...
# 28d0f45805f4a2e9ec4d8fe4cf2e517e          5     on            only me  ...
# 0ad6197707803a31a98aa69dccc39bad          3     on  between 5 and  12  ...
# d8695dead80bb8f3ba0caa25e5ca785c          4     on    between 2 and 4  ...
# 4379192aef2087ff9a349056bcbb6bb4          4   null    between 2 and 4  ...
# 8ed6774338c3fee17bbdca2dfbc7f1d6          5     on    between 2 and 4  ...
# f1deeddb2588e790d7425adfa7ffb307          5     on            only me  ...
# a3fb71f8688c810c126ede0a989b79cc          5   null            only me  ...
# d1cf1e2bd3e41f2bd3576a32593e2f73          5     on    between 2 and 4  ...
# 15977d31cfde3f67cdf3ca9e9f8995a0        NaN    NaN    between 2 and 4  ...
#
#                                   updating                ways when_best  \
# sessionid
# 03ebd33fe07a1226f3b98aa8aa13e76e       NaN        [u'1', u'2']         5
# 03ebd33fe07a1226f3b98aa8aa13e76e       NaN        [u'1', u'2']         5
# 0edc7c52e0ccb1714e9a39ea75af43fe       NaN              [u'2']         5
# 358e6df6c02309c57fd05b27540fb8e8        on              [u'2']         6
# 3cff31dfa808cff92541784186c8243a       NaN  [u'1', u'2', u'3']         5
# 43f10113e67dff73361c235ee10bd14b       NaN              [u'1']         5
# 4daf9ac2c73522a2339d564abc33f2d4       NaN        [u'1', u'2']         6
# 62d5d75aa5c5c673ff839565556057cd        on              [u'2']         6
# 6481c74f482bb574529fcfe12f7247c2       NaN              [u'4']         5
# 85d35a71ea3dbd9e452e4c9a0b83016b       NaN              [u'1']         5
# 86ed6760b4a6fc54cff9850e090c7b5f       NaN  [u'1', u'2', u'3']         5
# 9bdb3c0e8ae917d2fe5dc746a4fe24c6       NaN  [u'1', u'2', u'3']         5
# b540afa5300616f5a6ed80106fb6b20e       NaN        [u'1', u'2']         5
# e9e357d280b62fde1f5c9b718ee3ea36       NaN              [u'2']         5
# 0687ef14d441706b211ff0edf9f2ebea       NaN        [u'1', u'2']         5
# 0ddaf25718c6b4c35bf05ae6335150d4       NaN        [u'1', u'3']         4
# 18da94199bf2471a70d0298958543bb4       NaN              [u'1']         5
# 23ba4e6b2b149ba6294bd7e0125b2948       NaN        [u'1', u'2']         4
# 2bd5b76b8fac74b062c1a99c9bbc0a75       NaN              [u'3']         5
# 2be130732b05502a4a631bc01291b25b       NaN        [u'1', u'3']         5
# 38c7d17c9d41c293afe9d368d45a629c        on              [u'2']         5
# 3ea2814b0443687ea2400e6c1726d7ab        on        [u'1', u'2']         6
# 4306bad121fb3ad1fb2365dda1a32440       NaN              [u'3']         5
# 4d9db524466a6d05f29fb721f842de77       NaN              [u'1']         5
# 52d3867f738f6cff74269cf62e3b7251        on        [u'1', u'2']         5
# 5b114f95a429eb982fc0b378c64a23f9       NaN              [u'1']         5
# 690e88138d83a8ec5fea4230b364aae0       NaN  [u'1', u'2', u'3']         5
# 6b216d7a04c90e3490fb335b6dc39314        on              [u'2']         5
# 6fd7664989b2b16f85c63169595bb66e        on              [u'2']         6
# 78764885189f4abe3a13ee47ebe3d1fa        on        [u'1', u'3']         5
# ...                                    ...                 ...       ...
# b57ae216d47820a5a597768ddc48fdca       NaN        [u'3', u'4']         5
# c0ba478916443e75928dc18d1bc8e468       NaN        [u'1', u'2']         5
# c122797a0a6e34e5c7159bb839ab9cec       NaN        [u'1', u'2']         5
# c424cb968746b9c146cfda7af86bd46f        on              [u'4']         4
# c4855b2635f52a5f8f10a13348b2e688       NaN                 NaN         5
# c4af4b34d71a116d49cfd1bbc37115dc        on  [u'1', u'2', u'3']         5
# ce4dd38c1a2b00597a5937d82828d532       NaN              [u'2']         5
# d05374703295171ee7746105b806e10b       NaN              [u'3']         5
# d88bf82976822f5950e5bc4cf56e700a       NaN        [u'1', u'2']         5
# dce82b0bd1c889c42227c7290aa6cec0        on  [u'1', u'2', u'3']         6
# ed4707fdbf643cdb6651a9d7807d8048        on        [u'1', u'2']         5
# f3906c5106e79f3165050a0fcbbf4cc3        on        [u'2', u'3']         5
# fa251851931ddd1b63a9d66bd90ca95c       NaN        [u'2', u'3']         6
# fc5bb1982077af9dd12aa7de0a5660c3       NaN              [u'1']         5
# 68ec3fb55059c118977c24cbd4fca91c       NaN              [u'4']         5
# c2026cc168583afd72bbfbb284c0f1e9       NaN              [u'2']         5
# 9f739b36a1f91569017b5ab36be07f7f        on              [u'2']         5
# 66f12cf71b45603b5b5bded2142fb89c       NaN              [u'1']         5
# b4bd8ddfbcf302338f7898eec8382690        on           ["1","2"]         6
# 90c08c4bb24fd7715f6dce58d09061f4      null               ["4"]         3
# 2916e59453604e0bf19d4b3b60b75fdd        on           ["1","2"]         5
# 28d0f45805f4a2e9ec4d8fe4cf2e517e      null               ["1"]         5
# 0ad6197707803a31a98aa69dccc39bad        on           ["1","2"]         5
# d8695dead80bb8f3ba0caa25e5ca785c      null               ["1"]         5
# 4379192aef2087ff9a349056bcbb6bb4      null           ["1","2"]         5
# 8ed6774338c3fee17bbdca2dfbc7f1d6      null               ["4"]         5
# f1deeddb2588e790d7425adfa7ffb307      null               ["1"]         5
# a3fb71f8688c810c126ede0a989b79cc      null               ["1"]         5
# d1cf1e2bd3e41f2bd3576a32593e2f73      null               ["4"]         5
# 15977d31cfde3f67cdf3ca9e9f8995a0       NaN                 NaN       NaN
#
#                                  when_to_1 when_to_2     with_who_1  \
# sessionid
# 03ebd33fe07a1226f3b98aa8aa13e76e       nan       nan         public
# 03ebd33fe07a1226f3b98aa8aa13e76e       nan       nan         public
# 0edc7c52e0ccb1714e9a39ea75af43fe       nan       nan         public
# 358e6df6c02309c57fd05b27540fb8e8       10y       nan  collaborators
# 3cff31dfa808cff92541784186c8243a       nan       nan         public
# 43f10113e67dff73361c235ee10bd14b       10y       10y        private
# 4daf9ac2c73522a2339d564abc33f2d4       nan       nan         public
# 62d5d75aa5c5c673ff839565556057cd       10y       nan   stakeholders
# 6481c74f482bb574529fcfe12f7247c2       nan       nan         public
# 85d35a71ea3dbd9e452e4c9a0b83016b       nan       nan         public
# 86ed6760b4a6fc54cff9850e090c7b5f       10y       10y   stakeholders
# 9bdb3c0e8ae917d2fe5dc746a4fe24c6       10y       nan   stakeholders
# b540afa5300616f5a6ed80106fb6b20e       nan        6m         public
# e9e357d280b62fde1f5c9b718ee3ea36       nan       nan         public
# 0687ef14d441706b211ff0edf9f2ebea       nan       nan         public
# 0ddaf25718c6b4c35bf05ae6335150d4       10y       nan  collaborators
# 18da94199bf2471a70d0298958543bb4       nan       nan         public
# 23ba4e6b2b149ba6294bd7e0125b2948       nan       nan         public
# 2bd5b76b8fac74b062c1a99c9bbc0a75       nan       nan         public
# 2be130732b05502a4a631bc01291b25b       nan       nan         public
# 38c7d17c9d41c293afe9d368d45a629c       nan       nan         public
# 3ea2814b0443687ea2400e6c1726d7ab       nan       nan         public
# 4306bad121fb3ad1fb2365dda1a32440       nan       nan         public
# 4d9db524466a6d05f29fb721f842de77       nan       nan         public
# 52d3867f738f6cff74269cf62e3b7251        6m        1y  collaborators
# 5b114f95a429eb982fc0b378c64a23f9       nan       nan         public
# 690e88138d83a8ec5fea4230b364aae0       nan       nan         public
# 6b216d7a04c90e3490fb335b6dc39314       10y       nan   stakeholders
# 6fd7664989b2b16f85c63169595bb66e       nan       nan         public
# 78764885189f4abe3a13ee47ebe3d1fa       nan       nan         public
# ...                                    ...       ...            ...
# b57ae216d47820a5a597768ddc48fdca       nan       nan         public
# c0ba478916443e75928dc18d1bc8e468        3y       10y   stakeholders
# c122797a0a6e34e5c7159bb839ab9cec       nan       nan         public
# c424cb968746b9c146cfda7af86bd46f        1y       nan   stakeholders
# c4855b2635f52a5f8f10a13348b2e688       nan       nan         public
# c4af4b34d71a116d49cfd1bbc37115dc       nan       nan         public
# ce4dd38c1a2b00597a5937d82828d532       nan       nan         public
# d05374703295171ee7746105b806e10b       nan       nan         public
# d88bf82976822f5950e5bc4cf56e700a       nan       nan         public
# dce82b0bd1c889c42227c7290aa6cec0       nan       nan         public
# ed4707fdbf643cdb6651a9d7807d8048       nan       nan         public
# f3906c5106e79f3165050a0fcbbf4cc3       nan       nan         public
# fa251851931ddd1b63a9d66bd90ca95c       nan       nan         public
# fc5bb1982077af9dd12aa7de0a5660c3       nan       nan         public
# 68ec3fb55059c118977c24cbd4fca91c       nan       nan         public
# c2026cc168583afd72bbfbb284c0f1e9        6m       nan   stakeholders
# 9f739b36a1f91569017b5ab36be07f7f        1y       10y        private
# 66f12cf71b45603b5b5bded2142fb89c       nan       nan         public
# b4bd8ddfbcf302338f7898eec8382690      null      null         public
# 90c08c4bb24fd7715f6dce58d09061f4      null       nan         public
# 2916e59453604e0bf19d4b3b60b75fdd      null       nan         public
# 28d0f45805f4a2e9ec4d8fe4cf2e517e      null       nan         public
# 0ad6197707803a31a98aa69dccc39bad      null      null         public
# d8695dead80bb8f3ba0caa25e5ca785c      null       nan         public
# 4379192aef2087ff9a349056bcbb6bb4        1y        1y  collaborators
# 8ed6774338c3fee17bbdca2dfbc7f1d6        1y       10y  collaborators
# f1deeddb2588e790d7425adfa7ffb307      null       nan         public
# a3fb71f8688c810c126ede0a989b79cc       10y       10y  collaborators
# d1cf1e2bd3e41f2bd3576a32593e2f73      null       nan         public
# 15977d31cfde3f67cdf3ca9e9f8995a0      null       nan         public
#
#                                      with_who_2 year_born gibberish field
# sessionid
# 03ebd33fe07a1226f3b98aa8aa13e76e         public      1985      True    LS
# 03ebd33fe07a1226f3b98aa8aa13e76e         public      1985      True    LS
# 0edc7c52e0ccb1714e9a39ea75af43fe         public      1979      True    LS
# 358e6df6c02309c57fd05b27540fb8e8         public      1975      True    LS
# 3cff31dfa808cff92541784186c8243a         public      1976      True    LS
# 43f10113e67dff73361c235ee10bd14b  collaborators      2000      True    LS
# 4daf9ac2c73522a2339d564abc33f2d4         public      1984      True    LS
# 62d5d75aa5c5c673ff839565556057cd         public      1981      True    LS
# 6481c74f482bb574529fcfe12f7247c2         public      1989      True    LS
# 85d35a71ea3dbd9e452e4c9a0b83016b         public      1979      True    LS
# 86ed6760b4a6fc54cff9850e090c7b5f   stakeholders      1981      True    LS
# 9bdb3c0e8ae917d2fe5dc746a4fe24c6         public      1985      True    LS
# b540afa5300616f5a6ed80106fb6b20e   stakeholders      1982      True    LS
# e9e357d280b62fde1f5c9b718ee3ea36         public      1989      True    LS
# 0687ef14d441706b211ff0edf9f2ebea         public      1980      True    LS
# 0ddaf25718c6b4c35bf05ae6335150d4         public      1971      True    LS
# 18da94199bf2471a70d0298958543bb4         public      1989      True    LS
# 23ba4e6b2b149ba6294bd7e0125b2948         public      1959      True    LS
# 2bd5b76b8fac74b062c1a99c9bbc0a75         public      1985      True    LS
# 2be130732b05502a4a631bc01291b25b         public      1970      True    LS
# 38c7d17c9d41c293afe9d368d45a629c         public      1981      True    LS
# 3ea2814b0443687ea2400e6c1726d7ab         public      1976      True    LS
# 4306bad121fb3ad1fb2365dda1a32440         public      1973      True    LS
# 4d9db524466a6d05f29fb721f842de77         public      1950      True    LS
# 52d3867f738f6cff74269cf62e3b7251  collaborators      1986      True    LS
# 5b114f95a429eb982fc0b378c64a23f9         public      1989      True    LS
# 690e88138d83a8ec5fea4230b364aae0         public      1985      True    LS
# 6b216d7a04c90e3490fb335b6dc39314         public      1973      True    LS
# 6fd7664989b2b16f85c63169595bb66e         public      1973      True    LS
# 78764885189f4abe3a13ee47ebe3d1fa         public      1963      True    LS
# ...                                         ...       ...       ...   ...
# b57ae216d47820a5a597768ddc48fdca         public      1977      True    LS
# c0ba478916443e75928dc18d1bc8e468   stakeholders      1970      True    LS
# c122797a0a6e34e5c7159bb839ab9cec         public      1981      True    LS
# c424cb968746b9c146cfda7af86bd46f         public      1985      True    LS
# c4855b2635f52a5f8f10a13348b2e688         public      1988      True    LS
# c4af4b34d71a116d49cfd1bbc37115dc         public      1978      True    LS
# ce4dd38c1a2b00597a5937d82828d532         public      1984      True    LS
# d05374703295171ee7746105b806e10b         public      1985      True    LS
# d88bf82976822f5950e5bc4cf56e700a         public      1980      True    LS
# dce82b0bd1c889c42227c7290aa6cec0         public      1986      True    LS
# ed4707fdbf643cdb6651a9d7807d8048         public      1972      True    LS
# f3906c5106e79f3165050a0fcbbf4cc3         public      1982      True    LS
# fa251851931ddd1b63a9d66bd90ca95c         public      1961      True    LS
# fc5bb1982077af9dd12aa7de0a5660c3         public      1975      True    LS
# 68ec3fb55059c118977c24cbd4fca91c         public      1978      True    LS
# c2026cc168583afd72bbfbb284c0f1e9         public      1987      True    LS
# 9f739b36a1f91569017b5ab36be07f7f        private      1975      True    LS
# 66f12cf71b45603b5b5bded2142fb89c         public      1986      True    LS
# b4bd8ddfbcf302338f7898eec8382690         public      1986      True    LS
# 90c08c4bb24fd7715f6dce58d09061f4            NaN      1986      True    LS
# 2916e59453604e0bf19d4b3b60b75fdd         public      1981      True    LS
# 28d0f45805f4a2e9ec4d8fe4cf2e517e         public      1990      True    LS
# 0ad6197707803a31a98aa69dccc39bad         public      1986      True    LS
# d8695dead80bb8f3ba0caa25e5ca785c            NaN      1987      True    LS
# 4379192aef2087ff9a349056bcbb6bb4  collaborators      1981      True    LS
# 8ed6774338c3fee17bbdca2dfbc7f1d6  collaborators      1991      True    LS
# f1deeddb2588e790d7425adfa7ffb307         public      1987      True    LS
# a3fb71f8688c810c126ede0a989b79cc        private      1979      True    LS
# d1cf1e2bd3e41f2bd3576a32593e2f73         public      1986      True    LS
# 15977d31cfde3f67cdf3ca9e9f8995a0            NaN      1989      True    LS
#
# [77 rows x 43 columns]

# %%
df = fc.get_between_subject_dataframe_whent('')
df
# Out:
# (77, 43)
#       c   t
# 1     3   4
# 2     4   5
# 3     0   1
# 10   14   6
# nan  47  52

# %% [markdown]
# #### Comparison test Wicoxon SCC both perios

# %%
# %%R -i df
# library(MASS)
# print(summary(df))
# print(chisq.test(df))
# s<-wilcox.test(df$t,df$c, paired=F, conf.int = TRUE,  alternative = "g")
# print(s)
# Out:
#        c              t
#  Min.   : 0.0   Min.   : 1.0
#  1st Qu.: 3.0   1st Qu.: 4.0
#  Median : 4.0   Median : 5.0
#  Mean   :13.6   Mean   :13.6
#  3rd Qu.:14.0   3rd Qu.: 6.0
#  Max.   :47.0   Max.   :52.0
#
# 	Pearson's Chi-squared test
#
# data:  df
# X-squared = 4.7065, df = 4, p-value = 0.3188
#
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  df$t and df$c
# W = 14.5, p-value = 0.3766
# alternative hypothesis: true location shift is greater than 0
# 95 percent confidence interval:
#  -13.00005       Inf
# sample estimates:
# difference in location
#               1.000052

# %% [markdown]
# #### Comparison test logistic regression SCC both periods

# %%
r = fc.get_rm_ws_dataframe_whent()
r = r[r.response != 'null']
r = r.dropna()
r = r.sort(columns=['trt'])
r['trt'] = r['trt'].replace(['A','B'],['1','0'])
r['response'] = r['response'].replace(['later','10y','3y','1y','6m'],['10','10','3','2','1'])
# Out:
# (77, 44)
# sasa
# (77, 5)
# (73, 5)
# (140, 5)

# %%
# %%R -i r
# library(MASS)
# ddf2 <- data.frame(r)
# ddf2$value <- factor(ddf2$response)
# ddf2$trt <- factor(ddf2$trt)
# ddf2$sequ <- factor(ddf2$sequ)
#
#
# mymodel = polr(response ~ trt, data=ddf2,  Hess=TRUE, method="probit")
#
# n1 <- data.frame(trt='1')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Treatment')
# print(s)
# n1 <- data.frame(trt='0')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Control')
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
# [1] "Probabilities for Treatment"
#           1          10           2           3         nan
# 0.046308849 0.112226778 0.050977834 0.007321772 0.783164766
# [1] "Probabilities for Control"
#           1          10           2           3         nan
# 0.060886775 0.132325815 0.057027446 0.008074552 0.741685412
# Waiting for profiling to be done...
#              OR
# 2.5 %  1.143823 0.7251928
# 97.5 % 1.143823 1.8103034

# %%
fc = FrameExperimentTable('logs/data_incremental_file')
# fc = FrameExperimentTable('logs/data_scenario_changed')
fc.add_records('logs/data_two_records')
fc.add_records_csv('logs/data_scramble_filled_csv.csv')
fc.add_records('logs/data_scenario_changed')
fc.filter_noise()
fc.code_for_stat_ana()
fc.code_survey_numeric()



scc_df = fc.get_plotdata()
# Out:
# (21, 41)
# Fields Excluded
# (49,)
# sessionid
# 88f18269f0d7ff772f8a3f89fc8c81cb                                                asasa
# 88f18269f0d7ff772f8a3f89fc8c81cb    djdjdjdjjdjdjdjdjdjdjdjdjdjdjdjdjdjdjdjdjdjkdk...
# 96d141400e48d48311882f7cde6344fc                                    Political Science
# f14a64d2f8ec48ce4cee9b2982bec68b                                                  NaN
# 58d0e078f29b6a75e930333a851b5cb3                                 Software Development
# 8f3ffab2333bbd52df8bfae3ece74b7a                                                 XXXX
# 9cdbd6ec8df0f2d350c1d5bd74f7ebb0                                           Statistics
# b3b25386946e6bba8a0d267a6b17c819                                                  NaN
# b3b25386946e6bba8a0d267a6b17c819                                                  NaN
# b3b25386946e6bba8a0d267a6b17c819                                                  NaN
# b3b25386946e6bba8a0d267a6b17c819                                                  NaN
# b3b25386946e6bba8a0d267a6b17c819                                                WWWWW
# b3b25386946e6bba8a0d267a6b17c819                                               xxxxxx
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# b74992465d47a1ef70634de9689de07f                                                  NaN
# e57134ffac386481e78550d53e544198                                               azzzzz
# e57134ffac386481e78550d53e544198                                               looooo
# e57134ffac386481e78550d53e544198                                                oolll
# e57134ffac386481e78550d53e544198                                                qqqqq
# Name: discipline, dtype: object
# (77, 43)

# %%
W  = pd.DataFrame({'GAIN_SCC_P1' : scc_df.when_to_1[scc_df.treatment_eval_1 == 'cite DataLabour']})
S  = pd.DataFrame({'LOSS_SCC_P1' : scc_df.when_to_1[scc_df.treatment_eval_1 == 'Jam Share Data']})
S.shape
# Out:
# (34, 1)

# %%
# %%R -i W -i S
# source("stacked_bars.R")
# graph_when(W, S)

# %%
W  = pd.DataFrame({'GAIN_SCC_P2' : scc_df.when_to_2[scc_df.treatment_eval_2 == 'cite DataLabour']})
S = pd.DataFrame({'LOSS_SCC_P2' : scc_df.when_to_2[scc_df.treatment_eval_2 == 'Jam Share Data']})

# %%
# %%R -i W -i S
# graph_when(W, S)
# Out:
# NULL

# %% [markdown]
# ### Between Subjects test for all the interactions (EF)

# %% [markdown]
# #### T1 vs C1 (EF)

# %%
df = master_dataset.replace(['cite DataLabour','Jam Share Data'],['A','B'])
print df.shape
df = df[['treatment_eval_1','treatment_eval_2','with_who_1','with_who_2']]
df = df.dropna()
print df.shape
df = df[df.treatment_eval_1 != df.treatment_eval_2]
df = df.replace(['stackeholders'],['stakeholders'])
df = df.replace(['private','collaborators','stakeholders','public'],[1,2,3,4])
# t1 = df['with_who_1'][df['treatment_eval_1'] == 'A'].head(10)
# c1 = df['with_who_1'][df['treatment_eval_1'] == 'B'].head(10)
# Out:
# (31, 41)
# (28, 4)

# %%
df_new = master_dataset[['treatment_eval_1','treatment_eval_2','with_who_1','with_who_2']].dropna()
df_new = df_new.replace(['stackeholders'],['stakeholders'])
df_new = df_new.replace(['with_who_1'],[1])
df_new = df_new.replace(['private','collaborators','stakeholders','public'],[1,2,3,4])
df_new = df_new.replace(['cite DataLabour','Jam Share Data'],['A','B'])

s = pd.melt(df_new, id_vars=['with_who_1','with_who_2'])
# print df_new['with_who_2'].value_counts()
t1 = df['with_who_1'][df['treatment_eval_1'] == 'A'].value_counts()
c1 = df['with_who_1'][df['treatment_eval_1'] == 'B'].value_counts()
dd = pd.DataFrame({'t1' : t1, 'c1':c1}).fillna(0)
# d = dd.append(c1,ignore_index=True)
dd
# # s['with_who_1'].value_counts()
# w=s.pivot_table(['value',], rows=['with_who_1'], index=Grouper(freq='A', key='B'))
# w

# # w = s.groupby(['with_who_2'])
# # w.count()
# Out:
#    c1  t1
# 1   0   2
# 2   1   1
# 3   3   1
# 4   8   8

# %%
# %%R -i dd
# library(MASS)
# print(summary(dd))
# print(chisq.test(dd))
# #print(assocstats(dd))
# wilcox.test(dd$t1,dd$c1, paired=FALSE, conf.int = TRUE, alternative = "greater")
# Out:
#        c1             t1
#  Min.   :0.00   Min.   :1.0
#  1st Qu.:0.75   1st Qu.:1.0
#  Median :2.00   Median :1.5
#  Mean   :3.00   Mean   :3.0
#  3rd Qu.:4.25   3rd Qu.:3.5
#  Max.   :8.00   Max.   :8.0
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 3, df = 3, p-value = 0.3916
#
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  dd$t1 and dd$c1
# W = 8.5, p-value = 0.5
# alternative hypothesis: true location shift is greater than 0
# 95 percent confidence interval:
#  -6.999949       Inf
# sample estimates:
# difference in location
#           1.953827e-05

# %% [markdown]
# ### T2 vs C2

# %%
t2 = df['with_who_2'][df['treatment_eval_2'] == 'A'].value_counts()
c2 = df['with_who_2'][df['treatment_eval_2'] == 'B'].value_counts()
dd = pd.DataFrame({'t2' : t2, 'c2':c2}).fillna(0)

# %%
# %%R -i dd
# library(MASS)
# library(vcd)
# print(dd)
# print(summary(dd))
# print(chisq.test(dd))
# print(fisher.test(dd))
# #print(assocstats(dd))
# wilcox.test(dd$t2,dd$c2, paired=FALSE, conf.int = TRUE, alternative = "greater")
# Out:
#   c2 t2
# 1  1  0
# 2  2  0
# 3  0  2
# 4  9 10
#        c2             t2
#  Min.   :0.00   Min.   : 0
#  1st Qu.:0.75   1st Qu.: 0
#  Median :1.50   Median : 1
#  Mean   :3.00   Mean   : 3
#  3rd Qu.:3.75   3rd Qu.: 4
#  Max.   :9.00   Max.   :10
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 5.0526, df = 3, p-value = 0.168
#
#
# 	Fisher's Exact Test for Count Data
#
# data:  dd
# p-value = 0.2298
# alternative hypothesis: two.sided
#
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  dd$t2 and dd$c2
# W = 7.5, p-value = 0.617
# alternative hypothesis: true location shift is greater than 0
# 95 percent confidence interval:
#  -8.999935       Inf
# sample estimates:
# difference in location
#           -2.38965e-05

# %% [markdown]
# ### T1 vs C2

# %%
t1 = df['with_who_1'][df['treatment_eval_1'] == 'A'].value_counts()
c2 = df['with_who_2'][df['treatment_eval_2'] == 'B'].value_counts()
dd = pd.DataFrame({'t1' : t1, 'c2':c2}).fillna(0)

# %%
# %%R -i dd
# library(MASS)
# library(vcd)
# print(dd)
# print(summary(dd))
# print(chisq.test(dd))
# print(fisher.test(dd))
# #print(assocstats(dd))
# wilcox.test(dd$t1, dd$c2, paired=TRUE, alternative = "greater")
# Out:
#   c2 t1
# 1  1  2
# 2  2  1
# 3  0  1
# 4  9  8
#        c2             t1
#  Min.   :0.00   Min.   :1.0
#  1st Qu.:0.75   1st Qu.:1.0
#  Median :1.50   Median :1.5
#  Mean   :3.00   Mean   :3.0
#  3rd Qu.:3.75   3rd Qu.:3.5
#  Max.   :9.00   Max.   :8.0
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 1.7255, df = 3, p-value = 0.6313
#
#
# 	Fisher's Exact Test for Count Data
#
# data:  dd
# p-value = 1
# alternative hypothesis: two.sided
#
#
# 	Wilcoxon signed rank test with continuity correction
#
# data:  dd$t1 and dd$c2
# V = 5, p-value = 0.5793
# alternative hypothesis: true location shift is greater than 0

# %% [markdown]
# ### T2 vs C1

# %%
t2 = df['with_who_2'][df['treatment_eval_2'] == 'A'].value_counts()
c1 = df['with_who_1'][df['treatment_eval_1'] == 'B'].value_counts()
dd = pd.DataFrame({'t2' : t2, 'c1':c1}).fillna(0)

# %%
# %%R -i dd
# library(MASS)
# print(dd)
# print(summary(dd))
# print(chisq.test(dd))
# #print(assocstats(dd))
# wilcox.test(dd$t2, dd$c1, paired=TRUE, alternative = "greater")
# Out:
#   c1 t2
# 2  1  0
# 3  3  2
# 4  8 10
#        c1            t2
#  Min.   :1.0   Min.   : 0
#  1st Qu.:2.0   1st Qu.: 1
#  Median :3.0   Median : 2
#  Mean   :4.0   Mean   : 4
#  3rd Qu.:5.5   3rd Qu.: 6
#  Max.   :8.0   Max.   :10
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 1.4222, df = 2, p-value = 0.4911
#
#
# 	Wilcoxon signed rank test with continuity correction
#
# data:  dd$t2 and dd$c1
# V = 3, p-value = 0.6073
# alternative hypothesis: true location shift is greater than 0

# %% [markdown]
# ### T1 vs T2

# %%
t1 = df['with_who_1'][df['treatment_eval_1'] == 'A'].value_counts()
t2 = df['with_who_2'][df['treatment_eval_2'] == 'A'].value_counts()
dd = pd.DataFrame({'t1' : t1, 't2': t2}).fillna(0)

# %%
# %%R -i dd
# library(MASS)
# print(dd)
# print(summary(dd))
# print(chisq.test(dd))
# #print(assocstats(dd))
#
# wilcox.test(dd$t1, dd$t2, paired=FALSE, conf.int = TRUE, alternative = "greater")
# Out:
#   t1 t2
# 1  2  0
# 2  1  0
# 3  1  2
# 4  8 10
#        t1            t2
#  Min.   :1.0   Min.   : 0
#  1st Qu.:1.0   1st Qu.: 0
#  Median :1.5   Median : 1
#  Mean   :3.0   Mean   : 3
#  3rd Qu.:3.5   3rd Qu.: 4
#  Max.   :8.0   Max.   :10
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 3.5556, df = 3, p-value = 0.3136
#
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  dd$t1 and dd$t2
# W = 9.5, p-value = 0.3844
# alternative hypothesis: true location shift is greater than 0
# 95 percent confidence interval:
#  -8.99994      Inf
# sample estimates:
# difference in location
#              0.9999308

# %% [markdown]
# ### C1 vs C2

# %%
c1 = df['with_who_1'][df['treatment_eval_1'] == 'B'].value_counts()
c2 = df['with_who_2'][df['treatment_eval_2'] == 'B'].value_counts()
dd = pd.DataFrame({'c1' : c1, 'c2': c2}).fillna(0)

# %%
# %%R -i dd
# library(MASS)
# print(dd)
# print(summary(dd))
# print(chisq.test(dd))
# #print(assocstats(dd))
#
# wilcox.test(dd$c1,dd$c2, paired=FALSE, conf.int = TRUE, alternative = "greater")
# Out:
#   c1 c2
# 1  0  1
# 2  1  2
# 3  3  0
# 4  8  9
#        c1             c2
#  Min.   :0.00   Min.   :0.00
#  1st Qu.:0.75   1st Qu.:0.75
#  Median :2.00   Median :1.50
#  Mean   :3.00   Mean   :3.00
#  3rd Qu.:4.25   3rd Qu.:3.75
#  Max.   :8.00   Max.   :9.00
#
# 	Pearson's Chi-squared test
#
# data:  dd
# X-squared = 4.3922, df = 3, p-value = 0.2221
#
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  dd$c1 and dd$c2
# W = 8, p-value = 0.5581
# alternative hypothesis: true location shift is greater than 0
# 95 percent confidence interval:
#  -7.999956       Inf
# sample estimates:
# difference in location
#          -2.508769e-05

# %% [markdown]
# There is not a Statistical difference between the distributions (T1 vs C1).
#
#
# Actually the null hypothesis seems to be true in all interactions.
#
#
# T1-C1 = T1-C2 = C1-T2 = C2-T2

# %% [markdown]
# ### Chi square Analysi

# %%
df_filtered['measure_1'] = df_filtered.apply(lambda row: code_openess_labels(row['treatment_eval_1'], row['with_who_1']), axis=1)
df_filtered['measure_2'] = df_filtered.apply(lambda row: code_openess_labels(row['treatment_eval_2'], row['with_who_2']), axis=1)

# %% [markdown]
# ###Logistic regression analysis

# %%
gg = df_new[['treatment_eval_1', 'treatment_eval_2','with_who_1','with_who_2']]
df_x = pd.melt(gg, id_vars=['treatment_eval_1', 'treatment_eval_2'])
df_x['trt'] = df_x.apply(lambda row: sepa_trt(row), axis=1)
df_x['trt'] = df_x['trt'].replace(['A','B'],['1','0'])
ddf = df_x.sort(columns=['trt'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-4a19f79a84a5> in <module>()
# ----> 1 gg = df_new[['treatment_eval_1', 'treatment_eval_2','with_who_1','with_who_2']]
#       2 df_x = pd.melt(gg, id_vars=['treatment_eval_1', 'treatment_eval_2'])
#       3 df_x['trt'] = df_x.apply(lambda row: sepa_trt(row), axis=1)
#       4 df_x['trt'] = df_x['trt'].replace(['A','B'],['1','0'])
#       5 ddf = df_x.sort(columns=['trt'])
#
# NameError: name 'df_new' is not defined

# %% [markdown]
# ###T1 ~ C2

# %%
t1c2 = ddf[(ddf['variable'] == 'with_who_1') & (ddf['trt'] == '1') | (ddf['variable'] == 'with_who_2') & (ddf['trt'] == '0')]

t1c2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-b028bc1b0b16> in <module>()
# ----> 1 t1c2 = ddf[(ddf['variable'] == 'with_who_1') & (ddf['trt'] == '1') | (ddf['variable'] == 'with_who_2') & (ddf['trt'] == '0')]
#       2
#       3 t1c2
#
# NameError: name 'ddf' is not defined

# %%
# %%R -i t1c2
# library(MASS)
# ddf2 <- data.frame(t1c2)
# ddf2$value <- factor(ddf2$value)
# ddf2$trt <- factor(ddf2$trt)
#
# mymodel = polr(value ~ trt, data=ddf2,  Hess=TRUE)
#
# n1 <- data.frame(trt='1')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Treatment')
# print(s)
# n1 <- data.frame(trt='0')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Control')
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
# [1] "Probabilities for Treatment"
#          1          2          3          4
# 0.09068777 0.12346323 0.06237514 0.72347386
# [1] "Probabilities for Control"
#          1          2          3          4
# 0.10476817 0.13752465 0.06734228 0.69036490
# Waiting for profiling to be done...
#              OR
# 2.5 %  1.173433 0.2386576
# 97.5 % 1.173433 5.5378060

# %% [markdown]
# ###T2 ~ C1

# %%
t2c1 = ddf[(ddf['variable'] == 'with_who_1') & (ddf['trt'] == '0') | (ddf['variable'] == 'with_who_2') & (ddf['trt'] == '1')]

# %%
# %%R -i t2c1
# library(MASS)
# ddf2 <- data.frame(t2c1)
# ddf2$value <- factor(ddf2$value)
# ddf2$trt <- factor(ddf2$trt)
#
# mymodel = polr(value ~ trt, data=ddf2,  Hess=TRUE)
#
# n1 <- data.frame(trt='1')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Treatment')
# print(s)
# n1 <- data.frame(trt='0')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Control')
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
# [1] "Probabilities for Treatment"
#         2         3         4
# 0.1409080 0.1659252 0.6931668
# [1] "Probabilities for Control"
#         2         3         4
# 0.2518871 0.2241886 0.5239243
# Waiting for profiling to be done...
#              OR
# 2.5 %  2.052782 0.4996914
# 97.5 % 2.052782 8.9842739

# %% [markdown]
# ###T1 ~ C1

# %%
t1c1 = ddf[ddf['variable'] == 'with_who_1']

# %%
# %%R -i t1c1
# library(MASS)
# ddf2 <- data.frame(t1c1)
# ddf2$value <- factor(ddf2$value)
# ddf2$trt <- factor(ddf2$trt)
#
# mymodel = polr(value ~ trt, data=ddf2,  Hess=TRUE, na.action=na.omit)
#
# n1 <- data.frame(trt='1')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Treatment')
# print(s)
# n1 <- data.frame(trt='0')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Control')
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
# [1] "Probabilities for Treatment"
#          1          2          3          4
# 0.02261218 0.12049613 0.16834732 0.68854436
# [1] "Probabilities for Control"
#          1          2          3          4
# 0.04313412 0.20238336 0.22295513 0.53152739
# Waiting for profiling to be done...
#              OR
# 2.5 %  1.948473 0.4753499
# 97.5 % 1.948473 8.4946094

# %% [markdown]
# ###T2 ~ C2

# %%
t2c2 = ddf[ddf['variable'] == 'with_who_2']

# %%
# %%R -i t2c2
# library(MASS)
# ddw2 <- data.frame(t2c2)
# ddw2$value <- factor(ddw2$value)
# ddw2$trt <- factor(ddw2$trt)
#
# mymodel = polr(value ~ trt, data=ddw2,  Hess=TRUE, na.action=na.omit)
#
# n1 <- data.frame(trt='1')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Treatment')
# print(s)
# n1 <- data.frame(trt='0')
# s<-predict(mymodel,n1, type="probs")
# print('Probabilities for Control')
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
# [1] "Probabilities for Treatment"
#          1          2          3          4
# 0.05832332 0.15054936 0.06117490 0.72995241
# [1] "Probabilities for Control"
#          1          2          3          4
# 0.07315170 0.17859302 0.06864622 0.67960906
# Waiting for profiling to be done...
#              OR
# 2.5 %  1.274311 0.2580346
# 97.5 % 1.274311 6.0594170

# %% [markdown]
# ##Research Question 1: Is a treatment better than the other one?
# Comparison all Control vs All Treatment

# %%
df = master_dataset.replace(['cite DataLabour','Jam Share Data'],['A','B'])
df = df[['treatment_eval_1','treatment_eval_2','with_who_1','with_who_2']].dropna()
df = df[df.treatment_eval_1 != df.treatment_eval_2]
df = df.replace(['stackeholders'],['stakeholders'])
df = df.replace(['private','collaborators','stakeholders','public'],[1,2,3,4])


t1 = df['with_who_1'][df['treatment_eval_1'] == 'A'].head(10)
c1 = df['with_who_1'][df['treatment_eval_1'] == 'B'].head(10)
print t1
print c1
# Out:
# sessionid
# 2916e59453604e0bf19d4b3b60b75fdd    4
# 28d0f45805f4a2e9ec4d8fe4cf2e517e    4
# 8ed6774338c3fee17bbdca2dfbc7f1d6    2
# f1deeddb2588e790d7425adfa7ffb307    4
# d1cf1e2bd3e41f2bd3576a32593e2f73    4
# c2026cc168583afd72bbfbb284c0f1e9    3
# 9f739b36a1f91569017b5ab36be07f7f    1
# 0edc7c52e0ccb1714e9a39ea75af43fe    4
# 5df3091a4aeef9cea0b9a9d2335b4f49    4
# 6481c74f482bb574529fcfe12f7247c2    4
# Name: with_who_1, dtype: int64
# sessionid
# 68ec3fb55059c118977c24cbd4fca91c    4
# 66f12cf71b45603b5b5bded2142fb89c    4
# 03ebd33fe07a1226f3b98aa8aa13e76e    4
# 03ebd33fe07a1226f3b98aa8aa13e76e    4
# 358e6df6c02309c57fd05b27540fb8e8    2
# 62d5d75aa5c5c673ff839565556057cd    3
# 86ed6760b4a6fc54cff9850e090c7b5f    3
# 88f18269f0d7ff772f8a3f89fc8c81cb    3
# b540afa5300616f5a6ed80106fb6b20e    4
# e9e357d280b62fde1f5c9b718ee3ea36    4
# Name: with_who_1, dtype: int64

# %%
# %%R -i t1 -i c1
# library(MASS)
#
# tbl = table(t1, c1)
# chisq.test(tbl)
# Out:
# 	Pearson's Chi-squared test
#
# data:  tbl
# X-squared = 6.1905, df = 6, p-value = 0.4022

# %% [markdown]
# ###Data Re-shape

# %%
df_filtered.head(10)
pd.DataFrame.to_csv(df_filtered,'logs/data_coded_csv')

gg = df_filtered

x = batch_code(gg)

dataUnderShareA = x[x['treatment_eval_1'] == 'Jam Share Data']
dataUnderShareB = x[x['treatment_eval_2'] == 'Jam Share Data']

dataUnderShareA = dataUnderShareA.reset_index()
dataUnderShareB = dataUnderShareB.reset_index()

dataUnderShare = dataUnderShareA['measure_1'].append(dataUnderShareB['measure_2'])

dataUnderCiteA = x[x['treatment_eval_1'] == 'cite DataLabour']
dataUnderCiteB = x[x['treatment_eval_2'] == 'cite DataLabour']

dataUnderCiteA = dataUnderCiteA.reset_index()
dataUnderCiteB = dataUnderCiteB.reset_index()

dataUnderCite = dataUnderCiteA['measure_1'].append(dataUnderCiteB['measure_2'])
DFdataUnderCite = pd.DataFrame({'Treatment_GAIN' :dataUnderCite})

DFdataUnderShare = pd.DataFrame({'Treatment_LOSS' :dataUnderShare})
# Out:
# null
# null
# null
# null
# null
# 1y
# null
# null
# nan
# 6m
# 1y
# nan
# nan
# nan
# nan
# 10y
# 10y
# nan
# nan
# null
# nan
# nan
# null
# nan
# 10y
# nan
# nan
# nan
# nan
# 10y
# nan
# nan
# nan
# nan
# nan
# nan
# 6m
# nan

# %%
dataUnderShare       = dataUnderShareA['ease_1'].append(dataUnderShareB['ease_2'])
dataUnderCite        = dataUnderCiteA['ease_1'].append(dataUnderCiteB['ease_2'])
DFdataUnderCiteEase  = pd.DataFrame({'Treatment_GAIN_ease' :dataUnderCite})
DFdataUnderShareEase = pd.DataFrame({'Treatment_LOSS_ease' :dataUnderShare})

dataUnderShare       = dataUnderShareA['support_1'].append(dataUnderShareB['support_2'])
dataUnderCite        = dataUnderCiteA['support_1'].append(dataUnderCiteB['support_2'])
DFdataUnderCiteSupport  = pd.DataFrame({'Treatment_GAIN_support' :dataUnderCite})
DFdataUnderShareSupport = pd.DataFrame({'Treatment_LOSS_support' :dataUnderShare})

dataUnderShare       = dataUnderShareA['time_1'].append(dataUnderShareB['time_2'])
dataUnderCite        = dataUnderCiteA['time_1'].append(dataUnderCiteB['time_2'])
DFdataUnderCiteTime  = pd.DataFrame({'Treatment_GAIN_time' :dataUnderCite})
DFdataUnderShareTime = pd.DataFrame({'Treatment_LOSS_time' :dataUnderShare})

dataUnderShare       = dataUnderShareA['regret_1'].append(dataUnderShareB['regret_2'])
dataUnderCite        = dataUnderCiteA['regret_1'].append(dataUnderCiteB['regret_2'])
DFdataUnderCiteRegret  = pd.DataFrame({'Treatment_GAIN_regret' :dataUnderCite})
DFdataUnderShareRegret = pd.DataFrame({'Treatment_LOSS_regret' :dataUnderShare})




dataUnderShare       = dataUnderShareA['when_to_1'].append(dataUnderShareB['when_to_2'])
dataUnderCite        = dataUnderCiteA['when_to_1'].append(dataUnderCiteB['when_to_2'])
DFdataUnderCiteWhento  = pd.DataFrame({'GAIN_when_to' :dataUnderCite})
DFdataUnderShareWhento = pd.DataFrame({'LOSS_when_to' :dataUnderShare})

# %%
def axbow(t):
    r = ""
    if t == 'Jam Share Data':
        r =0
    elif t == 'cite DataLabour':
        r = 1
    return r
    
df_filtered['treatment_1'] = df_filtered.apply(lambda row: code_treatment_numeric(row['treatment_eval_1']), axis=1)
df_filtered['treatment_2'] = df_filtered.apply(lambda row: code_treatment_numeric(row['treatment_eval_2']), axis=1)
# Out:
# -c:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# -c:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_filtered['measure_1'] = df_filtered.apply(lambda row: code_openess_numeric(row['treatment_eval_1'], row['with_who_1']), axis=1)
df_filtered['measure_1']
mydatatable_1 = df_filtered[['measure_1','year_born','treatment_1']]
mydatatable_1 = mydatatable_1.drop(['c2026cc168583afd72bbfbb284c0f1e9','73cd08d3f841f5a9f085fd88a7694216'])
mydatatable_1

df_filtered['measure_2'] = df_filtered.apply(lambda row: code_openess_numeric(row['treatment_eval_2'], row['with_who_2']), axis=1)
df_filtered['measure_2']
mydatatable = df_filtered[['measure_2','year_born','treatment_2']]
mydatatable = mydatatable.dropna()
mydatatable
# Out:
# -c:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                  measure_2  year_born treatment_2
# sessionid
# b4bd8ddfbcf302338f7898eec8382690         4       1986           1
# 2916e59453604e0bf19d4b3b60b75fdd         4       1981           0
# 28d0f45805f4a2e9ec4d8fe4cf2e517e         4       1990           0
# 0ad6197707803a31a98aa69dccc39bad         4       1986           1
# d8695dead80bb8f3ba0caa25e5ca785c                 1987
# 8ed6774338c3fee17bbdca2dfbc7f1d6         2       1991           0
# f1deeddb2588e790d7425adfa7ffb307         4       1987           0
# d1cf1e2bd3e41f2bd3576a32593e2f73         4       1986           0
# 68ec3fb55059c118977c24cbd4fca91c         4       1978           1
# c2026cc168583afd72bbfbb284c0f1e9         4       1987           0
# 9f739b36a1f91569017b5ab36be07f7f         1       1975           0
# 66f12cf71b45603b5b5bded2142fb89c         4       1986           1
# 03ebd33fe07a1226f3b98aa8aa13e76e         4       1985           1
# 03ebd33fe07a1226f3b98aa8aa13e76e         4       1985           1
# 0edc7c52e0ccb1714e9a39ea75af43fe         4       1979           0
# 358e6df6c02309c57fd05b27540fb8e8         4       1975           1
# 62d5d75aa5c5c673ff839565556057cd         4       1981           1
# b540afa5300616f5a6ed80106fb6b20e         3       1982           1
# e9e357d280b62fde1f5c9b718ee3ea36         4       1989           1

# %%
# %%R -i mydatatable
# library(MASS)
# df_filtered <- data.frame(mydatatable)
# df_filtered$measure_2 <- factor(df_filtered$measure_2)
# df_filtered$year_born <- as.numeric(df_filtered$year_born)
#
# print (head(df_filtered,10))
#
# mymodel = polr(measure_2 ~ treatment_2, data=df_filtered, Hess=TRUE, na.action=na.omit)
#
# n1 <- data.frame(treatment_2='0')
# s<-predict(mymodel,n1, type="probs")
#
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
#    measure_2 year_born treatment_2
# 1          4      1986           1
# 2          4      1981           0
# 3          4      1990           0
# 4          4      1986           1
# 5                 1987
# 6          2      1991           0
# 7          4      1987           0
# 8          4      1986           0
# 9          4      1978           1
# 10         4      1987           0
#                         1            2            3            4
# 0.0000174785 0.0927116831 0.0927174481 0.0860721750 0.7284812152
# Waiting for profiling to be done...
# Error in optim(s0, fmin, gmin, method = "BFGS", ...) :
#   initial value in 'vmmin' is not finite
# In addition: There were 40 warnings (use warnings() to see them)
# Error in optim(s0, fmin, gmin, method = "BFGS", ...) :
#   initial value in 'vmmin' is not finite

# %%
print mydatatable
print mydatatable_1

mydatatable.columns = ['measure', 'year_born','treatment']
mydatatable_1.columns = ['measure', 'year_born','treatment']
c = mydatatable_1.append(mydatatable, ignore_index=True )
c
# Out:
#                                  measure_2  year_born treatment_2
# sessionid
# b4bd8ddfbcf302338f7898eec8382690         4       1986           1
# 2916e59453604e0bf19d4b3b60b75fdd         4       1981           0
# 28d0f45805f4a2e9ec4d8fe4cf2e517e         4       1990           0
# 0ad6197707803a31a98aa69dccc39bad         4       1986           1
# d8695dead80bb8f3ba0caa25e5ca785c                 1987
# 8ed6774338c3fee17bbdca2dfbc7f1d6         2       1991           0
# f1deeddb2588e790d7425adfa7ffb307         4       1987           0
# d1cf1e2bd3e41f2bd3576a32593e2f73         4       1986           0
# 68ec3fb55059c118977c24cbd4fca91c         4       1978           1
# c2026cc168583afd72bbfbb284c0f1e9         4       1987           0
# 9f739b36a1f91569017b5ab36be07f7f         1       1975           0
# 66f12cf71b45603b5b5bded2142fb89c         4       1986           1
# 03ebd33fe07a1226f3b98aa8aa13e76e         4       1985           1
# 03ebd33fe07a1226f3b98aa8aa13e76e         4       1985           1
# 0edc7c52e0ccb1714e9a39ea75af43fe         4       1979           0
# 358e6df6c02309c57fd05b27540fb8e8         4       1975           1
# 62d5d75aa5c5c673ff839565556057cd         4       1981           1
# b540afa5300616f5a6ed80106fb6b20e         3       1982           1
# e9e357d280b62fde1f5c9b718ee3ea36         4       1989           1
#                                   measure_1  year_born  treatment_1
# sessionid
# b4bd8ddfbcf302338f7898eec8382690          4       1986            1
# 2916e59453604e0bf19d4b3b60b75fdd          4       1981            1
# 28d0f45805f4a2e9ec4d8fe4cf2e517e          4       1990            1
# 0ad6197707803a31a98aa69dccc39bad          4       1986            1
# d8695dead80bb8f3ba0caa25e5ca785c          4       1987            1
# 8ed6774338c3fee17bbdca2dfbc7f1d6          2       1991            1
# f1deeddb2588e790d7425adfa7ffb307          4       1987            1
# d1cf1e2bd3e41f2bd3576a32593e2f73          4       1986            1
# 68ec3fb55059c118977c24cbd4fca91c          4       1978            0
# 9f739b36a1f91569017b5ab36be07f7f          1       1975            1
# 66f12cf71b45603b5b5bded2142fb89c          4       1986            0
# 03ebd33fe07a1226f3b98aa8aa13e76e          4       1985            0
# 03ebd33fe07a1226f3b98aa8aa13e76e          4       1985            0
# 0edc7c52e0ccb1714e9a39ea75af43fe          4       1979            1
# 358e6df6c02309c57fd05b27540fb8e8          2       1975            0
# 62d5d75aa5c5c673ff839565556057cd          3       1981            0
# b540afa5300616f5a6ed80106fb6b20e          4       1982            0
# e9e357d280b62fde1f5c9b718ee3ea36          4       1989            0
#    measure  year_born treatment
# 0        4       1986         1
# 1        4       1981         1
# 2        4       1990         1
# 3        4       1986         1
# 4        4       1987         1
# 5        2       1991         1
# 6        4       1987         1
# 7        4       1986         1
# 8        4       1978         0
# 9        1       1975         1
# 10       4       1986         0
# 11       4       1985         0
# 12       4       1985         0
# 13       4       1979         1
# 14       2       1975         0
# 15       3       1981         0
# 16       4       1982         0
# 17       4       1989         0
# 18       4       1986         1
# 19       4       1981         0
# 20       4       1990         0
# 21       4       1986         1
# 22               1987
# 23       2       1991         0
# 24       4       1987         0
# 25       4       1986         0
# 26       4       1978         1
# 27       4       1987         0
# 28       1       1975         0
# 29       4       1986         1
# 30       4       1985         1
# 31       4       1985         1
# 32       4       1979         0
# 33       4       1975         1
# 34       4       1981         1
# 35       3       1982         1
# 36       4       1989         1

# %%
# %%R -i c
# library(MASS)
# df_filtered <- data.frame(c)
# df_filtered$measure <- factor(df_filtered$measure)
# df_filtered$year_born <- as.numeric(df_filtered$year_born)
#
# print (head(df_filtered,10))
#
# mymodel = polr(measure ~ treatment, data=df_filtered, Hess=TRUE, na.action=na.omit)
#
# n1 <- data.frame(treatment='0')
# s<-predict(mymodel,n1, type="probs")
#
# print(s)
#
# exp(cbind(OR =coef(mymodel), confint(mymodel)))
# Out:
#   measure year_born treatment
# 0       4      1986         1
# 1       4      1981         1
# 2       4      1990         1
# 3       4      1986         1
# 4       4      1987         1
# 5       2      1991         1
# 6       4      1987         1
# 7       4      1986         1
# 8       4      1978         0
# 9       1      1975         1
#                         1            2            3            4
# 1.413751e-05 7.367332e-02 1.067197e-01 6.865265e-02 7.509402e-01
# Waiting for profiling to be done...
#                     OR    2.5 % 97.5 %
# treatment0  6783446377  7.84442     NA
# treatment1 12702992860 14.40907     NA

# %% [markdown]
# ##Research Question 2: Is a treatment better than the other one when accounting for carry-over effects?
# Comparison Control vs Treatment only in first measure.

# %%
DFdataUnderCiteMeasure  = pd.DataFrame({'GAIN_P1' : x.measure_1[x.treatment_eval_1 == 'cite DataLabour']})
DFdataUnderShareMeasure = pd.DataFrame({'LOSS_P1' : x.measure_1[x.treatment_eval_1 == 'Jam Share Data']})

# %% [markdown]
# ####Sharing Behavior

# %%
# %%R -i DFdataUnderCiteMeasure -i DFdataUnderShareMeasure
# require(likert)
# require(reshape)
# library(RColorBrewer)
# library(plyr)
# cc <-brewer.pal(4, "PuBu")
# #mydata = read.csv("../../delete_two_records_csv")
#
# #Product_Gain <- c(x$measure_1[x$treatment_eval_1 == 'cite DataLabour'])
# #Product_Loss <- c(x$measure_1[x$treatment_eval_1 == 'Jam Share Data'])
# #Product_Gain <- c(mydata$regret_1[mydata$treatment_eval_1 == 'cite DataLabour'], mydata$regret_2[mydata$treatment_eval_2 == 'cite DataLabour'])
# #Product_Loss <- c(mydata$regret_1[mydata$treatment_eval_1 == 'Jam Share Data'], mydata$regret_2[mydata$treatment_eval_2 == 'Jam Share Data'])
#
# likertLabels<- c("private", "collaborators", "stackeholders", "public")
#
#    dAlcite <- data.frame(DFdataUnderCiteMeasure)
#    dAshare <- data.frame(DFdataUnderShareMeasure)
#
#    myList5 <- list(dAshare, dAlcite)
#    junto <-do.call(rbind.fill, myList5)
#    djunto <- data.frame(junto)
#    mydata2 <- junto
#
# DFG <- lapply(mydata2, factor, levels = likertLabels)
# d <- data.frame(DFG)
# df24<-likert(d)
# s<- plot(df24, color=cc,center=3, text.size=4,plot.percents=TRUE, plot.percent.neutral=FALSE,plot.percent.low=FALSE, plot.percent.high=FALSE, ordered=FALSE, group.order=names(d))
# s
# Out:
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-587-1835996c1253> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'R', u'-i DFdataUnderCiteMeasure -i DFdataUnderShareMeasure', u'require(likert)\nrequire(reshape)\nlibrary(RColorBrewer)\nlibrary(plyr)\ncc <-brewer.pal(4, "PuBu")\n#mydata = read.csv("../../delete_two_records_csv")\n\n#Product_Gain <- c(x$measure_1[x$treatment_eval_1 == \'cite DataLabour\'])\n#Product_Loss <- c(x$measure_1[x$treatment_eval_1 == \'Jam Share Data\'])\n#Product_Gain <- c(mydata$regret_1[mydata$treatment_eval_1 == \'cite DataLabour\'], mydata$regret_2[mydata$treatment_eval_2 == \'cite DataLabour\'])\n#Product_Loss <- c(mydata$regret_1[mydata$treatment_eval_1 == \'Jam Share Data\'], mydata$regret_2[mydata$treatment_eval_2 == \'Jam Share Data\'])\n   \nlikertLabels<- c("private", "collaborators", "stackeholders", "public")\n  \n   dAlcite <- data.frame(DFdataUnderCiteMeasure)\n   dAshare <- data.frame(DFdataUnderShareMeasure)\n\n   myList5 <- list(dAshare, dAlcite)\n   junto <-do.call(rbind.fill, myList5)\n   djunto <- data.frame(junto)\n   mydata2 <- junto\n\nDFG <- lapply(mydata2, factor, levels = likertLabels)\nd <- data.frame(DFG)\ndf24<-likert(d)\ns<- plot(df24, color=cc,center=3, text.size=4,plot.percents=TRUE, plot.percent.neutral=FALSE,plot.percent.low=FALSE, plot.percent.high=FALSE, ordered=FALSE, group.order=names(d)) \ns ')
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2160             magic_arg_s = self.var_expand(line, stack_depth)
#    2161             with self.builtin_trap:
# -> 2162                 result = fn(magic_arg_s, cell)
#    2163             return result
#    2164
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/extensions/rmagic.pyc in R(self, line, cell, local_ns)
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/IPython/extensions/rmagic.pyc in R(self, line, cell, local_ns)
#     615                     old_writeconsole = ri.get_writeconsole()
#     616                     ri.set_writeconsole(self.write_console)
# --> 617                     ro.r.show(result)
#     618                     text_output += self.flush()
#     619                     ri.set_writeconsole(old_writeconsole)
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/robjects/functions.pyc in __call__(self, *args, **kwargs)
#     168                 v = kwargs.pop(k)
#     169                 kwargs[r_k] = v
# --> 170         return super(SignatureTranslatedFunction, self).__call__(*args, **kwargs)
#     171
#     172 pattern_link = re.compile(r'\\link\{(.+?)\}')
#
# /Users/kristian/miniconda/lib/python2.7/site-packages/rpy2/robjects/functions.pyc in __call__(self, *args, **kwargs)
#      98         for k, v in kwargs.items():
#      99             new_kwargs[k] = conversion.py2ri(v)
# --> 100         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     101         res = conversion.ri2ro(res)
#     102         return res
#
# RRuntimeError: Error in eval(expr, envir, enclos) : object 'pos' not found

# %%
DFdataUnderCiteRegret  = pd.DataFrame({'GAIN_regret_P1' : x.regret_1[x.treatment_eval_1 == 'cite DataLabour']})
DFdataUnderShareRegret = pd.DataFrame({'LOSS_regret_P1' : x.regret_1[x.treatment_eval_1 == 'Jam Share Data']})
